# %%
import pandas as pd
import igraph as ig
from ipysigma import Sigma
import glob
import json
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt

# %%
edgelist = pd.DataFrame(columns=['forward_from','forward_to','count'])

for path in glob.glob('../*_edgelist/*edgelist*.csv'):
    df = pd.read_csv(path)
    edgelist = pd.concat([edgelist,df])

# %%
## load it into igraph
G = ig.Graph.TupleList(edgelist.itertuples(index=False), directed=True, weights=True)

# %%
## community detection
communities = G.as_undirected().community_leiden(objective_function="modularity")

## add community as node label
G.vs['community'] = communities.membership

# %%
with open('../dictionaires/id_to_desc.json') as file_desc,\
    open('../dictionaires/id_to_names.json') as file_names:
    id_to_desc = json.load(file_desc)
    id_to_names = json.load(file_names)

# %%
id_to_names_int = dict(map(lambda x: (int(x[0]),x[1]), id_to_names.items()))
id_to_desc_int = dict(map(lambda x: (int(x[0]),x[1]), id_to_desc.items()))

# %%
G.vs['label'] = list(map(lambda x: id_to_names_int.get(x,x),G.vs['name']))
G.vs['desc'] = list(map(lambda x: id_to_desc_int.get(x,x),G.vs['name']))

# %%
Sigma(G, node_size=G.degree(mode='out'),
      node_color=G.vs['community'], 
      hide_edges_on_move=True,
      node_color_gradient='Viridis', node_label=G.vs['label'],
     layout_settings = {"barnesHutOptimize":False,
                       'gravity': 0.1})
# Out:
# Sigma(ig.Graph with 3,368 nodes and 9,716 edges)

# %%
max(communities.membership)
#twelve communities
# Out:
# 21

# %%
dict_degree = Counter(G.degree())
dict_degree_in = Counter(G.indegree())
dict_degree_out = Counter(G.outdegree())

# %%
plt.scatter(dict_degree.keys(), dict_degree.values())
plt.xscale('log')
plt.yscale('log')
plt.title('Degree distribution (total degree)')
plt.show()

# %%
plt.scatter(dict_degree_in.keys(), dict_degree_in.values())
plt.xscale('log')
plt.yscale('log')
plt.title('Indegree distribution')
plt.show()

# %%
plt.scatter(dict_degree_out.keys(), dict_degree_out.values())
plt.xscale('log')
plt.yscale('log')
plt.title('Outdegree distribution')
plt.show()

# %%
sorted(list(zip(G.vs['label'],G.vs.outdegree())), key=lambda x: x[1], reverse=True)
# Out:
# [('🏴\u200d☠️\U0001f977 Prima Linea 🏴 ⚒️', 51),
#  ('Antifa Enternasyonal', 44),
#  ('Osservatorio Repressione', 40),
#  ('CrimethInc. Ex-Workers Collective', 39),
#  ("Radio Onda D'Urto", 37),
#  ('Antifascist Solidarity', 34),
#  ("Antifascist 'Pics&Vids'", 34),
#  ('NO 41bis - International Mobilisation', 34),
#  ('Radical Graffiti', 33),
#  ('International Revolution', 33),
#  ('PALESTINA HOY 🇵🇸', 31),
#  ('Resistance News Network', 31),
#  ('Indian Libertarian Socialist Federation', 29),
#  ('Riotlibro', 29),
#  ('CND', 28),
#  ('Antifa Squads', 28),
#  ('Sopravvivere al degrado', 27),
#  ('Anticapitalist Surrealism 🇵🇸🔻', 26),
#  ('Anarchist Stickers Archive', 26),
#  ('Quds News Network', 25),
#  ('RiseUp4Rojava', 25),
#  ('Samidoun Estado español', 24),
#  ('🍉 Wesh La Smala 🍉', 23),
#  ('𝕱𝖗𝖔𝖒 Ⓐ𝖙𝖍𝖊𝖓𝖘 𝖜𝖎𝖙𝖍 𝕻𝖆𝖘𝖘𝖎𝖔𝖓 🏴', 23),
#  ('InfoAut', 23),
#  ('Dans la rue', 23),
#  ('Les ami•es des Soulèvements de la Terre', 22),
#  ('TUTTO SQUAT MILANO', 22),
#  ('Middle East Spectator', 21),
#  ('Seditionist Distribution', 21),
#  ('Brughiere', 21),
#  ('ANIMAL LIBERATION FRONT', 21),
#  ('AZIONE ANTIFASCISTA ROMA EST', 21),
#  ('Galactocosmic Ontological Disorder', 20),
#  ('red.', 20),
#  ('🇵🇸 Eye on Palestine', 20),
#  ('Plataforma Antirepressiva de Barcelona #PAB', 20),
#  ("Le Père Peinard - L'info libertaire", 20),
#  ('Press TV', 19),
#  ('Bellum Acta - Intel, Urgent News and Archives', 19),
#  ("Lacan's Whore House", 19),
#  ('💀🎃 Fully Automated Luxury Lesbian Space Anarcho Communism', 19),
#  ('Post-Syndiegram 🇵🇸', 19),
#  ('🛣 A69 - CANAL INFO 💥', 19),
#  ('War Monitor', 19),
#  ('United Anarchists', 19),
#  ('ÈGIDA', 19),
#  ('©️ʰᵃˡᵉᶜᵒˢⒶᵐᵃʳⁱˡˡᵒˢ™', 18),
#  ('Anonyme Citoyen', 18),
#  ('Critical Punkism', 18),
#  ('𝑩𝒂𝒄𝒌𝒍𝒂𝒔𝒉 𝑰𝒏𝒇𝒐 𝑪𝒉𝒂𝒏𝒏𝒆𝒍 🏴', 18),
#  ('ilrovescio', 18),
#  ('anarkiddie fuzzy memes', 18),
#  ('Antifa Street Art 🇵🇸', 18),
#  ('Radio Blackout 105.250FM', 18),
#  ('C.S.O.A. EX SNIA', 18),
#  ('POPULAR FRONT', 18),
#  ('/CIG/ Telegram | Counter Intelligence Global', 17),
#  ('Lebanese News and Updates', 17),
#  (1891165770, 17),
#  ('Intel Slava Z', 17),
#  ('Circolo Anarchico "La Faglia" — Foligno', 17),
#  ('Rete Kurdistan Italia', 17),
#  ('Som Antifeixistes ✊', 17),
#  ('Occupa & Resisti', 17),
#  ('VivelAnarchie', 16),
#  ('DD Geopolitics', 16),
#  ('SANA en Español🇸🇾', 16),
#  ('𝚁𝚎𝚟𝚘𝚕𝚞𝚌𝚒ó𝚗 𝙲𝚘𝚖𝚞𝚗𝚒𝚜𝚝𝚊☭', 16),
#  ('/r/latestagecapitalism', 16),
#  ('Kaosenlared', 16),
#  ('Rivoluzione Internazionale', 16),
#  ('Movimiento Antirrepresivo de Madrid', 16),
#  ('Youth Writing History', 16),
#  ('Europa Antifa', 16),
#  ('Contre Attaque Actu', 16),
#  ('Rise of the Global South', 15),
#  ('Post-Foucault', 15),
#  ('Irina 🇷🇺', 15),
#  ('The Cradle', 15),
#  ('@InfoAgitacion', 15),
#  ('Anarquistas por la Paz.', 15),
#  ('Global Project', 15),
#  ('This Too, Is a Forest', 15),
#  ('Lyon Insurrection', 15),
#  ('YPJ Information', 15),
#  ('⏚ Le Printemps du CARE, Collectif Autonome Révoltes et Entraide', 15),
#  ('Zaum!', 15),
#  ('Radio Onda Rossa', 15),
#  ('Molotov✊Contra la opresion', 14),
#  ('JugendInfo', 14),
#  ('Africa Intel', 14),
#  ('161 Crew', 14),
#  ('El Ojo 👁 Noticias sobre Israel, Palestina, Rusia, Ucrania, China, Estados Unidos, Irán, México, Ecuador | Política | Guerras',
#   14),
#  ('CNT-AIT', 14),
#  ('P(r)ettyposting 💖🍉', 14),
#  ('RÉVOLTE OLYMPIQUE', 14),
#  ('PEUPLE RÉVOLTÉ ✊', 14),
#  ("Enby pirate's depressed and horny memes and unrelated mischievous stuff",
#   14),
#  ('Sas Absolució ✊', 14),
#  ('Boccaccio Lovers 🏴\u200d☠', 14),
#  ('Al Mayadeen Español', 13),
#  ('Geopolitics Live', 13),
#  ('Frontflict 🇵🇸🔻🇱🇧', 13),
#  ('Los Sombreros Blancos [Z]', 13),
#  ('LON - I Memes di Benjamin', 13),
#  ('Post-Shitposting (ZHIN-ZHIAN-AZADI: Show Must Go On! edition)', 13),
#  ('Dionysian Anarchism', 13),
#  ('Carceri in rivolta', 13),
#  ('Via Independència (oficial)', 13),
#  ('¡Ahí les va!', 13),
#  ('elsaltodiario.com', 13),
#  ('Cronache Ribelli', 13),
#  ('En lutte contre la métropole 🏴\u200d☠️', 13),
#  ('Urgence Palestine', 13),
#  ('Alerta Gorria Irratia', 13),
#  ('Комітет Спротиву /// Resistance Committee', 13),
#  ('IWW', 13),
#  ('À bas les CRA (Centres de Rétention Administrative)', 13),
#  ('lean mean tiger team machine: Sopping Fucking Wet Edition', 13),
#  ('MDS Info', 13),
#  ('Milano Sud Antifascista', 13),
#  ('Plataforma Antirepressiva de Ponent', 13),
#  ('Galipettes Milano', 13),
#  ('🟥 CAPITALISMO ES BARBARIE / antiimperialismo/ solidaridad Palestina', 12),
#  ('HispanTV', 12),
#  ('Socialism Beer', 12),
#  ('The Big Pig Channel', 12),
#  ('ResistanceTrench mirror', 12),
#  ('Rerum Novarum // Intelligence, Breaking News, and Alerts', 12),
#  ('/r/COMPLETEANARCHY', 12),
#  ('Ucraniando', 12),
#  ("Canal Difusió de l'A.R.A.", 12),
#  ('Intel Republic', 12),
#  ('Stay Free', 12),
#  ("the left can't meme🐳 (🏳️\u200d🌈🏳️\u200d⚧️🇦🇱🇦🇱🇦🇱🇦🇱🇪🇭🇵🇸)", 12),
#  ('CCRuWu', 12),
#  ('Fotros Resistance (AryJeay)', 12),
#  ('World Pravda', 12),
#  ('Failures of Capitalism', 12),
#  ('RIOT DOGS', 12),
#  ('Hurriya Info', 12),
#  ('Convocatorias Descentralizadas', 12),
#  ('LIBERATION OR DEATH Ⓐ', 12),
#  ('Arbiter, My Beloved', 12),
#  ('Askatasuna_47', 12),
#  ('Antifa Tolosa', 12),
#  ('MONiTOR', 12),
#  ('Sare Antifaxista Euskal Herria', 11),
#  ('Pepe Escobar', 11),
#  ('فدراسیون عصر آنارشيسم / Federation of Anarchism Era', 11),
#  ('Circolo Culturale Anarchico “Gogliardo Fiaschi” — Carrara', 11),
#  ('анархістські меми 🇺🇦', 11),
#  ('Todo Por Hacer', 11),
#  ('Acaposting :3', 11),
#  ("L'Indipendente", 11),
#  ('To the left and beyond (we love big rodents)', 11),
#  ('Rapports de force - info', 11),
#  ('Propaganda Posters', 11),
#  ('La Directa', 11),
#  ('Telos 🚓🔥', 11),
#  ('Colpo di Tacco', 11),
#  ('Malditaultraderecha', 10),
#  ('RT en Español (sin censura - real-time mirror)', 10),
#  ('Revolução no Curdistão', 10),
#  ('RNN Prisoners', 10),
#  ('REDCOM', 10),
#  ('Fearless John - @European_dissident', 10),
#  ('slow ritornellos', 10),
#  ('OGB Info [IDF]', 10),
#  ('Atlantean "Fascist" Alternative', 10),
#  ('Al Otro Lado de la frontera de Ucrania', 10),
#  ('Euskal Herria-Donbass Elkartasun Komitea', 10),
#  ('Spanish Revolution', 10),
#  ('Slavyangrad', 10),
#  ('DAViD.cu', 10),
#  ('Global Intel Watch', 10),
#  ('Disclose.tv', 10),
#  ('Victor Ternovsky', 10),
#  ('ACAB includes Tankies', 10),
#  ('Stop Arming Israel - France', 10),
#  ('Action Palestine France', 10),
#  ('Nouvelles de Palestine', 10),
#  ('Guerras & Geopolitica🚀🔥', 10),
#  ('PAS DE JO 2024', 10),
#  ('Resistance Channel', 10),
#  ('Toulouse Insurgée', 10),
#  ('Автономное Действие', 10),
#  ('Memorial Antifascista', 10),
#  ('Antudo.info', 10),
#  ('Alerta Solidària', 10),
#  ('Off Topic News', 10),
#  ('Révolution Internationale', 10),
#  ('Moviments socials', 10),
#  ('Midget memes, broken dreams', 10),
#  ('ｃｙｂｅｒｐｕｎｋ － ａｃｒａｃｙｎｅｔ', 10),
#  ('Critica Università Della Strada - Dal 1312', 10),
#  ('INFOS GJ', 10),
#  ('Sevilla Anticarcelaria y Anarquista Ⓐ', 9),
#  ('mpr21.info', 9),
#  ('Marwa Osman--MidEaStream', 9),
#  ('MV', 9),
#  ('Really cool memes actually', 9),
#  ('Sardegna Anarchica', 9),
#  ('InfoDefenseENGLISH', 9),
#  ('ENTRE GUERRAS', 9),
#  ('elnacionalcat', 9),
#  ('Anarquismo (canal)', 9),
#  ('Nuestras casas son trinxeras', 9),
#  ('Black Mosquito', 9),
#  ('Bolognesi contro il passante', 9),
#  ('Action Urgence Palestine', 9),
#  ('Antifascist Alerts Naarm (Melbourne)', 9),
#  ('Колективи Солідарності • Solidarity Collectives', 9),
#  ('Lesbian Schizo Bar 🍉', 9),
#  ('Mediterranean Man', 9),
#  ('Grupo Ruptura', 9),
#  ('Eureka news', 9),
#  ('Saccage 2024', 9),
#  ('Vanessa Beeley', 9),
#  ('Descifrando la Guerra', 9),
#  ('Radio Tirso Libertaria', 9),
#  ('Strike Force #EscalateForGaza', 9),
#  ('[anywhere] Department of Ferrets, Memetics, and Cognitohazards', 9),
#  ('The unique and his peen', 9),
#  ('Eva Karene Bartlett, Reality Theories', 9),
#  ('AnarcoCanal', 9),
#  ("Eta's stolen memes 'n' queer stuff (personal art not included)", 9),
#  ('Hacker News', 9),
#  ("Jammish's random memes", 9),
#  ('algo randm🧅', 9),
#  ('AnarcoHacking 🖤❤️ 👨\u200d💻✊🏴', 9),
#  ('CSOA La Kasa Estudi Nou', 9),
#  ('Inhabit', 9),
#  ('La Vérité Censurée', 8),
#  ('NI UNA MÁS / Contra el relato', 8),
#  ('Lord Bebo & Friends', 8),
#  ('Comitato per il Donbass Antinazista - Notizie sulla guerra in Ucraina', 8),
#  ('West Burbs Fash Watch', 8),
#  ("PUNT D'INFLEXIÓ", 8),
#  ('PRESOS REVOLUCIONARIOS', 8),
#  ('IROP 🇵🇰', 8),
#  ('Anarchisterie Lilloise', 8),
#  ('HispanTV Producción', 8),
#  ('Manu Pineda🔻', 8),
#  ('Contropotere 🏴', 8),
#  ('Simurgh News Network', 8),
#  ('Comitè de Defensa de Represaliades 💪', 8),
#  ('Nûçe Ciwan Kurmancî', 8),
#  ('Horny Mementi', 8),
#  ('Tonho', 8),
#  ("L'AntiDiplomatico", 8),
#  ('🇵🇸 Canal BDS País Valencià', 8),
#  ('InfoDefenseESPAÑOL', 8),
#  (1191128783, 8),
#  ('Anti-work quotes', 8),
#  ('A Toda Potencia', 8),
#  ('Cancillería de Rusia', 8),
#  ('Jardins à Défendre', 8),
#  ('GERÎLA INTERNATIONAL', 8),
#  ('Difusión CNT-AIT Granada', 8),
#  ('Anarchy, Love and Memes', 8),
#  ('The1312Time', 8),
#  ('Global Resistance News', 8),
#  ('OUTSIDERS.ESP', 8),
#  ('Irídia - Drets Humans', 8),
#  ('🇵🇸 Al-Yudur Juventud Palestina', 8),
#  ('Líneas invisibles', 8),
#  ('CNT AIT Sierra de Madrid', 8),
#  ('Carmen Parejo', 8),
#  ('CNT AIT GIJÓN / XIXÓN', 8),
#  ('ROKOT | TORMENTA', 8),
#  ('Festival Intersquat en Ile-de-France', 8),
#  ('CDR Vic - Canal de comunicació', 8),
#  ('Antifascist Action Wollongong', 8),
#  ('ANTIIMPERIALISTAS', 7),
#  ('Rybar in English', 7),
#  ('Two Majors - English Channel', 7),
#  ('PUNTO.AR', 7),
#  ('TECs TERTULIAS EN CUARENTENA', 7),
#  ('Tupi Report 🇧🇷', 7),
#  ('🇦🇺AussieCossack🇷🇺', 7),
#  ('RoiLopezRivas', 7),
#  ('Sputnik Mundo (sin censura) real-time mirror', 7),
#  ('🇻🇪Venezuela News Network | Intel, Urgent News and Archives |Wild times in Venekistan 3.5 edition',
#   7),
#  ('🇷🇺LEVI🇧🇾', 7),
#  ('Anti-Imperialist Front', 7),
#  ('What, when, where, why, and how?', 7),
#  ('BULTZAKA', 7),
#  ('Futuro Vegetal 🧯', 7),
#  ('Ukraine Watch', 7),
#  ('YPJ MEDIA CENTER', 7),
#  ('CNT AIT 🔴⚫ Murcia & Cartagena', 7),
#  ('BcnLegends', 7),
#  ('Geopolítica actual', 7),
#  ('Er Cacanale dər Micheletrə', 7),
#  ('Believe In Syria - Axis Of Resistance', 7),
#  ('NATO eta EBren aurkako Herri Ekimena', 7),
#  ('⏚ Assemblée GJ LYON & Environs ⏚', 7),
#  ('Popular University 4 Gaza', 7),
#  ('Avis de Tempête', 7),
#  ('📢 CSA Can Vies', 7),
#  ('آرشیو گاهشمار آنارشیستی', 7),
#  ('canale di fiums', 7),
#  ('Info ZAD A69', 7),
#  ('CNT-AIT SOV (Madrid)', 7),
#  ('HORNYPOSTING 🤤', 7),
#  ('SDF_PRESS - المركز الإعلامي', 7),
#  ('Blood Meridian', 7),
#  ('Okupa y Resiste', 7),
#  ('Assemblea studentesca contro ogni carcere e cpr - Milano', 7),
#  ('TASS - Agencia rusa de noticias', 7),
#  ("L'insoumission", 7),
#  ('𝕷𝖊 𝕵𝖔𝖚𝖗𝖓𝖆𝖑 𝖉𝖚 𝖕𝖊𝖚𝖕𝖑𝖊 𝖘𝖞𝖗𝖎𝖊𝖓', 7),
#  (2082224197, 7),
#  ('commune.info', 7),
#  ("ULTIM'ORA 24", 7),
#  ('🏴 AnarchoMemes 🔥', 7),
#  ('Les Insurgés 🚩', 7),
#  ('Revista La Comuna.', 7),
#  ('Russians With Attitude', 7),
#  ('Bitácora soviética', 7),
#  ('𝑨𝒏𝒕𝒊𝒇𝒂𝒔𝒄𝒊𝒔𝒕𝒂𝒔', 7),
#  ('FUCK LAWNS', 7),
#  ('No Border info 🏴 Calais & more ✨', 7),
#  ('L.E.A. Berta Cáceres', 7),
#  ('Revolutionary Toolbox', 7),
#  ('AMI | L’Agenda Militant Indépendant', 7),
#  ('18+ The Weasel Meme Stash 18+', 7),
#  ('L38Squat', 7),
#  ('Anarcho Gardening', 7),
#  ('C.S.O.A. GABRIO', 7),
#  ('CSA Baraonda', 7),
#  ('notav.info', 7),
#  ('Genova Antifascista', 7),
#  ('WarZone - News', 6),
#  ('War Noir', 6),
#  ('The Journaltics', 6),
#  ('Ayatolá Jameneí', 6),
#  ('Kurdish Front News', 6),
#  ('Levant Observer', 6),
#  ('📣Diffusion Infos Toulouse ⏚', 6),
#  ('IRNA Español', 6),
#  ('neomarksizm 🚩leftist marxist socialist communist and anarchist memes ✊ enjoy comrades (❁´◡`❁)',
#   6),
#  ("Putinger's Cat / Кот Путингера", 6),
#  ('Yekîneyên Servanên Efrînê', 6),
#  ('Gerîla TV', 6),
#  ('Mapuche Info', 6),
#  ('Eurasia & Multipolarity', 6),
#  ('MilitaryPOV', 6),
#  ('🌵🐗 Groupe local audois des Soulèvements de la terre.', 6),
#  ('Ultimora.net - POLITICS 24', 6),
#  ('Governo del Cambianiente Channel', 6),
#  ('Eventi Incombenti Succulenti Mlmlm', 6),
#  ('Vakulinchuk', 6),
#  ('Asturies Insumisa', 6),
#  ('Palestine🇵🇸 - Agenda (Axdlr)', 6),
#  ('Contro il nulla che avanza', 6),
#  ('#LaResistència🟨🟥🟨🟥🟨🟥🟨🟥🟨', 6),
#  ('/r/Mapporn', 6),
#  ('Resumiendo', 6),
#  ('Rojava Agenda', 6),
#  ('Helena Villar', 6),
#  ('GNIP', 6),
#  ('🇵🇸 Assemblée internationaliste pour la Palestine 🌐', 6),
#  ('YPG Press Office', 6),
#  ('LISTE DES BLOCAGES PAYSANS ⚠️', 6),
#  ('Aula6Liberata✊🏽🇵🇸', 6),
#  ('ExLatteria Occupata Genova', 6),
#  ("Kaze's Beeposting 🐝", 6),
#  ('Free Open Source Posthumanism', 6),
#  ('Боец Анархист', 6),
#  ('ASIANOMICS', 6),
#  ('🎓 TIL - Today I Learned but no 🐝', 6),
#  ('Psychosis den🔞', 6),
#  ('Lyon Révolté', 6),
#  ('L’Altra Faccia dell’Impero', 6),
#  ('Wu Ming Foundation', 6),
#  ('Otras Italias', 6),
#  ('Interkiezionale News', 6),
#  ('Zic.it | Zeroincondotta', 6),
#  ('Le Gueuloir', 6),
#  ('Ministry of Doubleplusgood Dope 2️⃣➕😊', 6),
#  ('Inessa S ️️', 6),
#  ('Patria Socialista', 6),
#  ('Asamblea Libertaria Lorca', 6),
#  ('Violences Policières.fr', 6),
#  ('C̷Y̶P̸H̶E̸R̸P̷U̵N̷K̸', 6),
#  ('🌻 mansardaposting', 6),
#  ('Антифа ру', 6),
#  ('Il Tribolo', 6),
#  ('Is This an ADHD Thing?', 6),
#  ('eldiario.es', 6),
#  ('HUNT SABS 🦊🛠️', 6),
#  ('ALBATROPS', 6),
#  ('Ministry of good ideas', 6),
#  ('Info Collettivo di Fabbrica GKN Firenze', 6),
#  ('Rusia en España', 6),
#  ('Queerdump', 6),
#  ('Anarchopiratism', 6),
#  ('Chrono Vox - 🇮🇹', 6),
#  ('Estudio Insurgencia', 6),
#  ('KCK-Info', 6),
#  ('Good Shit™️😤😤', 6),
#  ('MemeⒶrchy', 6),
#  ('DesnonamentsBCN', 6),
#  ('Friggitoria di frociomemini', 6),
#  ('Lsoa Buridda', 6),
#  ('RéseauGMA (Grève Manifs Actions)', 5),
#  ('Agencia El Vigía', 5),
#  ('Antiwork', 5),
#  (1195125468, 5),
#  ('The Islander', 5),
#  ('Alle zusammen gegen den Faschismus - #riseup4rojava', 5),
#  ('Andrea Lucidi -Canale ufficiale- Андреа Лучиди -официальный телеграм канал-',
#   5),
#  ('Yıldız Teşkilatı Haber', 5),
#  ('OGB Discussion [IDF]', 5),
#  ('Donbass italia', 5),
#  ('ANRed noticias', 5),
#  ('Russian MFA 🇷🇺', 5),
#  ('QVINTA ÆTAS', 5),
#  ('SAMU.ZA', 5),
#  ('LoQueSomosWeb', 5),
#  ('Pinch Klub', 5),
#  ('SYDNEY CRIMINAL LAWYERS', 5),
#  ('Wofnon', 5),
#  ('ShamS', 5),
#  ('teleSURtv', 5),
#  ('Kurdistán', 5),
#  ('CNT-AIT MARINA ALTA', 5),
#  ('📣 Et La Rue Elle Est À Qui❓', 5),
#  ('Sputnik Africa', 5),
#  ('Rojava Vive * Kollettiva Jiyan', 5),
#  ('Giubbe Rosse', 5),
#  ('Keith Woods', 5),
#  ('Politfacts', 5),
#  ('Begumpura: bahujan antifascism', 5),
#  ('NEW WORLD ORDYR ٣١٣', 5),
#  ('Sturm und Meme', 5),
#  ('@SalamancaAntinuclear', 5),
#  ('Saker Italia', 5),
#  ('301Military', 5),
#  ('Черная книга капитализма | ЧКК', 5),
#  ('ʀᴇᴊᴇᴄᴛ ᴍᴇᴅɪᴀ', 5),
#  ('El Necio', 5),
#  ('Nuevos paradigmas', 5),
#  ('OPAL 🇨🇱', 5),
#  ('Canciones Protesta', 5),
#  ('El Informante Universal', 5),
#  ('Rozbrat', 5),
#  ('Comité Local Soulèvements de la Terre Lyon', 5),
#  ('YJA STAR', 5),
#  ('CGTZonaSur', 5),
#  ('/tmp/', 5),
#  ('BASTASFRATTI canale #rentstrike', 5),
#  ('The Children of Gaza', 5),
#  ('Heil Ukraine', 5),
#  ('Geoestrategia y Política', 5),
#  ('Al Descubierto Oficial', 5),
#  (1394845916, 5),
#  ('🔞 Hot goth girl anarcho-shitposting and unsolicited advice 🔞', 5),
#  ('Revolt France', 5),
#  ('IAATA - Information Anti-Autoritaire Toulouse et Alentours', 5),
#  ("L'Accent", 5),
#  ('Montpellier Poing Info', 5),
#  ('Solidaridad Obrera', 5),
#  ('ﷺIMAMAT_SANSARA☸️', 5),
#  ('The Right People Z', 5),
#  (1184107842, 5),
#  ('Columbia Encampment', 5),
#  ('Mars Infos', 5),
#  ("Sindicat d'Estudiants dels Països Catalans", 5),
#  ('Marcelleria™', 5),
#  ('FemiNews ♀#NiUnaMenos #AportaOAparta', 5),
#  ('Russian БaZa [ZOV]', 5),
#  ('Patrick Lancaster News Today', 5),
#  ('Libreria Collettiva', 5),
#  ('Vag61', 5),
#  ("rothko's kimono", 5),
#  ('Alessandrian Emporium', 5),
#  ('Brevesdepresse', 5),
#  ('from western woods to beaversdam', 5),
#  ('The 15th International Vore Brigade (18+)', 5),
#  ('Resist Varese e Provincia', 5),
#  ('Escuela de Activismo', 5),
#  ('Caravan of Immortals', 5),
#  ('Collectif Palestine Vaincra', 5),
#  ('USER WAS DIAGNOSED FOR THIS POST', 5),
#  ('Cubainformacion.tv', 5),
#  ('Euro-Med Media (EN-FR)', 5),
#  ('BoltxeZ', 5),
#  ('(trying) healthy adult mode', 5),
#  ('i have internet instead of personality (Morbius strip edition)', 5),
#  ('Jackson Hinkle', 5),
#  ('🇵🇸🏳️\u200d🌈∆̷Ⓐ☭ASCELLE FANCLUB☭Ⓐ∆̷🏳️\u200d🌈🇵🇸', 5),
#  ('Defend the Forest - Atlanta', 5),
#  ('Lefty Bullshit', 5),
#  ('Mundo Multipolar', 5),
#  ('Zoomer Hoomer', 5),
#  ('SENTENTIA', 5),
#  ('Multipolar Market', 5),
#  ('CALP info', 5),
#  ('Humans Of Dystopia', 5),
#  ('Le Peuple Uni', 5),
#  ('Révolution Permanente', 5),
#  ('Anarcho-Alterhumanist Voidpunk Memes And Miscellaneous', 5),
#  ('Público', 5),
#  ('Líneas Rojas', 5),
#  ('Kurdish Front', 5),
#  ('From Russia with Love ❤', 5),
#  ('No_Borders_Team', 5),
#  ('Depresión económica (Economía y finanzas de América Latina y del mundo)',
#   5),
#  ('SolarPunk', 5),
#  ('Force antifasciste lycéenne de lyon', 5),
#  ('Sindicato de Estudiantes', 5),
#  ('Communist Outlaws', 5),
#  ('Embajada de Rusia en Mexico', 5),
#  ('Blockchain is Stupid', 5),
#  ('Ｓａｄ░ｎｏｉｓｅｓ （エッチ）', 5),
#  ('Image en lutte', 5),
#  ("A FORAS - Contra s' Ocupatzione militare de sa Sardigna", 5),
#  ('Chrono Vox - 🇪🇺 🌍', 5),
#  ('Controinforma-ti🏴\u200d☠️', 5),
#  ('Fumettologica', 5),
#  ('Activitats ateneu llibertari de gracia', 5),
#  ('Palestina news', 5),
#  ('Assyria News Network', 4),
#  ('Espada de Jerusalén', 4),
#  ('Clara Statello - Canale Ufficiale', 4),
#  ('فوضى | FAUDA', 4),
#  ('South Africa Reports', 4),
#  ('Kalibrated', 4),
#  ('RT News UNCENSORED (real-time mirror)', 4),
#  ('База from Olga', 4),
#  ('301🇦🇲', 4),
#  ('Hamdy Arnous', 4),
#  ('DiarioOctubre', 4),
#  ('Ventana a Palestina', 4),
#  ('Samidoun Network', 4),
#  (1912350458, 4),
#  ('Pravda ☭ - Contrapropaganda 🌍', 4),
#  ('La Hojilla En TV Mario Silva', 4),
#  ('GERILANAME', 4),
#  ('Le fil d’IO', 4),
#  ('Poder Migrante', 4),
#  ('Comunidad Saker Latinoamérica', 4),
#  ("Brian Berletic's New Atlas Channel", 4),
#  ('نشر افکار', 4),
#  ('UKR LEAKS_eng', 4),
#  ('Data Urgente', 4),
#  ('Aturem el País (Canal Oficial)', 4),
#  ('FAI', 4),
#  ('Зона солидарности', 4),
#  ('Nûçe Ciwan Türkçe', 4),
#  ('7️⃣5️⃣ Urgence Palestine Paris', 4),
#  ('red_irl🇵🇸', 4),
#  ('Strategic Culture Foundation', 4),
#  ('Laura Ru', 4),
#  ('ContrAfake💥BélicAsocial', 4),
#  ('ARAINFO', 4),
#  ('Canarias Se Agota', 4),
#  ('NUEVO ORDEN MUNDIAL', 4),
#  ("Grup d'Habitatge de Sants", 4),
#  ('Gaganauts of Geopolitics', 4),
#  ('International Reporters', 4),
#  ('Best Timeline', 4),
#  ('🔥SPLIT OVUNQUE🔥', 4),
#  ('HubAut Bologna', 4),
#  ('Europe Elects Official', 4),
#  ('La CGT', 4),
#  ('XR España | Extinction Rebellion Spain |', 4),
#  ('Geroman', 4),
#  ('Óscar Reina', 4),
#  ('G.J. Internationale United', 4),
#  ('Hameau agricole de Pontareuse | Les Hirondelles', 4),
#  ('Little Entente', 4),
#  ('𓂆 🇵🇸 Gaza News+🔻', 4),
#  ('Rusia España Ucrania', 4),
#  ('"israel" is a War Criminal 🇵🇸', 4),
#  ('Bad Memes & News by Tank', 4),
#  ('NO ponte sullo Stretto', 4),
#  ('VilaWeb', 4),
#  ('TIMES OF GAZA', 4),
#  ('Tesla stoppen! Infokanal', 4),
#  ('Anarchismus in Dresden', 4),
#  ('Kittyfox Corner', 4),
#  ('Political memes', 4),
#  ('Forum voor Anarchisme Ⓐ', 4),
#  ('Infestazioni News', 4),
#  ('Мама Анархия!', 4),
#  ('Remylind23', 4),
#  ('Samidoun Paris Banlieue', 4),
#  ('Sevilla en Acción', 4),
#  ('feminismo 💜 soft.libre 🗝 tecnología 👩\u200d💻', 4),
#  ('💥 Pulse Z', 4),
#  ('Wartime Media - Ukraine / Russia / China / Etc', 4),
#  ('JOIN @geopolitics_live » official Sputnik International mirror', 4),
#  ("Shaun's Shitpost's", 4),
#  ('Colapso Civilizatorio | Collapse | Effondrement | Col·lapse |', 4),
#  ('Frente del Este', 4),
#  ('UKR LEAKS_esp', 4),
#  ('SAM SYRIA 🇸🇾', 4),
#  ('Alena Rusa \U0001fa86', 4),
#  ('𝑆𝑜𝑛𝑜 𝑛𝑢𝑑𝑜.', 4),
#  ('El Zoom', 4),
#  ('Axe de la Résistance - 🇵🇸 Palestine / Gaza 🇵🇸', 4),
#  ('Literally 1984', 4),
#  ('LiveLeak', 4),
#  ('ANF - Agencia de Noticias Firat', 4),
#  ('RoteJugendDeutschland', 4),
#  ('Граффити без расизма!', 4),
#  ('Llibertat.cat 🎗', 4),
#  ('InfoDefenseITALIA', 4),
#  ('🐻Desinformador ruso👁\u200d🗨', 4),
#  ('CUP Països Catalans', 4),
#  ('Istituto Italia Brics', 4),
#  ('The Western Chauvinist', 4),
#  ('Anarquismosenlibros', 4),
#  ('#MemoriaAnarquista', 4),
#  ('Alexander Dugin', 4),
#  ('Giorgio Bianchi Photojournalist', 4),
#  ('Distri La Polilla', 4),
#  ('Fundación de Cultura Estratégica', 4),
#  ('Sulcis - Iglesiente RIBELLE', 4),
#  ('Song of Oil and LNG', 4),
#  ('HolyMementi', 4),
#  ("Chrys's Coochie Corner", 4),
#  ('ESLA EKO Difusión', 4),
#  ('Tsunami Toulouse', 4),
#  ('Geopolitika en español', 4),
#  ('BURE à cuire !', 4),
#  ('Readovka World', 4),
#  ('Socialist Art', 4),
#  ('History Quote Buff', 4),
#  ('Enlightened Content', 4),
#  ('⏚Printemps du Changement⏚', 4),
#  ("Trenca l'aïllament 🔥 Noticiari rebel 🤜🏼🤛🏾", 4),
#  ('💥BarZad💥', 4),
#  ('EN PLENA LUZ', 4),
#  ('Skinheads Attitude', 4),
#  ('✊️Gilets Jaunes on continue💛', 4),
#  (1944093542, 4),
#  ('Recovered', 4),
#  ('Anarkiviu', 4),
#  (1273142419, 4),
#  ('STOP GREENDOCK Logistique en panique 24soir-25-26 mai', 4),
#  ('Basic Fucking Kindness', 4),
#  ('Crudelia Memon', 4),
#  ('zena.info', 4),
#  ('✳️ Canal Estatal RegularizacionYa', 4),
#  ('Archivio Anarchico "G. Ciavolino" Assemini (CA)', 4),
#  ('Is Henry Kissinger dead yet?', 4),
#  ('ｅｍａｃｓ', 4),
#  ('I Sollevamenti della Terra in Marcia', 4),
#  ('СОЛОВЬЁВ', 4),
#  ('📢 Etica Digitale', 4),
#  ('kermessedesterres_Paris', 4),
#  ('Extrême droite antifa info', 4),
#  ('Russell TEXAS Bentley', 4),
#  ('Luchas Libertarias', 4),
#  ('Attac France - fil infos 📣💥', 4),
#  ('Deutsche Memokratische Republik ☭🇮🇱', 4),
#  ('News from Alan MacLeod', 4),
#  ('Ultras Not Reds', 4),
#  ("Centre Delàs d'Estudis per la Pau", 4),
#  ('Masar Badil News', 4),
#  ('Публичные призывы', 4),
#  ('ResistanceTrench', 4),
#  ("ZOKA's Channel", 4),
#  ('Jazzposting', 4),
#  ('Вільне Рівне', 4),
#  ('La Chispa, Iskra (И́скра) Info Gaza Israel Palestina', 4),
#  ('🔒Seguridad Informática', 4),
#  ('Late Stage Ireland', 4),
#  ('¡PLOMO CONTRA EL SIONISMO!', 4),
#  ('NAIZ', 4),
#  ('Underground Cat', 4),
#  ('r/vexillologycirclejerk', 4),
#  ('🐾🏳️\u200d⚧️ Manic Pubbygirl posting 🏳️\u200d⚧️🐾', 4),
#  ("La Manigua • Revolución Pa' Rato 🇨🇺🇨🇺", 4),
#  (1946385696, 4),
#  ('Insurgencia Urbana Colombia', 4),
#  ('🇧 🇮 🇧 🇱 🇮 🇴 🇹 🇪 🇨 🇦 Manigua Información', 4),
#  ('El Bages pels Drets Civils', 4),
#  ('/r/fuckcars', 4),
#  ('Mediapart RSS (non officiel)', 4),
#  ('Resumen Latinoamericano', 4),
#  ('Max Stirner', 4),
#  ('Trans/NB Memes 🏳️\u200d⚧️', 4),
#  ('No BS kNews', 4),
#  ('Partido Pirata de Chile', 4),
#  ('❗OBSERVADOR MILITAR 🔞', 4),
#  ('Wolfypostaggio', 4),
#  ('Contrainfo', 4),
#  ('Eldritch Blueprints', 4),
#  ('Islamic World News', 4),
#  ("L'Alerta Canal", 4),
#  ("Du Rove's Channel", 4),
#  ('Sulla Breccia', 4),
#  ('Die Druckerei - Info Channel', 4),
#  ('Politically Retro', 4),
#  ("Kingspup's Nonhuman Memehole", 4),
#  ('lundimatin', 4),
#  (1395570775, 4),
#  ('No remorse Iran/Palestina', 3),
#  ('Press TV Shows', 3),
#  ('🇬🇧 SITREP - Independent OSINT Channel 🇬🇧', 3),
#  ('Palestine Declassified', 3),
#  ('Demo Ticker Berlin (English)', 3),
#  ('Multipolare News', 3),
#  ('Archivio Hufeland [Cinema TV Lost Media]', 3),
#  ('China and Geopolitics with Danny Haiphong', 3),
#  ('Osservatorio democratico sulle nuove destre', 3),
#  ('Hêzên Rizgariya Efrînê', 3),
#  (1827178194, 3),
#  ('Ayatollah Khamenei', 3),
#  ('Idee&Azione', 3),
#  ('TOUS UNIS, NOUS VAINCRONS !!!', 3),
#  ('Kurdisches_Zentrum_St.Gallen', 3),
#  ('Military Wave', 3),
#  ('Jaime DQVA Canal Informativo📷📹📡💻📱📺', 3),
#  ('/SCI/ Southern Cross Intelligence -', 3),
#  ('gs 通讯 / guerrilla stickers news', 3),
#  ('The Duran', 3),
#  ('Working Man Memes', 3),
#  ("L'Osservatorio - Esteri", 3),
#  ('Dissident Thoughts', 3),
#  ('Gérvas Salud/Health', 3),
#  ('LR, Geopolitica e News', 3),
#  ('Tokata', 3),
#  ('insurgente.org', 3),
#  ('gs ステッカー禁止 / guerrilla stickers no adesivi grazie', 3),
#  ('BAB MANDEB YEMEN', 3),
#  ('Agora Galiza-Unidade Popular Informa 🚩', 3),
#  ('Antirinfo', 3),
#  ('DiegoEnLaLucha', 3),
#  ('The American Majority', 3),
#  ('Desobediència Civil Catalunya', 3),
#  ('Manicato UArt ] DHML [', 3),
#  ('Ho Visto Joker', 3),
#  ('il Post', 3),
#  ('Foreign Agent Intel', 3),
#  ('SOS Racisme Catalunya', 3),
#  ('חדשות מהשטח בטלגרם Yediot News', 3),
#  ('Military Summary', 3),
#  ('Patriot Front Videos', 3),
#  ('Press TV Français', 3),
#  ('شبکه مردمی حقوق بشر افغانستان', 3),
#  ('Byoblu', 3),
#  ('Geopolitikaz Difusión/Hedapena', 3),
#  ('Russia Beyond', 3),
#  ('MUNDO SAHARAUI - NOTICIAS', 3),
#  ('Inter36', 3),
#  ('σβομπόντα', 3),
#  ("String's18+RapidFireMemes💦", 3),
#  ('War Room - Russia, Ucraina, NATO', 3),
#  ('Yuliana Titaeva / Юлиана Титаева', 3),
#  ('Dipartimento Federale dei Femboy govt election year arc', 3),
#  ('Suriyakmaps', 3),
#  ('SENGER', 3),
#  ('OPERASYON', 3),
#  ('The Grayzone', 3),
#  ('Fuser News', 3),
#  ('Eastern European insider', 3),
#  ('Vi racconto la Russia', 3),
#  ('Convocatòries Barcelona', 3),
#  ('کانالِ خودساماندهیِ مطالبِ گروهِ اتحادیۀ آنارشیست\u200cهای افغانستان و ایران',
#   3),
#  ('Relationship Anarchy India', 3),
#  ('Vincent James', 3),
#  ('Matrioska.info', 3),
#  ('TrackANaziMerc', 3),
#  ('Critical Pedagogy', 3),
#  ('Syriana Analysis', 3),
#  ('NetBlocks', 3),
#  ("CSOA l'Horta", 3),
#  ('Barbie Terrorista', 3),
#  ('Global Dissident', 3),
#  ('Geuzenbond – International', 3),
#  ('Beorn and The Shieldmaiden', 3),
#  ('Canal Marx21 - Andalucía', 3),
#  ('Coalition Stop Embouteillage', 3),
#  (1675024280, 3),
#  ('Soutien aux peuples du Kurdistan', 3),
#  ('Familias Frente a la Crueldad Carcelaria', 3),
#  ('OpenForFuture.org | WEB UPDATES', 3),
#  ('Zigantas 🏴', 3),
#  ('Scott Ritter', 3),
#  ('HPG - Türkçe', 3),
#  ('Exosapiens', 3),
#  ('contraotanybases', 3),
#  ('Revista PPV', 3),
#  ('Bologna for Climate Justice', 3),
#  ('Clash Report', 3),
#  ('Victor vicktop55', 3),
#  ('Partido Sindicalista', 3),
#  ('European Insider', 3),
#  ('Tümpeltown Ticker', 3),
#  ('USF Settore Smaltimento Scorie👁', 3),
#  ('Anarcho Syndicat and shitposting', 3),
#  ('AnarquismosCineteca', 3),
#  ('Se va a armar la Gorda', 3),
#  (2000274936, 3),
#  ('Revolución Obrera', 3),
#  ('FemNosotras♀', 3),
#  ('Liu Sivaya', 3),
#  ('Dissident News', 3),
#  ('CNT-AIT Torrelavega', 3),
#  ('Екологічна Платформа', 3),
#  ('Kuzmenko Blog', 3),
#  ('Sindicat de Llogaters | Canal oficial', 3),
#  ('Info Libera Collina di Castello', 3),
#  ('Geopolitica Sin Censura en España y Latinoamerica', 3),
#  ('La Màquia - Azadî Jin', 3),
#  ('Gemeinschaft der Eigenen', 3),
#  ('Automated Cringe Memetico~ACM', 3),
#  (1867210895, 3),
#  ('Solidarité Palestine BDS Toulouse', 3),
#  ('CUNY Gaza Solidarity Encampment', 3),
#  ('مَدونّافريييدا', 3),
#  ('Demo Ticker Berlin', 3),
#  ('ریتم آنارشی Anarchy rhythm', 3),
#  ('𝗞𝗨𝗥𝗗𝗜𝗦𝗛 𝗥𝗘𝗩𝗢𝗟𝗨𝗧𝗜𝗢𝗡', 3),
#  ('CannabItaly 🇮🇹🍁', 3),
#  ('Fiorella In Moscow', 3),
#  ('Canal Antifasciste - Vigilance Étudiante', 3),
#  ('Antifa United', 3),
#  ('ARGIA', 3),
#  ('CSO Nabat 4 ever', 3),
#  ("Lola's Life Log", 3),
#  ('WYF 2024', 3),
#  ('⸙anachronistic leaves🌿', 3),
#  ('[DIFUSIÓN] AVV El Triángulo', 3),
#  ('Rete Jin Milano✌️', 3),
#  ('RED JURÍDICA Soc. Coop. Mad.', 3),
#  ('CONTRO LE BASI', 3),
#  ('Douglas Macgregor', 3),
#  ('Wald statt Asphalt - Info-Channel 🌳✊', 3),
#  ('Pirates de Catalunya', 3),
#  ('Пряма дія | Незалежна студентська профспілка', 3),
#  ('Always anti-fascist 1161', 3),
#  ('City Strike Info', 3),
#  ('Tiktok Pensante 🧠', 3),
#  ('O.d.E.G. Guerra NATO-RUSSIA', 3),
#  ('\U0001fa77 CANAL CSO LA ROSA \U0001fa77', 3),
#  ('LIVE - Ultimora.net', 3),
#  ('ASF-IWA Info', 3),
#  ('ANTIMILITARISTA', 3),
#  ('Javier Couso', 3),
#  ('World War Now', 3),
#  ('Рыбарь', 3),
#  ('🇵🇸 Brigada Laila Jaled 🇵🇸', 3),
#  ('꧁NOTI✞KAOS꧂', 3),
#  ('Iɴsᴜʙᴏʀᴅɪɴᴀʙʟᴇs', 3),
#  ('Vault of Secrets - Unpopular History', 3),
#  ('The Anarchist Tension by Alfredo M Bonanno', 3),
#  ('La Gaceta Roja de Stalingrado', 3),
#  ('la Red de la Clase Trabayadora', 3),
#  ('Спільне | Commons', 3),
#  ('No! Against Adult Supremacy', 3),
#  ('TelevideoRAI101', 3),
#  ('The National Party │ An Páirtí Náisiúnta', 3),
#  ('Gruppo Tanuki', 3),
#  ('lunar-punk.feed', 3),
#  ('Embajada de Rusia en Cuba', 3),
#  ('Chronicles Of The Conflict', 3),
#  ('🎥 Lа Prимиcя', 3),
#  ('Slavyangrad Analytica ☭', 3),
#  ('Action Radar Europe', 3),
#  ('MUNDO MULTIPOLAR: La Nueva Era', 3),
#  ('Cult of EROI, The Cliff Arrives (peak oil) \U0001fae1🛢', 3),
#  ('Berlin Demos English', 3),
#  ('Только Сами', 3),
#  ('Trainposting', 3),
#  ('Tutti i fatti', 3),
#  ('Regimiento Inmortal España', 3),
#  ('Oddly Motivational', 3),
#  ('capitalism and schizophrenia', 3),
#  ('The Red Society', 3),
#  ('Embajada de Rusia en Argentina - Посольство России в Аргентине', 3),
#  ('Jacobin Italia', 3),
#  ('Grannel Zir0', 3),
#  ('КРАС / CRAS - М.А.Т /AIT / IWA', 3),
#  ('Palestina.Cat', 3),
#  ('Defendamos Kurdistan', 3),
#  ('Wobposting - Chipi Chapa edition', 3),
#  ('Pantopia Reading Nook 📰🚩', 3),
#  ('Mundo en Guerra', 3),
#  ('Russian Diplomat 🅉', 3),
#  ('La Izquierda Diario ✊🏽', 3),
#  ('Bilingual Shitposting - Chilean Based Operations', 3),
#  ('FA Kraków', 3),
#  ('Laboro (No oficial)', 3),
#  ('Fracas', 3),
#  ('CTXT', 3),
#  ('A normal day in Night Vale', 3),
#  ('Middle East Eye', 3),
#  ('RangeloniNews', 3),
#  ('maff’s bad posts garden', 3),
#  ('abstract cybernetic rehabilitation culture', 3),
#  ('Er Talk Channel di Esse, Ross e Melone', 3),
#  ('Desarmons-les! - INFO', 3),
#  ('Edizioni Alegre', 3),
#  ("hours' dumb meme shit", 3),
#  ('Canal #AcampadaPalestinaUV', 3),
#  ('Lotta al passante: Eventi', 3),
#  ('Texas vs U.S.', 3),
#  (1954626378, 3),
#  ('бармалеи/партизаны', 3),
#  ("People's Cyber Army", 3),
#  ('💥 TUNTENHAUS BLEIBT! 👠', 3),
#  ('La guerra en Donbás', 3),
#  ('Muhammad Smiry | GAZA', 3),
#  ('LA VAMPA - Casa Transfemminista Occupata', 3),
#  ('Ateneo Republicano de Vallekas', 3),
#  ('Где Седа?', 3),
#  ('S.I. Cobas - Genova', 3),
#  ('memi tecnosovversiv for ragazzettə agile', 3),
#  ("Architector #4 but it's a channel", 3),
#  ('Untitled Goose Channel', 3),
#  ('Kharkiv Hardcore', 3),
#  ('Fronte della Resistenza al Mondialismo', 3),
#  ('Revdar Milano', 3),
#  ('De Nieuwshoorn', 3),
#  ('memes outta my ass', 3),
#  ('Semión Sénderov', 3),
#  ("Count Inkie's most dignified trash heap", 3),
#  ('Fil info - Laisse Bėton Salvaza 😀❤️🦋✊', 3),
#  ('Con El Mazo Dando', 3),
#  ('FreeAzat!', 3),
#  ('the earth is pregnant with the dead', 3),
#  ('🦅 Aquila 🦅', 3),
#  ('Syndicat Solidaires 📢', 3),
#  ('Alkarama_mmp', 3),
#  ('Bastamag RSS (non officiel)', 3),
#  ('International Workers Association (IWA)', 3),
#  ('Feminismos Madrid', 3),
#  ('CATGIRL PC POL', 3),
#  ('Project161', 3),
#  ('Antifascists of India', 3),
#  ('i hate self commodification i hate self commodification', 3),
#  ("Shroom's All-posting", 3),
#  ('CatHunt', 3),
#  ('Deerposts', 3),
#  ('Planos ADHD Hellhole', 3),
#  ('funniest shit i’ve ever seen', 3),
#  ('Tucker Carlson Network', 3),
#  ('It’s Not an AuDHD Thing', 3),
#  ("Koi's Memetastic Galaxy :3 🌌", 3),
#  ('Il Caffè', 3),
#  ('Котеки, репости і репости котеків', 3),
#  (1363308317, 3),
#  ('Le Média', 3),
#  ('Прамень', 3),
#  ('Pikara Magazine', 3),
#  ('Red ALBA', 3),
#  ('meme tutorial', 3),
#  ('Proudly Pointless', 3),
#  ('Cubadebate', 3),
#  ('Computeristic World (Aesthetics, Lain and Stuff)', 3),
#  ('Cute Happy Stuffs', 3),
#  ('Zluka de Novorusia. ZOV.', 3),
#  ('Les Répliques 🍉', 3),
#  ('Now', 3),
#  ('pupy hell', 3),
#  ('the woman destroyed', 3),
#  ('196', 3),
#  ('CNT-AIT Enseñanza Madrid', 3),
#  ('R&U Videos', 3),
#  ('Cool Guides', 3),
#  ('Non Una Di Meno - Roma', 3),
#  ('Militanza Grafica', 3),
#  ('VivelAnarchie', 2),
#  ('SOTA', 2),
#  ('COPINH', 2),
#  ('Wallachian Gazette', 2),
#  ('🔥 Spicy Steamed Memeballs 🔥', 2),
#  ('Become Ungovernable', 2),
#  ('White Papers', 2),
#  ('Anarchisterie Lilloise Discussion', 2),
#  ('DPR MFA', 2),
#  ('Ares, Information Service', 2),
#  ('✨AlfaNews / اخبار آلفانیوز# ✨Новости Berita Noticias #Nachrichten Nouvelles Notícies Nyheter Nyheter Alterna Notizia #news #News',
#   2),
#  ('HAMAS-ISRAEL WAR', 2),
#  ('Savoir Libre', 2),
#  ('RADICALE', 2),
#  ('Digamos', 2),
#  ('Patriot Front', 2),
#  ('آنارشیست\u200cهای جلال\u200cآباد', 2),
#  ('Ragihandina Ciwanên Şoreşger إعلام الشبيبة الثورية', 2),
#  ('Soheil Arabi_سهیل عربی', 2),
#  ('Herritar Batasuna', 2),
#  ('⚡️War Digital News⚡️', 2),
#  ('EZKERRALDEA ANTIFAXISTA', 2),
#  ('Giuseppe Masala Chili 🌶', 2),
#  ('LUBAKI AGENDA', 2),
#  ('ASTRA', 2),
#  ('La France insoumise', 2),
#  ('La Agencia De Noticias Yemenita SABA', 2),
#  ('Pole Connection', 2),
#  ('InNomineSomnium', 2),
#  ...]

# %%
sorted(list(zip(G.vs['label'],G.vs.indegree())), key=lambda x: x[1], reverse=True)
# Out:
# [('Malditaultraderecha', 389),
#  ('🏴\u200d☠️\U0001f977 Prima Linea 🏴 ⚒️', 341),
#  ('Molotov✊Contra la opresion', 265),
#  ('NI UNA MÁS / Contra el relato', 236),
#  ('SAMU.ZA', 233),
#  ("Antifascist 'Pics&Vids'", 227),
#  ('Antifascist Solidarity', 220),
#  ('©️ʰᵃˡᵉᶜᵒˢⒶᵐᵃʳⁱˡˡᵒˢ™', 214),
#  ('Anticapitalist Surrealism 🇵🇸🔻', 187),
#  ('/CIG/ Telegram | Counter Intelligence Global', 185),
#  ('RéseauGMA (Grève Manifs Actions)', 178),
#  ('Indian Libertarian Socialist Federation', 175),
#  ('DD Geopolitics', 168),
#  ('United Anarchists', 153),
#  ('Sopravvivere al degrado', 153),
#  ('ANTIIMPERIALISTAS', 151),
#  ('Bellum Acta - Intel, Urgent News and Archives', 150),
#  ('Two Majors - English Channel', 146),
#  ('💀🎃 Fully Automated Luxury Lesbian Space Anarcho Communism', 137),
#  ('Pepe Escobar', 129),
#  ('No remorse Iran/Palestina', 115),
#  ("PUNT D'INFLEXIÓ", 114),
#  ('Contropotere 🏴', 111),
#  ('Sevilla Anticarcelaria y Anarquista Ⓐ', 110),
#  ('Zentropa', 101),
#  ('Horny Mementi', 101),
#  ('Tonho', 93),
#  ('neomarksizm 🚩leftist marxist socialist communist and anarchist memes ✊ enjoy comrades (❁´◡`❁)',
#   92),
#  ('Stay Free', 92),
#  ('Lord Bebo & Friends', 91),
#  ("the left can't meme🐳 (🏳️\u200d🌈🏳️\u200d⚧️🇦🇱🇦🇱🇦🇱🇦🇱🇪🇭🇵🇸)", 76),
#  ('Er Cacanale dər Micheletrə', 76),
#  ('🍉 Wesh La Smala 🍉', 68),
#  ('Critical Punkism', 68),
#  ('PRESOS REVOLUCIONARIOS', 64),
#  ('gs 通讯 / guerrilla stickers news', 63),
#  ('REDCOM', 61),
#  ('Giubbe Rosse', 61),
#  ('slow ritornellos', 59),
#  ('Antifa Enternasyonal', 59),
#  ('Kittyfox Corner', 59),
#  ('Boccaccio Lovers 🏴\u200d☠', 59),
#  ('TUTTO SQUAT MILANO', 58),
#  ('𝚁𝚎𝚟𝚘𝚕𝚞𝚌𝚒ó𝚗 𝙲𝚘𝚖𝚞𝚗𝚒𝚜𝚝𝚊☭', 57),
#  ('Socialism Beer', 54),
#  ('Sare Antifaxista Euskal Herria', 53),
#  ('Eventi Incombenti Succulenti Mlmlm', 53),
#  ('Euskal Herria-Donbass Elkartasun Komitea', 52),
#  ('📣 Et La Rue Elle Est À Qui❓', 52),
#  ('Rivoluzione Internazionale', 52),
#  ('USF Settore Smaltimento Scorie👁', 52),
#  ('Andrea Lucidi -Canale ufficiale- Андреа Лучиди -официальный телеграм канал-',
#   51),
#  ('Governo del Cambianiente Channel', 50),
#  ('SOTA', 49),
#  ('🟥 CAPITALISMO ES BARBARIE / antiimperialismo/ solidaridad Palestina', 48),
#  ('Post-Foucault', 48),
#  ('#ComplicidadGlobal🔥', 48),
#  ('Colpo di Tacco', 47),
#  ('AZIONE ANTIFASCISTA ROMA EST', 47),
#  ('Galactocosmic Ontological Disorder', 46),
#  ("Le Père Peinard - L'info libertaire", 44),
#  ('NO 41bis - International Mobilisation', 44),
#  ('RADICALE', 41),
#  ('PUNTO.AR', 40),
#  ('ShamS', 40),
#  ('Черная книга капитализма | ЧКК', 38),
#  ('The Journaltics', 37),
#  ('Al Otro Lado de la frontera de Ucrania', 36),
#  ('Revolução no Curdistão', 35),
#  ('Sardegna Anarchica', 33),
#  ('Contro il nulla che avanza', 33),
#  ('Middle East Spectator', 32),
#  ('Milano Sud Antifascista', 32),
#  ('Resistance News Network', 31),
#  ('C.S.O.A. EX SNIA', 31),
#  ('CNT-AIT MARINA ALTA', 30),
#  ('📣Diffusion Infos Toulouse ⏚', 29),
#  ('@InfoAgitacion', 29),
#  ('Yekîneyên Servanên Efrînê', 29),
#  ('Marcelleria™', 29),
#  ('Become Ungovernable', 27),
#  ('Anarquistas por la Paz.', 27),
#  ('АнархоСъпротива', 27),
#  ('ﷺIMAMAT_SANSARA☸️', 27),
#  ('Geopolítica actual', 26),
#  ('Comitato per il Donbass Antinazista - Notizie sulla guerra in Ucraina', 25),
#  ('IWW', 25),
#  ('G.J. Internationale United', 24),
#  ('CND', 23),
#  ('En lutte contre la métropole 🏴\u200d☠️', 23),
#  ('анархістські меми 🇺🇦', 23),
#  ('Polisportiva Gagarin Teramo', 23),
#  ('Мама Анархия!', 23),
#  ('La Vérité Censurée', 22),
#  ('Samidoun Estado español', 22),
#  ('Carceri in rivolta', 22),
#  ('فدراسیون عصر آنارشيسم / Federation of Anarchism Era', 22),
#  ('International Revolution', 21),
#  ("Canal Difusió de l'A.R.A.", 21),
#  ('Radical Graffiti', 20),
#  ('𝑩𝒂𝒄𝒌𝒍𝒂𝒔𝒉 𝑰𝒏𝒇𝒐 𝑪𝒉𝒂𝒏𝒏𝒆𝒍 🏴', 20),
#  ('ENTRE GUERRAS', 20),
#  ('161 Crew', 20),
#  ('Comitè de Defensa de Represaliades 💪', 20),
#  ('BcnLegends', 20),
#  ('CNT-AIT', 19),
#  ('Rojava Vive * Kollettiva Jiyan', 19),
#  ('Forum voor Anarchisme Ⓐ', 19),
#  ('Osservatorio Repressione', 18),
#  ('Dionysian Anarchism', 18),
#  ('ACAB includes Tankies', 18),
#  ('☠️ PIRATAS.org #Antifascistas', 18),
#  ('Zigantas 🏴', 18),
#  ('CNT-AIT SOV (Madrid)', 17),
#  ('Автономное Действие', 17),
#  ('OPERASYON', 17),
#  ('Dans la rue', 17),
#  ('🌻 mansardaposting', 17),
#  ('Always anti-fascist 1161', 17),
#  ('Via Independència (oficial)', 16),
#  ('#LaResistència🟨🟥🟨🟥🟨🟥🟨🟥🟨', 16),
#  ('⏚Printemps du Changement⏚', 16),
#  ('Tupi Report 🇧🇷', 15),
#  ('RoiLopezRivas', 15),
#  ('Africa Intel', 15),
#  ('Circolo Culturale Anarchico “Gogliardo Fiaschi” — Carrara', 15),
#  ('CGTZonaSur', 15),
#  ('le città sono di chi le abita', 15),
#  ('Интернациональная Революция', 15),
#  ('C̷Y̶P̸H̶E̸R̸P̷U̵N̷K̸', 15),
#  ('🏴 AnarchoMemes 🔥', 15),
#  ('Frontflict 🇵🇸🔻🇱🇧', 14),
#  ('Atlantean "Fascist" Alternative', 14),
#  ('آنارشیست\u200cهای جلال\u200cآباد', 14),
#  ('anarkiddie fuzzy memes', 14),
#  ("Brian Berletic's New Atlas Channel", 14),
#  ('Комітет Спротиву /// Resistance Committee', 14),
#  ('MDS Info', 14),
#  ('Assemblea studentesca contro ogni carcere e cpr - Milano', 14),
#  ('Climate Justice Berlin', 14),
#  ('AnarcoCanal', 14),
#  ('VivelAnarchie', 13),
#  ('OGB Discussion [IDF]', 13),
#  ('Le fil d’IO', 13),
#  ('Brughiere', 13),
#  ('Strike Force #EscalateForGaza', 13),
#  ('Post-Syndiegram 🇵🇸', 12),
#  ('Circolo Anarchico "La Faglia" — Foligno', 12),
#  ('Колективи Солідарності • Solidarity Collectives', 12),
#  ('Aturem el País (Canal Oficial)', 12),
#  ('Desobediència Civil Catalunya', 12),
#  ('Avis de Tempête', 12),
#  ('📢 CSA Can Vies', 12),
#  ('HubAut Bologna', 12),
#  ('Révolution Internationale', 12),
#  ('AnarcoHacking 🖤❤️ 👨\u200d💻✊🏴', 12),
#  ('Genova Antifascista', 12),
#  ('West Burbs Fash Watch', 11),
#  ('Anarchisterie Lilloise', 11),
#  ('Europa Antifa', 11),
#  ('Jardins à Défendre', 11),
#  ('Tesla stoppen! Infokanal', 11),
#  ('MemeⒶrchy', 11),
#  ('Press TV', 10),
#  ('Ragihandina Ciwanên Şoreşger إعلام الشبيبة الثورية', 10),
#  ('The1312Time', 10),
#  ('Intersecta', 10),
#  ('ÈGIDA', 10),
#  ('Alerta Solidària', 10),
#  ('Боец Анархист', 10),
#  ('Anarchist Memes Database', 10),
#  ('Interkiezionale News', 10),
#  ('CALP info', 10),
#  ('VivelAnarchie', 9),
#  ('TECs TERTULIAS EN CUARENTENA', 9),
#  ('Anarchisterie Lilloise Discussion', 9),
#  ('RiseUp4Rojava', 9),
#  ('La France insoumise', 9),
#  ('Rojava Agenda', 9),
#  ('BASTASFRATTI canale #rentstrike', 9),
#  ('Kurdish Cyber Gerîla (KCG)', 9),
#  ('Wu Ming Foundation', 9),
#  ('Граффити без расизма!', 9),
#  ('CSO PEDRO - Padova', 8),
#  ('Antirinfo', 8),
#  ('À bas les CRA (Centres de Rétention Administrative)', 8),
#  ("Grup d'Habitatge de Sants", 8),
#  ('⏚ Le Printemps du CARE, Collectif Autonome Révoltes et Entraide', 8),
#  ('ExLatteria Occupata Genova', 8),
#  ('Antifa United', 8),
#  ('Anarchistisch Libertär FREIE LINKE', 8),
#  ('فوضى | FAUDA', 7),
#  ('Seditionist Distribution', 7),
#  ('GERILANAME', 7),
#  ('CNT AIT 🔴⚫ Murcia & Cartagena', 7),
#  ('Black Mosquito', 7),
#  ('XR España | Extinction Rebellion Spain |', 7),
#  ('Hurriya Info', 7),
#  ('InfoAut', 7),
#  ('Anarchismus in Dresden', 7),
#  ('Aula6Liberata✊🏽🇵🇸', 7),
#  ('XR BCN | eXtinction Rebellion Barcelona', 7),
#  ('Tümpeltown Ticker', 7),
#  ('Antifa Jugendcafé Info🚩🏴', 7),
#  ('Левая История', 7),
#  ('Archivio Hufeland [Cinema TV Lost Media]', 6),
#  ('Osservatorio democratico sulle nuove destre', 6),
#  ('🌵🐗 Groupe local audois des Soulèvements de la terre.', 6),
#  ('Action Urgence Palestine', 6),
#  ('Les ami•es des Soulèvements de la Terre', 6),
#  ('Nouvelles de Palestine', 6),
#  ('Som Antifeixistes ✊', 6),
#  ('7️⃣5️⃣ Urgence Palestine Paris', 6),
#  ('La CGT', 6),
#  ('Infestazioni News', 6),
#  ('Clermont et environs antifascistes', 6),
#  ("ULTIM'ORA 24", 6),
#  ('Song of Oil and LNG', 6),
#  ('CSOA La Kasa Estudi Nou', 6),
#  ('Estudio Insurgencia', 6),
#  ('C.S.O.A. GABRIO', 6),
#  ('Alle zusammen gegen den Faschismus - #riseup4rojava', 5),
#  ('Antifa Street Art 🇵🇸', 5),
#  ('Nuestras casas son trinxeras', 5),
#  ('Bolognesi contro il passante', 5),
#  ('OUTSIDERS.ESP', 5),
#  ('Antudo.info', 5),
#  ('Flying High - Demokanal und Subkultur Bonn', 5),
#  ('La bussola', 5),
#  ('cloud archive', 5),
#  ('La Marmotta 🌲', 5),
#  ('#MemoriaAnarquista', 5),
#  ('Les Insurgés 🚩', 5),
#  ('Visuales libertarios y sociales', 5),
#  ('No Border info 🏴 Calais & more ✨', 5),
#  ('BURE à cuire !', 5),
#  ('Fénéon 2.0', 5),
#  ('Mostly, I Write', 5),
#  ('HispanTV', 4),
#  ('Anarquismo (canal)', 4),
#  ('This Too, Is a Forest', 4),
#  ('Urgence Palestine', 4),
#  ('Antifascist Alerts Naarm (Melbourne)', 4),
#  ('Palestine🇵🇸 - Agenda (Axdlr)', 4),
#  ('Action Palestine France', 4),
#  ('ANIMAL LIBERATION FRONT', 4),
#  ('ARAINFO', 4),
#  ('Comité Local Soulèvements de la Terre Lyon', 4),
#  ('חדשות מהשטח בטלגרם Yediot News', 4),
#  ('feminismo 💜 soft.libre 🗝 tecnología 👩\u200d💻', 4),
#  ('Lyon Révolté', 4),
#  ('Plataforma Antirepressiva de Ponent', 4),
#  ('Exploit Info', 4),
#  ('Bologna for Climate Justice', 4),
#  ('Антифа ру', 4),
#  ('Info Libera Collina di Castello', 4),
#  ('City Strike Info', 4),
#  ('Zaum!', 4),
#  ('Extrême droite antifa info', 4),
#  ('Galipettes Milano', 4),
#  ('Arşîva PKK', 4),
#  ('🗿Mêmes Grand-Parisiens', 4),
#  ('🛣 A69 - CANAL INFO 💥', 3),
#  ('Kurdisches_Zentrum_St.Gallen', 3),
#  ('Asturies Insumisa', 3),
#  ('Comité de soutien aux Soulèvements de Savoie', 3),
#  ('Sas Absolució ✊', 3),
#  ('Youth Writing History', 3),
#  ('Rozbrat', 3),
#  ('GERÎLA INTERNATIONAL', 3),
#  ('آرشیو گاهشمار آنارشیستی', 3),
#  ('SOS Racisme Catalunya', 3),
#  ('PAS DE JO 2024', 3),
#  ("L'Accent", 3),
#  ('🇵🇸 Assemblée internationaliste pour la Palestine 🌐', 3),
#  ('HPG CASTELLANO', 3),
#  ('Toulouse Anti CRA', 3),
#  ('Grondements des Terres', 3),
#  ('Patria Socialista', 3),
#  ('Soutien aux peuples du Kurdistan', 3),
#  ('RoteJugendDeutschland', 3),
#  ('Resist Varese e Provincia', 3),
#  ('Il Tribolo', 3),
#  ('Sulcis - Iglesiente RIBELLE', 3),
#  ('Internacionalna Revolucija', 3),
#  ('𝗞𝗨𝗥𝗗𝗜𝗦𝗛 𝗥𝗘𝗩𝗢𝗟𝗨𝗧𝗜𝗢𝗡', 3),
#  ('Rete Jin Milano✌️', 3),
#  ('INSORGIAMO Bologna 22ottobre', 3),
#  ('Max Freedom', 3),
#  ('Gruppo Tanuki', 3),
#  ('Làbas Bologna', 3),
#  ('КРАС / CRAS - М.А.Т /AIT / IWA', 3),
#  ('Quds News Network', 2),
#  ('OGB Info [IDF]', 2),
#  ('Rete Kurdistan Italia', 2),
#  ('ilrovescio', 2),
#  ('Antifa Squads', 2),
#  ('⏚ Assemblée GJ LYON & Environs ⏚', 2),
#  ('Anti-work quotes', 2),
#  ('Grupo Ruptura', 2),
#  ('Nûçe Ciwan Türkçe', 2),
#  ('YPJ Information', 2),
#  ('🔥SPLIT OVUNQUE🔥', 2),
#  ('Info ZAD A69', 2),
#  ('SDF_PRESS - المركز الإعلامي', 2),
#  ('GNIP', 2),
#  ('NO ponte sullo Stretto', 2),
#  ('σβομπόντα', 2),
#  ('Montpellier Poing Info', 2),
#  ('Off Topic News', 2),
#  ('PianoTerra', 2),
#  ('Libreria Collettiva', 2),
#  ('Coalition Stop Embouteillage', 2),
#  ('Vag61', 2),
#  ('Le Gueuloir', 2),
#  ('LIBERATION OR DEATH Ⓐ', 2),
#  ('Moviments socials', 2),
#  ('CUP Barcelona', 2),
#  ('Telos 🚓🔥', 2),
#  ('Socialist Art', 2),
#  ('L.E.A. Berta Cáceres', 2),
#  ('Revolutionary Toolbox', 2),
#  ("Trenca l'aïllament 🔥 Noticiari rebel 🤜🏼🤛🏾", 2),
#  ('👊 Debunkers', 2),
#  ('Inhabit', 2),
#  ('Black Mojito', 2),
#  ('STOP GREENDOCK Logistique en panique 24soir-25-26 mai', 2),
#  ('NOSTRA CANAL I PALESTINA-GAZA-ISRAEL, NOTICIAS DEL MUNDO, ARTÍCULOS, CURIOSIDADES, ETC',
#   2),
#  ('AZ Hafermarkt', 2),
#  ('Только Сами', 2),
#  ('Contrainfo', 2),
#  ('Radio Onda Rossa', 2),
#  ('ENTERNASYONAL ANTİFA', 2),
#  ('Fischladen', 2),
#  ('fargov', 2),
#  ('Fumettologica', 2),
#  ('ENDFOSSIL_Roma', 2),
#  ('red.', 1),
#  ('CrimethInc. Ex-Workers Collective', 1),
#  ('The Big Pig Channel', 1),
#  ('𝕱𝖗𝖔𝖒 Ⓐ𝖙𝖍𝖊𝖓𝖘 𝖜𝖎𝖙𝖍 𝕻𝖆𝖘𝖘𝖎𝖔𝖓 🏴', 1),
#  ('🇵🇸 Eye on Palestine', 1),
#  ('Nûçe Ciwan Kurmancî', 1),
#  ('Politfacts', 1),
#  ('RÉVOLTE OLYMPIQUE', 1),
#  ('PEUPLE RÉVOLTÉ ✊', 1),
#  ('elsaltodiario.com', 1),
#  ('GruppaOF Official 𝕳', 1),
#  ('Stop Arming Israel - France', 1),
#  ('Radio Blackout 105.250FM', 1),
#  ('LOGOS | Festa della parola', 1),
#  ('Toulouse Insurgée', 1),
#  ('Geoestrategia y Política', 1),
#  ('𓂆 🇵🇸 Gaza News+🔻', 1),
#  ('Otras Italias', 1),
#  ('Asamblea Libertaria Lorca', 1),
#  ('Occupa & Resisti', 1),
#  ('Festival Intersquat en Ile-de-France', 1),
#  ('Le Maximum', 1),
#  ('NVMP (Nazi Video Monitoring Project) Мониторинг видео неонацистских нападений',
#   1),
#  ('🟥🟨🟪 Documentales de Memoria Histórica', 1),
#  ('𝑨𝒏𝒕𝒊𝒇𝒂𝒔𝒄𝒊𝒔𝒕𝒂𝒔', 1),
#  ('FemNosotras♀', 1),
#  ('End Fossil Pisa UNIPI', 1),
#  ('HUNT SABS 🦊🛠️', 1),
#  ('CannabItaly 🇮🇹🍁', 1),
#  ('Canal Antifasciste - Vigilance Étudiante', 1),
#  ('SENTENTIA', 1),
#  ('Info Collettivo di Fabbrica GKN Firenze', 1),
#  ('I Sollevamenti della Terra in Marcia', 1),
#  ('ImamRezaES', 1),
#  ('📢 Etica Digitale', 1),
#  ('Osservatorio contro militarizzazione scuola', 1),
#  ('Le Peuple Uni', 1),
#  ('Ansa IT - Notizie in Tempo Reale.', 1),
#  ('Jacobin Italia', 1),
#  ('Underground Cat', 1),
#  ('Force antifasciste lycéenne de lyon', 1),
#  ('Antifascist Action Wollongong', 1),
#  ('🎙 RadioForte ⚡️', 1),
#  ('Insurgencia Urbana Colombia', 1),
#  ('DesnonamentsBCN', 1),
#  ("People's Cyber Army", 1),
#  ('Revdar Milano', 1),
#  ('CSA Baraonda', 1),
#  ('Project161', 1),
#  ('Wissam Gaza', 1),
#  ('Monkey Man Sound System', 1),
#  ('Kurdistan solidaarisuus -verkosto Helsinki', 1),
#  ('Updates from Israstine', 1),
#  ('Iene anarchiche', 1),
#  ('Brigata Medium Beer', 1),
#  ('Sally Brown rude-pub', 1),
#  ('Street Coyote', 1),
#  ('Extinction Rebellion Italia', 1),
#  ('INCITO Ⓐ', 1),
#  ('WarZone - News', 0),
#  ('PALESTINA HOY 🇵🇸', 0),
#  ('Al Mayadeen Español', 0),
#  ('Press TV Shows', 0),
#  ('RT en Español (sin censura - real-time mirror)', 0),
#  ('RNN Prisoners', 0),
#  ('Rybar in English', 0),
#  ('🇬🇧 SITREP - Independent OSINT Channel 🇬🇧', 0),
#  ('SANA en Español🇸🇾', 0),
#  ('Lebanese News and Updates', 0),
#  ('Assyria News Network', 0),
#  ('Palestine Declassified', 0),
#  ("Lacan's Whore House", 0),
#  ('Espada de Jerusalén', 0),
#  ('Geopolitics Live', 0),
#  ('🇦🇺AussieCossack🇷🇺', 0),
#  ('/r/latestagecapitalism', 0),
#  ('Выборы, всем ЦЫК!', 0),
#  ('Agencia El Vigía', 0),
#  ('Anonyme Citoyen', 0),
#  ('Los Sombreros Blancos [Z]', 0),
#  ('Clara Statello - Canale Ufficiale', 0),
#  ('War Noir', 0),
#  ('Rise of the Global South', 0),
#  ('حركة فوضى | الوحدة التنفيذية والتعليمية', 0),
#  ('Antiwork', 0),
#  ('Sputnik Mundo (sin censura) real-time mirror', 0),
#  (1195125468, 0),
#  ('🇻🇪Venezuela News Network | Intel, Urgent News and Archives |Wild times in Venekistan 3.5 edition',
#   0),
#  ('Kaosenlared', 0),
#  ('The Islander', 0),
#  ('JugendInfo', 0),
#  ('Fearless John - @European_dissident', 0),
#  ('Anarchist Stickers Archive', 0),
#  ('Ayatolá Jameneí', 0),
#  ('mpr21.info', 0),
#  ('Marwa Osman--MidEaStream', 0),
#  ('Demo Ticker Berlin (English)', 0),
#  ('ResistanceTrench mirror', 0),
#  ('Multipolare News', 0),
#  (1891165770, 0),
#  ('Kurdish Front News', 0),
#  ('Yıldız Teşkilatı Haber', 0),
#  ('Rerum Novarum // Intelligence, Breaking News, and Alerts', 0),
#  ('LON - I Memes di Benjamin', 0),
#  ('Levant Observer', 0),
#  ('Donbass italia', 0),
#  ('COPINH', 0),
#  ('ANRed noticias', 0),
#  ('MV', 0),
#  ('Intel Slava Z', 0),
#  ('Really cool memes actually', 0),
#  ('Russian MFA 🇷🇺', 0),
#  ('QVINTA ÆTAS', 0),
#  ('Fotone - Il ragazzo dal futuro [Tv-Sigle-Cartoni-Video-Audio]', 0),
#  ('🇷🇺LEVI🇧🇾', 0),
#  ('Irina 🇷🇺', 0),
#  ('IRNA Español', 0),
#  ('Anti-Imperialist Front', 0),
#  ('South Africa Reports', 0),
#  ('Wallachian Gazette', 0),
#  ('LoQueSomosWeb', 0),
#  ('CasaPound Italia ufficiale', 0),
#  ('IROP 🇵🇰', 0),
#  ("South Africa's violence project", 0),
#  ('🔥 Spicy Steamed Memeballs 🔥', 0),
#  ('Kalibrated', 0),
#  ('White Papers', 0),
#  ('RT News UNCENSORED (real-time mirror)', 0),
#  ('South Africa, future of the West 🇿🇦', 0),
#  ('Pinch Klub', 0),
#  ('China and Geopolitics with Danny Haiphong', 0),
#  ('What, when, where, why, and how?', 0),
#  ('HispanTV Producción', 0),
#  ('Plataforma Antirepressiva de Barcelona #PAB', 0),
#  ('Manu Pineda🔻', 0),
#  ('База from Olga', 0),
#  ('RIFONDAZIONE COMUNISTA LOMBARDIA', 0),
#  ('Spanish Revolution', 0),
#  ('Sard TV Retrò 📼 📺🦩', 0),
#  ('AASIB.ORG', 0),
#  ('Slavyangrad', 0),
#  ('/r/COMPLETEANARCHY', 0),
#  ('BULTZAKA', 0),
#  ('InfoDefenseENGLISH', 0),
#  ('Post-Shitposting (ZHIN-ZHIAN-AZADI: Show Must Go On! edition)', 0),
#  ('SYDNEY CRIMINAL LAWYERS', 0),
#  ('301🇦🇲', 0),
#  ('Wofnon', 0),
#  ('DPR MFA', 0),
#  ('Hamdy Arnous', 0),
#  ('The Cradle', 0),
#  ('Ucraniando', 0),
#  ('teleSURtv', 0),
#  ('Ares, Information Service', 0),
#  ('Docuplanet x Artel.doc', 0),
#  ('Kurdistán', 0),
#  ('Intel Republic', 0),
#  ("Putinger's Cat / Кот Путингера", 0),
#  ('DiarioOctubre', 0),
#  ('✨AlfaNews / اخبار آلفانیوز# ✨Новости Berita Noticias #Nachrichten Nouvelles Notícies Nyheter Nyheter Alterna Notizia #news #News',
#   0),
#  ('Ventana a Palestina', 0),
#  ('HAMAS-ISRAEL WAR', 0),
#  ('Hêzên Rizgariya Efrînê', 0),
#  ('El Ojo 👁 Noticias sobre Israel, Palestina, Rusia, Ucrania, China, Estados Unidos, Irán, México, Ecuador | Política | Guerras',
#   0),
#  ('Savoir Libre', 0),
#  ('Simurgh News Network', 0),
#  (1827178194, 0),
#  ('DAViD.cu', 0),
#  ('Digamos', 0),
#  ('Ayatollah Khamenei', 0),
#  ('BLVCK PVPER', 0),
#  ('P(r)ettyposting 💖🍉', 0),
#  ('elnacionalcat', 0),
#  ('Patriot Front', 0),
#  (1723040893, 0),
#  ('Academia Christiana', 0),
#  ('Sputnik Africa', 0),
#  ('Samidoun Network', 0),
#  (1912350458, 0),
#  ('Pravda ☭ - Contrapropaganda 🌍', 0),
#  ('La Hojilla En TV Mario Silva', 0),
#  ('Idee&Azione', 0),
#  ('TOUS UNIS, NOUS VAINCRONS !!!', 0),
#  ('Soheil Arabi_سهیل عربی', 0),
#  ('¡Ahí les va!', 0),
#  ('War Monitor', 0),
#  ('Gerîla TV', 0),
#  ('Hezbollah v.s. Israel - 2023,2024', 0),
#  ('Futuro Vegetal 🧯', 0),
#  ('Ukraine Watch', 0),
#  ('Global Intel Watch', 0),
#  ('Herritar Batasuna', 0),
#  ('⚡️War Digital News⚡️', 0),
#  ('EZKERRALDEA ANTIFAXISTA', 0),
#  ('Giuseppe Masala Chili 🌶', 0),
#  ('Keith Woods', 0),
#  ('Disclose.tv', 0),
#  ('VideoCloud', 0),
#  ('CCRuWu', 0),
#  ('LUBAKI AGENDA', 0),
#  ('YPJ MEDIA CENTER', 0),
#  ('FelipeChannel #FreeAssange', 0),
#  ('Fotros Resistance (AryJeay)', 0),
#  ('Actualités de Jérôme Legavre', 0),
#  ('World Pravda', 0),
#  ('Mapuche Info', 0),
#  ("L'AntiDiplomatico", 0),
#  ('Eurasia & Multipolarity', 0),
#  ('ASTRA', 0),
#  ('Maroela Media Nuus', 0),
#  ('Roy - الحرب الثالثة', 0),
#  ('The Rice Furnace', 0),
#  ('Marco Cosentino', 0),
#  ('Cronache Ribelli', 0),
#  ('Madre Russia (canale ufficiale)', 0),
#  ('Begumpura: bahujan antifascism', 0),
#  ('GruppaOF Pyro', 0),
#  ('Press TV Doc', 0),
#  ('Military Wave', 0),
#  ('Poder Migrante', 0),
#  ('Failures of Capitalism', 0),
#  ('Comunidad Saker Latinoamérica', 0),
#  ('Hidden Files', 0),
#  ('Global Project', 0),
#  ('La Agencia De Noticias Yemenita SABA', 0),
#  ('MilitaryPOV', 0),
#  ('NEW WORLD ORDYR ٣١٣', 0),
#  ('Jaime DQVA Canal Informativo📷📹📡💻📱📺', 0),
#  ('Pole Connection', 0),
#  ('Sturm und Meme', 0),
#  ('InNomineSomnium', 0),
#  ('صدى الشباب', 0),
#  ('/SCI/ Southern Cross Intelligence -', 0),
#  ('Victor Ternovsky', 0),
#  ('Believe In Syria - Axis Of Resistance', 0),
#  ('@SalamancaAntinuclear', 0),
#  ('Ultimora.net - POLITICS 24', 0),
#  ('Irina Socolova', 0),
#  ('Lyon Insurrection', 0),
#  ('Vanguard Britannica', 0),
#  ('نشر افکار', 0),
#  ('The Duran', 0),
#  ('Movimiento Antirrepresivo de Madrid', 0),
#  ('Working Man Memes', 0),
#  ('UKR LEAKS_eng', 0),
#  ('L’Eco del Nord', 0),
#  ('SouthFront: Analysis & Intelligence', 0),
#  ('Saker Italia', 0),
#  ('Riotlibro', 0),
#  ('301Military', 0),
#  ('ОВД-Инфо', 0),
#  ('NATO eta EBren aurkako Herri Ekimena', 0),
#  ('Alerta Gorria Irratia', 0),
#  ("L'Osservatorio - Esteri", 0),
#  ('Demographics Now and Then', 0),
#  ('Dissident Thoughts', 0),
#  ("Enby pirate's depressed and horny memes and unrelated mischievous stuff",
#   0),
#  ('Gérvas Salud/Health', 0),
#  ('LR, Geopolitica e News', 0),
#  ('Intel Bulls', 0),
#  ('ʀᴇᴊᴇᴄᴛ ᴍᴇᴅɪᴀ', 0),
#  ('Vakulinchuk', 0),
#  ('🇵🇸 Canal BDS País Valencià', 0),
#  ('Tokata', 0),
#  ('insurgente.org', 0),
#  ('Data Urgente', 0),
#  ('Die Vrou as Patriot', 0),
#  ('InfoDefenseESPAÑOL', 0),
#  ('Popular University 4 Gaza', 0),
#  ('gs ステッカー禁止 / guerrilla stickers no adesivi grazie', 0),
#  ('Lesbian Schizo Bar 🍉', 0),
#  (1191128783, 0),
#  ('BAB MANDEB YEMEN', 0),
#  ('Mediterranean Man', 0),
#  ('Resistance Music & Media', 0),
#  ('FAI', 0),
#  ('El Necio', 0),
#  ('Agora Galiza-Unidade Popular Informa 🚩', 0),
#  ('Blocco Studentesco', 0),
#  ('Nuevos paradigmas', 0),
#  ('EFRÎN TV', 0),
#  ('DiegoEnLaLucha', 0),
#  ('Todo Por Hacer', 0),
#  ('Зона солидарности', 0),
#  ('OPAL 🇨🇱', 0),
#  ('Blocco Studentesco Roma', 0),
#  ('Bittereinders Nasionaal', 0),
#  ('Nicholas J. Fuentes', 0),
#  ('World military news', 0),
#  ('BDZNafarroa', 0),
#  ('A Toda Potencia', 0),
#  ('Cancillería de Rusia', 0),
#  ('The American Majority', 0),
#  ('BRIGATE BENSON', 0),
#  ('VIDEOTECA OUTSIDERS', 0),
#  ('The Real Politick with Mark Sleboda', 0),
#  ('Jean-Eudes Gannat', 0),
#  ('elInternacionalista', 0),
#  ('Martina Pastorelli', 0),
#  ('Вот Так', 0),
#  ('EXPOSÉ', 0),
#  ('Tewie Wessels', 0),
#  ('H.I.J.O.S. Capital', 0),
#  ('Canciones Protesta', 0),
#  ('Nación Andaluza', 0),
#  ('El Informante Universal', 0),
#  ('Eureka news', 0),
#  ('Guerras & Geopolitica🚀🔥', 0),
#  ('Saccage 2024', 0),
#  ('Можем объяснить', 0),
#  (1516578446, 0),
#  ('Movimiento #FreeAlexSaab 🇻🇪', 0),
#  ('Manicato UArt ] DHML [', 0),
#  ('RedFICP Bolivarianos', 0),
#  ('red_irl🇵🇸', 0),
#  ('Strategic Culture Foundation', 0),
#  ('Acaposting :3', 0),
#  ('Первый отдел', 0),
#  ('Josef stern💪 informazioni libere.', 0),
#  ('Ho Visto Joker', 0),
#  ('Laura Ru', 0),
#  ('ContrAfake💥BélicAsocial', 0),
#  ('Radio Monotes', 0),
#  ('Люди Байкала', 0),
#  ('lean mean tiger team machine: Sopping Fucking Wet Edition', 0),
#  ('Canarias Se Agota', 0),
#  ('il Post', 0),
#  ('NUEVO ORDEN MUNDIAL', 0),
#  ('Repubblica Araba di Siria 🇸🇾', 0),
#  ('Foreign Agent Intel', 0),
#  ('Gaganauts of Geopolitics', 0),
#  ('YJA STAR', 0),
#  ('تاریخ طبقه کارگر', 0),
#  ('Difusión CNT-AIT Granada', 0),
#  ('CGT Madrid Castilla la Mancha y Extremadura', 0),
#  ('International Reporters', 0),
#  ('Insight', 0),
#  ('Clar i Català Expressions catalanes, adhesius, mems, preguntes...', 0),
#  ('Vanessa Beeley', 0),
#  ('Anarchy, Love and Memes', 0),
#  ('Patriot Front Sightings', 0),
#  ('Best Timeline', 0),
#  ('canale di fiums', 0),
#  ('/r/Mapporn', 0),
#  ('Europe Elects Official', 0),
#  ('/tmp/', 0),
#  ('Resumiendo', 0),
#  ('Helena Villar', 0),
#  ('Military Summary', 0),
#  ('Patriot Front Videos', 0),
#  ('Press TV Français', 0),
#  ('شبکه مردمی حقوق بشر افغانستان', 0),
#  ('⚔️ jim "NUSSY" roberts ⚔️', 0),
#  ('🗞ONGI ETORRI ERREFUXIATUAK Bizkaia', 0),
#  ('المقاتل وسيم عيسى🔻', 0),
#  ('Global Resistance News', 0),
#  ('Descifrando la Guerra', 0),
#  ("Radio Onda D'Urto", 0),
#  ('Kinism', 0),
#  ('UD CGT Nord', 0),
#  ('Join the new channel https://t.me/Geostratinsignt1', 0),
#  ('Warfront Lens', 0),
#  ('Nouveau Présent', 0),
#  ('infoChiapas MediosLibres', 0),
#  ('Radio Tirso Libertaria', 0),
#  ('RIOT DOGS', 0),
#  ('Geroman', 0),
#  ('Byoblu', 0),
#  ('POPULAR FRONT', 0),
#  ("L'Indipendente", 0),
#  ('To the left and beyond (we love big rodents)', 0),
#  ('Lettera da Mosca', 0),
#  ('Resistance Channel', 0),
#  ('Treadn’t', 0),
#  ('Meridiana Resisteix Notícies 🎗️', 0),
#  ('Rapports de force - info', 0),
#  ('Geopolitikaz Difusión/Hedapena', 0),
#  ('HORNYPOSTING 🤤', 0),
#  ('Óscar Reina', 0),
#  ('Observatorio Libertario de Conflictos Armados', 0),
#  ('Red Door Reports', 0),
#  ('The Children of Gaza', 0),
#  ('Sobhfestival', 0),
#  ('Almasirah English', 0),
#  ('Russia Beyond', 0),
#  ('MUNDO SAHARAUI - NOTICIAS', 0),
#  ('Inter36', 0),
#  ('Collettivo Shaoshan - Notizie sulla Cina 🇨🇳', 0),
#  ('Heil Ukraine', 0),
#  ('Ji bo bîranîna Şehîdan', 0),
#  ('Hameau agricole de Pontareuse | Les Hirondelles', 0),
#  ('Irídia - Drets Humans', 0),
#  ('Dialectic', 0),
#  ('Little Entente', 0),
#  ('Dal Popolo italiano con amore', 0),
#  ('Al Descubierto Oficial', 0),
#  ('WOLPalestine', 0),
#  (1394845916, 0),
#  ('🔞 Hot goth girl anarcho-shitposting and unsolicited advice 🔞', 0),
#  ('Militant Wire', 0),
#  ('Rusia España Ucrania', 0),
#  ('Des Tours et des Lys', 0),
#  ('Geostrat insight', 0),
#  ('Revolt France', 0),
#  ('"israel" is a War Criminal 🇵🇸', 0),
#  ('IAATA - Information Anti-Autoritaire Toulouse et Alentours', 0),
#  ('Memorial Antifascista', 0),
#  ('Bad Memes & News by Tank', 0),
#  ('Red Voltaire en español', 0),
#  ('Клуб 451', 0),
#  ('[anywhere] Department of Ferrets, Memetics, and Cognitohazards', 0),
#  ('VilaWeb', 0),
#  ('White House Watch', 0),
#  ('Blood Meridian', 0),
#  ("String's18+RapidFireMemes💦", 0),
#  ('Okupa y Resiste', 0),
#  ('Ultimora.net - POLITICS', 0),
#  ('Visione Tv', 0),
#  ('Vampire Six', 0),
#  ('The unique and his peen', 0),
#  ('La Mia Russia', 0),
#  ('CONTRONARRAZIONE', 0),
#  ('TIMES OF GAZA', 0),
#  ('Solidaridad Obrera', 0),
#  ('🇵🇸 Al-Yudur Juventud Palestina', 0),
#  ('Novelum_Carcassonne', 0),
#  ('Tesla den Hahn abdrehen!', 0),
#  ('War Room - Russia, Ucraina, NATO', 0),
#  ('Yuliana Titaeva / Юлиана Титаева', 0),
#  ('آنارشیست\u200cهای کابل', 0),
#  ('CafeRevolution', 0),
#  ('Contre Attaque Actu', 0),
#  ('🤡Congregation of Clussy🤡', 0),
#  ('Joel Davis', 0),
#  ('AGDchan', 0),
#  ('Eva Karene Bartlett, Reality Theories', 0),
#  (2108659107, 0),
#  ('جبهه\u200cی خودکُش\u200cها', 0),
#  ('Dipartimento Federale dei Femboy govt election year arc', 0),
#  ('Suriyakmaps', 0),
#  ('TASS - Agencia rusa de noticias', 0),
#  ('Fundamental Christianity', 0),
#  (1443809874, 0),
#  ('SENGER', 0),
#  ('Political memes', 0),
#  ('Pan-Baltic News Network', 0),
#  ('Afrin Human Rights Observatory', 0),
#  ('[BASED REBOOT] - Blinded by the lights 🚀', 0),
#  ('The Grayzone', 0),
#  ('Geuzenbond', 0),
#  ('Líneas invisibles', 0),
#  ('The Right People Z', 0),
#  ('Der Einzige - Il fronte intellettuale', 0),
#  ("L'insoumission", 0),
#  ('Fuser News', 0),
#  ('Assembleias Abertas Independentistas', 0),
#  ('Eastern European insider', 0),
#  ('Vi racconto la Russia', 0),
#  ('r_iww', 0),
#  (1184107842, 0),
#  ('Convocatòries Barcelona', 0),
#  ('Propaganda Posters', 0),
#  ('✨Альтушки /// Педовки🕷 — Шугейз СМИ', 0),
#  ('Ultramar - Portuguese Africa News and Reports', 0),
#  ('La terza ROMA', 0),
#  ('𝕷𝖊 𝕵𝖔𝖚𝖗𝖓𝖆𝖑 𝖉𝖚 𝖕𝖊𝖚𝖕𝖑𝖊 𝖘𝖞𝖗𝖎𝖊𝖓', 0),
#  ('The Indian Rationalist', 0),
#  ('Columbia Encampment', 0),
#  ('Berri-Otxoak (plataforma contra la exclusión social y por los derechos sociales)',
#   0),
#  ('Mars Infos', 0),
#  ('CNT AIT Sierra de Madrid', 0),
#  ('Normie Pipeline', 0),
#  ('YPG Press Office', 0),
#  ('Deialdiak Nafarroa', 0),
#  ('Il Testimone', 0),
#  ('Lugo por Palestina (Canle difusión)', 0),
#  ('Товарищ АНКОМ 🏴', 0),
#  ('LISTE DES BLOCAGES PAYSANS ⚠️', 0),
#  ('Remylind23', 0),
#  ('«Гроза»', 0),
#  ("Sindicat d'Estudiants dels Països Catalans", 0),
#  ('📇📃Reality Of War🔎📖', 0),
#  ('Ambasciata Russa in Italia/Посольство РФ в Италии', 0),
#  ('Queer, Leftist, AntiFascist Unity', 0),
#  ('Samidoun Paris Banlieue', 0),
#  ('وكالة سوا- أخبار غزة الآن', 0),
#  ('🎙 ALEXIS POULIN 🎙', 0),
#  (1831249479, 0),
#  (1193423105, 0),
#  ('کانالِ خودساماندهیِ مطالبِ گروهِ اتحادیۀ آنارشیست\u200cهای افغانستان و ایران',
#   0),
#  ('Комитет 212', 0),
#  ('Sevilla en Acción', 0),
#  ('CORVELVA', 0),
#  ('Relationship Anarchy India', 0),
#  ('Prospettiva Nevskij', 0),
#  ("Kaze's Beeposting 🐝", 0),
#  ('Flying High Bonn Kalender', 0),
#  ('Institut ILIADE', 0),
#  ('Free Open Source Posthumanism', 0),
#  ('BASTA guerra nel Donbass', 0),
#  ('Vincent James', 0),
#  ('FemiNews ♀#NiUnaMenos #AportaOAparta', 0),
#  ('Helvetia News 🇨🇭', 0),
#  ('Новая вкладка', 0),
#  ('Un ponte tra Italia e Russia', 0),
#  ('Matrioska.info', 0),
#  ('Женский Срок', 0),
#  ('La Marina Plaza', 0),
#  ('Eastasia Intel', 0),
#  ('TrackANaziMerc', 0),
#  ('ColdHackers CmG-TeaM', 0),
#  ('Gaza Genocide (Breaking News)', 0),
#  ('Samurái de Occidente', 0),
#  ('Wayka', 0),
#  ('PACMA', 0),
#  ('Goth memes', 0),
#  ('Imperium Press', 0),
#  ('A.P.E.', 0),
#  ('New Right News', 0),
#  ('ASIANOMICS', 0),
#  ('World Affairs Blog', 0),
#  ('آنارشیست\u200cهای مزار شریف', 0),
#  ('Critical Pedagogy', 0),
#  ('Thuletide', 0),
#  ('Countermeasures to the Capitalist Threat', 0),
#  (1508459547, 0),
#  ('💥 Pulse Z', 0),
#  ('🎓 TIL - Today I Learned but no 🐝', 0),
#  (2082224197, 0),
#  ('Psychosis den🔞', 0),
#  ('End Time Report', 0),
#  ('Syriana Analysis', 0),
#  ('🏴\u200d☠️ Canal Natio', 0),
#  ('La Directa', 0),
#  ('دادخواهانِ دربند', 0),
#  (1924128873, 0),
#  ('Russian БaZa [ZOV]', 0),
#  ('Carmen Parejo', 0),
#  (2059856127, 0),
#  ('𝐬𝐧𝐞𝐤 𝐩𝐢𝐭', 0),
#  ('3️⃣3️⃣3️⃣', 0),
#  ('NetBlocks', 0),
#  ('Wartime Media - Ukraine / Russia / China / Etc', 0),
#  ('FotoSoheil_RB', 0),
#  ('CNT AIT GIJÓN / XIXÓN', 0),
#  ('Кризисная группа СК SOS', 0),
#  ("CSOA l'Horta", 0),
#  ('Sahel Intel', 0),
#  (1622311519, 0),
#  ('JOIN @geopolitics_live » official Sputnik International mirror', 0),
#  ('Barbie Terrorista', 0),
#  ('Global Dissident', 0),
#  ('Symptoms', 0),
#  ('L’Altra Faccia dell’Impero', 0),
#  ('BECCAPOSTAGGIO', 0),
#  ('AhotsaInfo Bideoak', 0),
#  ('Geuzenbond – International', 0),
#  ('Farm Crime Updates', 0),
#  ('Partido Obrero Reunificado', 0),
#  ('Protestant Post', 0),
#  ('OPERASYON (Yedek)', 0),
#  ('Vivaia TFQ', 0),
#  ('Beorn and The Shieldmaiden', 0),
#  ('Frente Oriental', 0),
#  ("Eta's stolen memes 'n' queer stuff (personal art not included)", 0),
#  ('Diets Collectief', 0),
#  ('Canal Marx21 - Andalucía', 0),
#  ("Shaun's Shitpost's", 0),
#  ('Chupacabra Kennel', 0),
#  ('Colapso Civilizatorio | Collapse | Effondrement | Col·lapse |', 0),
#  ('Frente del Este', 0),
#  ('YBŞ Press Office', 0),
#  ('Aquila Popularis', 0),
#  ('DD Geopolitics Español', 0),
#  ('Patrick Lancaster News Today', 0),
#  ('آنارشيستهاي اصفهان و شاهين شهر', 0),
#  ('Bunarium', 0),
#  ('𝗖𝗢𝗠𝗨𝗡𝗜𝗗𝗔𝗗 𝗜𝗗𝗘𝗡𝗧𝗜𝗧𝗔𝗦', 0),
#  ('𝕋rue 𝔸narchy', 0),
#  ('Xynchannel', 0),
#  ('ДНР INFO 🇷🇺', 0),
#  ('حسن اصليح (صحفي)', 0),
#  ('UKR LEAKS_esp', 0),
#  ('XR Madrid | Rebelión O Extinción Madrid', 0),
#  ('🖱🌐EDIT🔘RÆs', 0),
#  ('حركة فوضى | الوحدة الإعلامية', 0),
#  ('SAM SYRIA 🇸🇾', 0),
#  (1675024280, 0),
#  ('Resistenza su tela Федерика Васселли', 0),
#  ('Drugstore & Potse Infochannel', 0),
#  ('strange archive', 0),
#  ('Alena Rusa \U0001fa86', 0),
#  (1465667929, 0),
#  ('Zic.it | Zeroincondotta', 0),
#  ('ЗеРада', 0),
#  ('𝑆𝑜𝑛𝑜 𝑛𝑢𝑑𝑜.', 0),
#  ('Canal de Noticias: Angula Berria', 0),
#  ('حركة فوضى | الوحدة التعليمية والتنفيذية', 0),
#  ('Рудой', 0),
#  ("Anna's Archive", 0),
#  ('Sementes Revolucionárias', 0),
#  ('Países no alineados', 0),
#  ('Опыт свободы', 0),
#  ('El Zoom', 0),
#  ('Anarcho Krant', 0),
#  ('Axe de la Résistance - 🇵🇸 Palestine / Gaza 🇵🇸', 0),
#  ('commune.info', 0),
#  ('secicredinotizie', 0),
#  ("rothko's kimono", 0),
#  ('Ministry of Doubleplusgood Dope 2️⃣➕😊', 0),
#  ('ROKOT | TORMENTA', 0),
#  ('Katehon', 0),
#  ('Голос арабов | صوت العرب', 0),
#  ('Inessa S ️️', 0),
#  ('Literally 1984', 0),
#  ('Rojnews Türkçe', 0),
#  ('Alessandrian Emporium', 0),
#  ('Filmkunstkollektiv', 0),
#  ('LiveLeak', 0),
#  ('Brevesdepresse', 0),
#  ('Центр Мемориал', 0),
#  ('Les Téméraires 🍇', 0),
#  ('محمود الشريف', 0),
#  ('Solidarité Identités', 0),
#  ('Familias Frente a la Crueldad Carcelaria', 0),
#  ('ANF - Agencia de Noticias Firat', 0),
#  ('Служба поддержки', 0),
#  (1659816199, 0),
#  ('Seek Truth From Facts', 0),
#  ('Radio Spore', 0),
#  ('OpenForFuture.org | WEB UPDATES', 0),
#  ('Unapologetically Ї ✙ \U0001fae1', 0),
#  ('Ali Reza Panahian🇵🇸', 0),
#  ('/GBG/ - Greek Borders General', 0),
#  ('🇮🇪The Irishman in Russia 🇷🇺', 0),
#  ('T-Invariant: действует в интересах своих читателей', 0),
#  ('Convocatorias Descentralizadas', 0),
#  ('Ticino-Palestina🇵🇸Coordinamento unitario a sostegno della Palestina', 0),
#  ('CNT-SO', 0),
#  ('from western woods to beaversdam', 0),
#  ('Incel Slava Z', 0),
#  ('Info e news Palestina', 0),
#  ('Пул N3', 0),
#  ('Les Bourguignons de Belgique', 0),
#  ('The 15th International Vore Brigade (18+)', 0),
#  ('ДумаБинго', 0),
#  ('Scott Ritter', 0),
#  ('Голос анархистов | La Voĉo de Anarkiistoj🚩🏴', 0),
#  ('Dries Van Langenhove', 0),
#  ('ARCAPACIS', 0),
#  ('Llibertat.cat 🎗', 0),
#  ('Il Primato Nazionale', 0),
#  ('InfoDefenseITALIA', 0),
#  (1113648725, 0),
#  ('алло, макрон', 0),
#  ('International', 0),
#  ('MANIFESTACTIONS', 0),
#  ('Blocco Studentesco Sardegna', 0),
#  ('🐻Desinformador ruso👁\u200d🗨', 0),
#  ('Arbiter, My Beloved', 0),
#  ('Da Sud a Nord - Voci per la giustizia climatica', 0),
#  ('Voluntarist Memes', 0),
#  ('Sistema 161 / Últimas noticias💥', 0),
#  ...]

# %% [markdown]
# # Let's filter for only links over 1

# %%
edgelist_filtered = edgelist[edgelist['count']>1]

# %%
## load it into igraph
G = ig.Graph.TupleList(edgelist_filtered.itertuples(index=False), directed=True, weights=True)

# %%
## community detection
communities = G.as_undirected().community_leiden(objective_function="modularity")

## add community as node label
G.vs['community'] = communities.membership

# %%
G.vs['label'] = list(map(lambda x: id_to_names_int.get(x,x),G.vs['name']))
G.vs['desc'] = list(map(lambda x: id_to_desc_int.get(x,x),G.vs['name']))

# %%
Sigma(G, node_size=G.degree(mode='out'),
      node_color=G.vs['community'], 
      hide_edges_on_move=True,
      node_color_gradient='Viridis', node_label=G.vs['label'],
     layout_settings = {"barnesHutOptimize":False,
                       'gravity': 0.1})
# Out:
# Sigma(ig.Graph with 2,047 nodes and 4,122 edges)

# %%
max(communities.membership)
#23 communities
# Out:
# 23

# %%
dict_degree = Counter(G.degree())
dict_degree_in = Counter(G.indegree())
dict_degree_out = Counter(G.outdegree())

# %%
plt.scatter(dict_degree.keys(), dict_degree.values())
plt.xscale('log')
plt.yscale('log')
plt.title('Degree distribution (total degree)')
plt.show()

# %%
plt.scatter(dict_degree_in.keys(), dict_degree_in.values())
plt.xscale('log')
plt.yscale('log')
plt.title('Indegree distribution')
plt.show()

# %%
plt.scatter(dict_degree_out.keys(), dict_degree_out.values())
plt.xscale('log')
plt.yscale('log')
plt.title('Outdegree distribution')
plt.show()
