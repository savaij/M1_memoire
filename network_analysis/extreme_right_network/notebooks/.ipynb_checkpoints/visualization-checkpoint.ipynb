# %%
import pandas as pd
import igraph as ig
from ipysigma import Sigma
import glob
import json
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt

# %%
edgelist = pd.DataFrame(columns=['forward_from','forward_to','count'])

for path in glob.glob('../*_edgelist/*edgelist*.csv'):
    df = pd.read_csv(path)
    edgelist = pd.concat([edgelist,df])

# %%
## load it into igraph
G = ig.Graph.TupleList(edgelist.itertuples(index=False), directed=True, weights=True)

# %%
## community detection
communities = G.as_undirected().community_leiden(objective_function="modularity")

## add community as node label
G.vs['community'] = communities.membership

# %%
with open('../dictionaires/id_to_desc.json') as file_desc,\
    open('../dictionaires/id_to_names.json') as file_names:
    id_to_desc = json.load(file_desc)
    id_to_names = json.load(file_names)

# %%
id_to_names_int = dict(map(lambda x: (int(x[0]),x[1]), id_to_names.items()))
id_to_desc_int = dict(map(lambda x: (int(x[0]),x[1]), id_to_desc.items()))

# %%
G.vs['label'] = list(map(lambda x: id_to_names_int.get(x,x),G.vs['name']))
G.vs['desc'] = list(map(lambda x: id_to_desc_int.get(x,x),G.vs['name']))

# %%
Sigma(G, node_size=G.degree(mode='out'),
      node_color=G.vs['community'], 
      hide_edges_on_move=True,
      node_color_gradient='Viridis', node_label=G.vs['label'],
     layout_settings = {"barnesHutOptimize":False,
                       'gravity': 0.1})
# Out:
# Sigma(ig.Graph with 3,636 nodes and 7,708 edges)

# %%
max(communities.membership)
#eleven communities
# Out:
# 10

# %%
dict_degree = Counter(G.degree())
dict_degree_in = Counter(G.indegree())
dict_degree_out = Counter(G.outdegree())

# %%
plt.scatter(dict_degree.keys(), dict_degree.values())
plt.xscale('log')
plt.yscale('log')
plt.title('Degree distribution (total degree)')
plt.show()

# %%
plt.scatter(dict_degree_in.keys(), dict_degree_in.values())
plt.xscale('log')
plt.yscale('log')
plt.title('Indegree distribution')
plt.show()

# %%
plt.scatter(dict_degree_out.keys(), dict_degree_out.values())
plt.xscale('log')
plt.yscale('log')
plt.title('Outdegree distribution')
plt.show()

# %%
sorted(list(zip(G.vs['label'],G.vs.outdegree())), key=lambda x: x[1], reverse=True)
# Out:
# [("ULTIM'ORA 24", 30),
#  ('La terza ROMA', 28),
#  ('Comitato per il Donbass Antinazista - Notizie sulla guerra in Ucraina', 27),
#  ('Andrea Lucidi -Canale ufficiale- Андреа Лучиди -официальный телеграм канал-',
#   27),
#  ("L'AntiDiplomatico", 27),
#  ('Donbass italia', 26),
#  ('InfoDefenseITALIA', 25),
#  ('Clara Statello - Canale Ufficiale', 25),
#  ('Giubbe Rosse', 23),
#  ('Giuseppe Masala Chili 🌶', 23),
#  ('LR, Geopolitica e News', 23),
#  ('Vi racconto la Russia', 22),
#  ('Saker Italia', 22),
#  ('Ambasciata Russa in Italia/Посольство РФ в Италии', 22),
#  ('Intel Slava Z', 22),
#  ('Giorgio Bianchi Photojournalist', 21),
#  ('Lettera da Mosca', 21),
#  ('La Mia Russia', 20),
#  ('LIVE - Ultimora.net', 20),
#  ('Multipolare News', 20),
#  ('RangeloniNews', 20),
#  ('Ultimora.net - POLITICS 24', 20),
#  ('Breaking News - Ultimora.net', 20),
#  ('Laura Ru', 19),
#  ('Byoblu', 19),
#  ('𝑆𝑜𝑛𝑜 𝑛𝑢𝑑𝑜.', 19),
#  ('O.d.E.G. Guerra NATO-RUSSIA', 18),
#  ('Tutti i fatti', 18),
#  ('Un ponte tra Italia e Russia', 18),
#  ('Fiorangela, canale pubblico.', 17),
#  ('Francesca Quibla, sono il tuo sogno eretico.', 17),
#  ('War Room - Russia, Ucraina, NATO', 16),
#  ('Idee&Azione', 15),
#  ('Visione Tv', 15),
#  ('Bellum Acta - Intel, Urgent News and Archives', 15),
#  ('/CIG/ Telegram | Counter Intelligence Global', 15),
#  ('Giuseppe Salamone', 14),
#  ('Zoomers IRL', 14),
#  ('Schizophrenics Online', 14),
#  ('Femoids Unleashed', 14),
#  ('eternal classic', 14),
#  ('Disclose.tv', 14),
#  ('📇📃Reality Of War🔎📖', 13),
#  ('⚡️War Digital News⚡️', 13),
#  ('Comitato Ucraina Antifascista Bologna', 13),
#  ('la fionda📕', 13),
#  ('Mondo multipolare', 13),
#  ('NICOLAI LILIN', 13),
#  ('Ultimora.net - POLITICS', 13),
#  ("Notizie dall'Iran islamico e rivoluzionario", 12),
#  ('Repubblica Araba di Siria 🇸🇾', 12),
#  ('𝐻𝒾𝒹𝒹𝑒𝓃 𝒟𝒶𝓉𝒶𝐵𝒶𝓈𝑒', 12),
#  ('Slutty SSRI Bomb Party', 12),
#  ('C E N S O R | M E | D A D D Y - Anime edition', 12),
#  ('UKR LEAKS_Italia', 12),
#  ('Working Man Memes', 12),
#  ('Russia e Dintorni', 12),
#  ('ARSENALE K CHANNEL - Circolo Ricreativo delle Bestie di Satira', 12),
#  ('Istituto Italia Brics', 12),
#  ('Middle East Spectator', 12),
#  ('Pepe Escobar', 11),
#  ('/g/‘s Tech Memes', 11),
#  ('ROCCO CANTAUNTORE', 11),
#  ('Il Veritiero', 11),
#  ('CONTRONARRAZIONE', 11),
#  ('Raffaella Regoli canale ufficiale', 11),
#  ('WarZone - News', 11),
#  ('Anime Enjoyers', 11),
#  ('Social Cringe & Based Posting', 11),
#  ('Estero 24H 🌍 – Notizie dal Mondo 🗞', 11),
#  ('Weltanschauung Italia', 11),
#  ('Inimicizie', 11),
#  ('BASTA guerra nel Donbass', 11),
#  ('Trash Bin', 11),
#  ('Simps IRL', 11),
#  ('Operazione Verità News 📰🗞', 10),
#  ('Ukraine Watch', 10),
#  ('Vento dell’Est 🇮🇹🕊🇷🇺', 10),
#  ('Thuletide', 10),
#  ('Martina Pastorelli', 10),
#  ('Deranged Posting - Good Things Happen Edition', 10),
#  ('Zorro Steppe (Kang Zone)', 10),
#  ('In Telegram Veritas', 10),
#  ('Irina Socolova', 10),
#  ('Ultra Royal MAGA Enjoyers Dark Edition', 10),
#  ('Josef stern💪 informazioni libere.', 10),
#  ('GEOPOLI (Mappe&Storia)', 10),
#  ('Catholics IRL', 10),
#  ('Best Timeline', 10),
#  ('Mai dire Kiev', 10),
#  ('Anticapitalist Surrealism 🇵🇸🔻', 10),
#  (1230715784, 10),
#  ('Fronte della Resistenza al Mondialismo', 9),
#  ('Io leggo 𝔅loղdet & 𝔉riǝղdຮ', 9),
#  ("Il Corriere dell'Animazione", 9),
#  ('Geopolitics Live', 9),
#  ('Western Moment', 9),
#  ('🇧🇾 Fortezza di Brest🇧🇾', 9),
#  ('AASIB.ORG', 9),
#  ('Zyklon IRL', 9),
#  ('️I HATE THE ANTICHRIST️', 9),
#  ('Cris Cersei Channel', 9),
#  ('GeopoliticalCenter', 9),
#  ('Marco Rizzo', 9),
#  ('Pino Cabras', 9),
#  ('Francesca Totolo (Unico canale)', 9),
#  ('Angelo Gambella', 9),
#  ('Khazars IRL', 9),
#  ('Wᴀʀ Rᴇᴀʟ Tɪᴍᴇ 🔞', 9),
#  ('Ultimo Uomo ☧', 9),
#  ('Rossella Fidanza', 9),
#  ('Andrea Zhok', 9),
#  ('Pics with Nationalities', 9),
#  ('Copepasta', 9),
#  ('OttolinaTV', 9),
#  ('DD Geopolitics', 9),
#  ('Breaking News - Ultimora.net', 9),
#  ('Notizie illustrate da IA', 9),
#  ('il Fritto Misto ™️', 8),
#  ('Aviazione russa - Analisi Difesa', 8),
#  ('Colonelcassad', 8),
#  ('Cesare Sacchetti', 8),
#  ('Una voce nel Silenzio ✝️', 8),
#  ('ヒマワリ会 Sunflower Society', 8),
#  ('Slavyangrad', 8),
#  ("L'Indipendente", 8),
#  ('Autism Memes', 8),
#  ('[BASED REBOOT] - Blinded by the lights 🚀', 8),
#  ('susiety', 8),
#  ('𝕀ℕ𝕊𝕀𝔻𝔼ℝ ℚ 𝕀𝕋𝔸𝕃𝕐 🇮🇹', 8),
#  ("[\U0001faa8] romu's repository", 8),
#  ('Рыбарь', 8),
#  ('History Memes', 8),
#  ('Il Vaso di Pandora', 8),
#  ('Cringe-o-rama V2', 8),
#  ('Paolo Borgognone', 8),
#  ('Maurizio Vezzosi', 8),
#  ('Archivi Ayanami', 8),
#  ('Istantanee che procedono irrefrenabilmente.', 8),
#  ('📊 Sondaggi - Ultimora.net', 8),
#  ('Internet puke', 8),
#  ('Sexual Subversion - LGBT Agenda', 8),
#  ('spaghetti uwuposting', 8),
#  (1891165770, 8),
#  ('Кирилл Фёдоров / Война История Оружие', 7),
#  ('Rise of the Global South', 7),
#  ('So far, so good', 7),
#  ('Il Testimone', 7),
#  ('PlayLover Academy', 7),
#  ("Italia 24H Live 🔴 – Notizie dall'Italia", 7),
#  ('Intel Republic', 7),
#  ('Fronte Sovranista (di Kaspercarlo) - non si parla di scie chimiche -', 7),
#  ('Cybernetic Void', 7),
#  ('ImolaOggi Channel', 7),
#  ('アニメ・ミーム・レポ・😭⃠・🇮🇱⃠', 7),
#  ('IL RISVEGLIO DELLA FENICE', 7),
#  ('Christian Brotherhood', 7),
#  ('TERZO MILLENNIO', 7),
#  ('Белорусский силовик 🇧🇾', 7),
#  ('Political memes', 7),
#  ('Lo Squillo di Gilberto Trombetta', 7),
#  ("Daniele Dell'Orco Geopolitica", 7),
#  ('Press TV', 7),
#  ('Shit posting from the front lines', 7),
#  ('Pro Vita & Famiglia', 7),
#  ('/v/‘s Video Memes', 7),
#  ('Lebanese News and Updates', 7),
#  ('Day of the Flush', 7),
#  ('Fabio Fazio si incula da solo con un sofisticato sistema di specchi e leve',
#   7),
#  ('Awesome MP4', 7),
#  ('Post-Shitposting (ZHIN-ZHIAN-AZADI: Show Must Go On! edition)', 7),
#  ('Voter Apathy Party', 7),
#  ('𝐙𝖔𝖔𝖒𝖊𝖗𝐖𝖆𝖋𝖋𝖊𝖓', 7),
#  ("Bictor's Bizzare Shitpost", 7),
#  ('Sa Defenza Channel', 6),
#  ("Ultim'ora notizie 🌍", 6),
#  ('VQB Channel', 6),
#  ('Stanza del porco dio', 6),
#  ('Church of Internal Combustion', 6),
#  ('Luce e Tenebre', 6),
#  ('🎮 VideogamesBirthdays', 6),
#  ('La Banda degli Idraulici', 6),
#  ('Военкор Котенок', 6),
#  ('DataBase Italia', 6),
#  ('Piccolenote', 6),
#  ('Jimble & Sons LLC', 6),
#  ('Q Tv official 3.0 - Qui radio londra Tv NEWS h24', 6),
#  ('The Border 2.0', 6),
#  ('placeholder', 6),
#  ('Malori improvvisi', 6),
#  ("Libtard's Nightmare", 6),
#  ('🎂 AnimeBirthdays', 6),
#  ('L’Altra Faccia dell’Impero', 6),
#  ('Target', 6),
#  ('Matteo Brandi - Canale Ufficiale', 6),
#  ('Aletheia Intelligence (OSINT)', 6),
#  ('Mattonews 🎙🧱🧊', 6),
#  ('CasaDelSoleTV', 6),
#  ('Il Canarino nella Miniera di Carbone', 6),
#  ("Manga's Corner 🐉", 6),
#  ('Bello, Onesto, emigrato Australia', 6),
#  ('Scenari Economici Channel', 6),
#  ('Memini depressi ma per finta', 6),
#  ('Dal Popolo italiano con amore', 6),
#  ('ROKOT | FRASTUONO', 6),
#  ('𝗖𝗢𝗡𝗦𝗘𝗡𝗦𝗢 𝗗𝗜𝗦𝗜𝗡𝗙𝗢𝗥𝗠𝗔𝗧𝗢', 6),
#  ('Der Einzige - Il fronte intellettuale', 6),
#  ('Twongo', 6),
#  ("🐙Lovecraft's Cat🐙", 6),
#  ('Eventi Avversi News', 6),
#  ('CORVELVA', 6),
#  ('Marx21.it', 6),
#  ('Bravi Ragazzi', 6),
#  ('I Fucking Hate Science', 6),
#  ('/slashbiz/ ~ Sneed, Crypto, Business and Finance, AI, memes and news, and being poor in general',
#   6),
#  ('Blofeld’s Undersea Lair (You Only Live Twice)', 6),
#  ('canalw dove uhhhhhhhhhhhhhhhhhhhh allora praticamentw qua si uhhhh e poi huhhhhhh aaaa e poi anche cose strane tipo smalto pink',
#   6),
#  ('Federica Francesconi - canale ufficiale 🖤🔥💪', 6),
#  ('Marvbol Gang: BALLS IN BIO', 6),
#  ('Napoli hard pictures', 6),
#  ('𝘾𝙤𝙡𝙪𝙢𝙗𝙪𝙨 𝙄𝙣𝙛𝙤𝙧𝙢𝙖𝙯𝙞𝙤𝙣𝙚', 6),
#  ('Il Baule dei Meme di Letteralmente lo Sherlock Holmes della Soia', 6),
#  ('Russia Beyond in italiano', 6),
#  ('Come Don Chisciotte - Informazione indipendente dal 2003', 6),
#  ('GeopoliticalCenter', 6),
#  ('100 Giorni da Leoni', 6),
#  ('ISPI - Geopolitica', 6),
#  ('Pics that go hard', 6),
#  ('Libertà e democrazia', 6),
#  ('Gabriele Germani', 6),
#  ('BECCIOLINI NETWORK', 6),
#  ('Casa Russa a Roma // Русский дом в Риме', 6),
#  (1219727646, 6),
#  ('Sabaku', 6),
#  ('Privacy & Security Goys', 6),
#  ('The JQ', 6),
#  ('Shooshposting', 6),
#  ('Повёрнутые на Z войне 🇷🇺', 5),
#  ('Военный Осведомитель', 5),
#  ('ALL YOUR BASE 2', 5),
#  ('PBellavite', 5),
#  ('Leonardo Guerra', 5),
#  ('Два майора', 5),
#  ('🅱️IayLover Academy', 5),
#  ('Enigmatic Ghost-cluster', 5),
#  ('Maurizio Martucci giornalista libero', 5),
#  ('Readovka', 5),
#  ('Gianluca Marletta - News e riflessioni', 5),
#  ('News Academy Italia - Intelligence For Freedom', 5),
#  ('/v/ do Brasil', 5),
#  ('Governo del Cambianiente Channel', 5),
#  ('⛽️', 5),
#  ('ꑭ Oppressed Lifters', 5),
#  ('Chudjak', 5),
#  ('Ziegler Channel ＭＹ ＰＵＳＳＹ ＩＮ ＢＩＯ', 5),
#  ('La Tana NSFW del Sorcio 🇺🇦🇵🇸', 5),
#  ('Портфель Генштаба', 5),
#  ('La Miglior Corsa [SONO IO LA CROCE] 🏁 🧯', 5),
#  ('HickTown', 5),
#  ('La civetta bianca', 5),
#  ('Patria Socialista', 5),
#  ('Progetto Razzia', 5),
#  ('🇦🇺AussieCossack🇷🇺', 5),
#  ('Global Resistance News', 5),
#  ('ZERGULIO🇷🇺', 5),
#  ('Internet §u§ Machine', 5),
#  ('Месть доброй воли', 5),
#  ('ALI - Avvocati Liberi', 5),
#  ('𝕂𝕚𝕥𝕥𝕖𝕟 𝔾𝕒𝕟𝕘 🐈', 5),
#  ('Дмитрий Медведев', 5),
#  ('Keith Woods', 5),
#  ('Kotsnews', 5),
#  ('Воин DV', 5),
#  ('Comitato Centrale', 5),
#  ('Ukrainians Are Based Goy', 5),
#  ('🔥 Spicy Steamed Memeballs 🔥', 5),
#  ('Surf Dad', 5),
#  ('Resistenza su tela Федерика Васселли', 5),
#  ('Dirlebanger', 5),
#  ('Daylight Blue - Mahoyo Edition', 5),
#  ('Notizie da Asia Centrale e Caucaso', 5),
#  ('esoteric vibrations 🌻✝️', 5),
#  ('Lara Arlotta Ufficiale', 5),
#  ('РИА Новости', 5),
#  ('Un altro punto di vista', 5),
#  ('UBERSOY’s Slovo', 5),
#  ('Sara Reginella - Canale ufficiale', 5),
#  ('LA VERITÀ RENDE LIBERI', 5),
#  ('🇮🇹🇷🇺🄸🅃🄰🄻🄸🄰 🆉︎🇷🇺🇮🇹', 5),
#  ('9MQ Web TV', 5),
#  ('🇵🇸🏳️\u200d🌈∆̷Ⓐ☭ASCELLE FANCLUB☭Ⓐ∆̷🏳️\u200d🌈🇵🇸', 5),
#  ('Galleria Pugyaa!!', 5),
#  ('guardia.di.fnaf.nza', 5),
#  ('Irene Mangiazizze', 5),
#  ('Оперативные сводки', 5),
#  ('UmanitàinAzione', 5),
#  ('Italy is ANIME', 5),
#  ('Punished Clossington', 5),
#  ('miki is going delulu', 5),
#  ('Alexander Dugin', 5),
#  ('Silvana Sale_ Babajola Arrubia ☭', 5),
#  ('ТАСС', 5),
#  ('Alessandro Orsini', 5),
#  ('Red Ice TV', 5),
#  ('World Pravda', 5),
#  ('Ambasciator non porta pena', 5),
#  ('Kulturjam.it', 5),
#  ('French Hate 🏳🏳', 5),
#  ("Bellerophon's Autism Plantation", 5),
#  ('Telegrams From Barsoom', 5),
#  ('The War Monger Channel', 5),
#  ('Lorna_toon 🦊', 5),
#  ('The Best Quotes', 5),
#  ('Ritardoantichità', 5),
#  ('Comitato Ascoltami', 5),
#  ('The End Times', 5),
#  ('ZainzTv 🐺 Unico 🦋 Canale Ufficiale!', 5),
#  ('Become Ungovernable', 5),
#  ('Cose che trovo', 5),
#  ('EUNOMIS INFORMA', 5),
#  ('Institute for Male Supremacy', 5),
#  ('Guerrieri per la libertà', 5),
#  ('Luogocomune2', 5),
#  ('4chan webm dump', 5),
#  (1671553909, 5),
#  ('Sturm und Meme', 5),
#  ('Hacker News', 5),
#  ('Texalian Gaming Epic Moments', 5),
#  ("Lacan's Whore House", 5),
#  ('Воевода Вещает', 4),
#  ('Неофициальный Безсонов', 4),
#  ('We wuz Kangzz', 4),
#  ('truthfree', 4),
#  ('TR: Judgement Day', 4),
#  ('АРХАНГЕЛ СПЕЦНАЗА Z🇷🇺', 4),
#  ('💀REVERSE SIDE OF THE MEDAL💀', 4),
#  ('Lion Udler', 4),
#  ('No remorse Iran/Palestina', 4),
#  ('Holy Modification Parish', 4),
#  ('RER | Russia Emilia-Romagna | 🇷🇺🇮🇹', 4),
#  ('Archivio Hufeland [Cinema TV Lost Media]', 4),
#  ('Romanov Лайт ]ࣩࣩࣩࣩ࣯ࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩ', 4),
#  ('CRISPR/GNUGUN Coopernetties', 4),
#  ('Akechi fanclub (sbeku no meku pornopostaggio)', 4),
#  ('Лыня🇷🇺', 4),
#  ('Enjoy the Decline', 4),
#  (1401755002, 4),
#  ('Объясняет Readovka', 4),
#  ("🎀 𝔹𝕌ℕ'𝕊 𝔹𝕌ℕ𝕂𝔼ℝ 🎀", 4),
#  ('RAM RANCH & BIG SNEED INC.', 4),
#  ('Marco Cosentino', 4),
#  ('Оркестр Вагнера | Wagner', 4),
#  ('Роман Сапоньков', 4),
#  ('NO furto eolico Sardegna!', 4),
#  ('Matteo Gracis', 4),
#  ('Revolt Against the Non Fren World 2: 2 Drunk 2 Drive', 4),
#  ('𝗗𝗜𝗦𝗜𝗡𝗙𝗢𝗥𝗠𝗔𝗭𝗜𝗢𝗡𝗘.𝗜𝗧 - Marcello Pamio', 4),
#  ('Роман Алехин', 4),
#  ('Осведомитель', 4),
#  ('NazBol Party Club² ☭ - Trans Pride!!! EDITION', 4),
#  ('bmpd', 4),
#  ('Qlobal-Change Italia 🇮🇹', 4),
#  ('Balkniggers & Slavtards', 4),
#  ('ХИЛЕР l HEALER', 4),
#  ('GREY ZONE', 4),
#  ('Total Drama', 4),
#  ('La Cattedrale di Kirby NG+', 4),
#  ('Zаписки мичмана Птичкина', 4),
#  ('Centro Studi Eurasia e Mediterraneo (CeSEM)', 4),
#  ("Smeed's Springery and Bloomery (not boioioing edition)", 4),
#  ('Natty Light Nationalism', 4),
#  ('Anti-Bug Eaters', 4),
#  ('SilvioDallaTorre', 4),
#  ('Андрей Медведев', 4),
#  ('Тринадцатый.', 4),
#  (1636876924, 4),
#  ('ComeDonChisciotte.org - UFFICIALE', 4),
#  ('Aviahub⚪️🟠', 4),
#  ("L' arte di Satyrus", 4),
#  ('🤍💙♥️MADRE RUSSIA🤍💙♥️', 4),
#  ('St. Peter’s Firewood Emporium', 4),
#  ('Joel Davis', 4),
#  ('IL PUGNO DURO DEL CLAN', 4),
#  ('Репортёр Руденко V', 4),
#  ('Wignats and Chud Central', 4),
#  ('/BMW/ - The Bureau of Memetic Warfare', 4),
#  ('Francesco Amodeo', 4),
#  ('Matteo Demicheli', 4),
#  ('X-21 Memes: Edge Dpt.', 4),
#  ('Fearless John - @European_dissident', 4),
#  ('Inessa S ️️', 4),
#  ('Money Man Mike', 4),
#  ('Pietro Minute (canale)', 4),
#  ('Hic Sunt Leones 🦁 - (canale di Renato Russo)', 4),
#  (1385594756, 4),
#  ('LeakyVax', 4),
#  ('Z News ChannelZ📡', 4),
#  ('Reddit Moments', 4),
#  ('Ратник 2-го раZряда', 4),
#  ("V's journal of scientific shitposting - Now certified 100% psyop free", 4),
#  ("JC's Shitposting Fartzone", 4),
#  ('International Reporters', 4),
#  ("PLAYMASTERMOVIE - canale d'informazione libera", 4),
#  ('Пул N3', 4),
#  ('The Conspiracy Hole', 4),
#  ('СREW RUSSIA', 4),
#  ('Resistance News Network', 4),
#  ('EDGYLiFTER85', 4),
#  ('Алексей Суконкин', 4),
#  ("UU's Memes", 4),
#  ('Shitposting: a lexical abuse', 4),
#  ('InsideOver', 4),
#  ('Multilevel della libertà', 4),
#  ('La durezza del vivere', 4),
#  ("\U0001fa99 THE FERRYMAN'S TOLL \U0001fa99", 4),
#  ('Редакция ШМЕЛЬ', 4),
#  ('Men intel', 4),
#  ('Emporium ReRedux', 4),
#  ('Buffonate di Stato', 4),
#  ('sharted in my pants (Mumu Ogun thunderstrike your mom)', 4),
#  (1629970915, 4),
#  ('🌘 Glass Moon', 4),
#  ('Noel le Pen', 4),
#  ("Ban us if you're gay", 4),
#  ('Patrioti per la liberazione- ARCHIVIO', 4),
#  ('Lord Bebo & Friends', 4),
#  ('Crudelia Memon', 4),
#  ('i have internet instead of personality (Morbius strip edition)', 4),
#  ('Репортер Filatov', 4),
#  (1564910578, 4),
#  ('Roberto Forcione', 4),
#  ('Свидетели Байрактара', 4),
#  ('𝕯emolish the hoax / 𝕯emolire la bufala', 4),
#  ('Afro-American Side Of The Moon', 4),
#  (1599381004, 4),
#  ('Радио России', 4),
#  ('Pesce&Sburo', 4),
#  ('#JustWeebThings', 4),
#  ('byebyeunclesam', 4),
#  ('Rogandar NEWs: Новости, факты, события!', 4),
#  ('Mark Collett', 4),
#  ('Shitgifs', 4),
#  ('🕌 Autism Outlet 2: The Sneedening 🕌', 4),
#  ('TheTexanConnection2.0', 4),
#  ('Rinascita LOMBARDIA', 4),
#  ('Raw Egg Nationalist', 4),
#  ('Lean Sigma Six for the Developmentally Disabled', 4),
#  (1743240836, 4),
#  ('fleshcanoe', 4),
#  ('LiveLeak', 4),
#  ('US Department of Women Haters', 4),
#  ('This Says A Lot About Society', 4),
#  ('I conti non tornano', 4),
#  ("Shadowman311's Manic Musings", 4),
#  ('APOCALISSE: LA VITTORIA FINALE', 4),
#  ('War Monitor', 4),
#  ('Rerum Novarum // Intelligence, Breaking News, and Alerts', 4),
#  ('🔥 𝔾𝕃𝕆𝔹𝔸𝕃 𝕎𝔸ℝ𝕄𝕀ℕ𝔾: Cambiamento climatico • Surriscaldamento globale • Green economy',
#   4),
#  ('Ирина Волк', 4),
#  ('༺ALFA OMEGA CHANNEL༻', 4),
#  ("Breaking News - ULTIM'ORA", 4),
#  ('ContiamoCi!', 4),
#  ('Women Cringe Department', 4),
#  ('✝ Ragazzi Normali ✝', 4),
#  (1649949105, 4),
#  ("Phad's Channel", 4),
#  ('The General', 4),
#  ('Intelligence for the People', 4),
#  ('mastig', 4),
#  ('Chupacabra Kennel', 4),
#  ('Pax Tube', 4),
#  ('#DifesaMinori', 4),
#  ('IO ODIO MAKOTO SHINKAI', 4),
#  ('/fit/ memes waifu edition', 4),
#  ('НгП раZVедка', 4),
#  ('🎀nnknht fans >:3 🇺🇦🇮🇱🏳\u200d🌈', 4),
#  ("The Alchemist's Shack", 4),
#  ('🇺🇸The Sins of The West🇺🇸', 4),
#  ('AngloSphere Archives', 4),
#  ("Sò[QQ]uadro 'NtoQulo Etero Channel - Signoraaaaaa!? I liimoooniii!!!...DAJE! 'Ntoqulo al MES! Fréchète 'ngul!....Anyway, Farts!",
#   4),
#  ('СОЛОВЬЁВ', 4),
#  ("Du Rove's Channel", 4),
#  ('💀🎃 Fully Automated Luxury Lesbian Space Anarcho Communism', 4),
#  ('🔱 WW3.INFO Battlefield Research', 4),
#  (1387906893, 4),
#  ('BlackPill Italia', 4),
#  ('Azione Incel', 4),
#  ('IL Circo 🤡', 4),
#  ('Eureka Riflessioni', 4),
#  ('Deliri Pungenti - Mlem', 4),
#  ('Centro Unico di Informazione e Coordinamento Nazionale', 3),
#  ('White Pride', 3),
#  ('Io Non Mi Vaccino 💉👎🏻', 3),
#  ('In ogni caso nessun rimorso', 3),
#  ('The Fascifist Archive', 3),
#  ('Spread It', 3),
#  ('Voluntarist Memes', 3),
#  ('Cyaomamma', 3),
#  ('liberaveritas 🌬🌊', 3),
#  ('Кирилл Фёдоров', 3),
#  ('Robocock 🐔', 3),
#  ('Avv. Francesco Cinquemani', 3),
#  ('Anto channel', 3),
#  ('Dambiev', 3),
#  ('Apri la tua mente ... Iveta Semetkova Official', 3),
#  ('🇰🇵🌐 Pyongyang Internazionale 🌐🇰🇵', 3),
#  ('Nogeoingegneria', 3),
#  ('Christian Tabletop', 3),
#  ('TERRA (Tanker Enemy Channel)', 3),
#  ('Marrake(k)bab🥄', 3),
#  ('Really cool memes actually', 3),
#  ('ЖИВОВ Z 🇷🇺', 3),
#  ('Proud ODDstanians', 3),
#  ('[CANALE] Miracolo a Milano', 3),
#  ('Andrea Tosatto Official', 3),
#  ('🇷🇺Дневник Мракоборцев | Z🇷🇺 (Группа Аида СпН "Ахмат")', 3),
#  ('Geg the gambler', 3),
#  ('Война с фейками', 3),
#  ('InfoDefenseENGLISH', 3),
#  (1592564357, 3),
#  ('sicksadsorrymess', 3),
#  ('Enzo Di Frenna • BLOG', 3),
#  ('Канал специального назначения', 3),
#  ('Notizie 24 ore', 3),
#  ("L'eRemita", 3),
#  ("Fyodor's Necro", 3),
#  ("Ol' Sweepys Southern-Style Broom Emporium and Meme Trading Post", 3),
#  ('Sauce', 3),
#  ('Lyceum musicum Citaudium Novum, Catana - Circulus veneratorum Rosalindae',
#   3),
#  ('White House Watch', 3),
#  ('Gospa News', 3),
#  ('🎀 𝒲𝒶𝒾𝒻𝓊𝓈𝒰𝓃𝒸𝒽𝒶𝒾𝓃𝑒𝒹 🎀', 3),
#  ('Eurasia & Multipolarity', 3),
#  ('ITALIA UNITA', 3),
#  ('Срочно, Сейчас', 3),
#  ('IL PIANO - LA RINASCITA DELL UMANITÀ', 3),
#  ('🌍 𝐕𝐎𝐂𝐈 𝐃𝐀𝐋𝐋𝐀 𝐒𝐓𝐑𝐀𝐃𝐀 🌎', 3),
#  (1680897239, 3),
#  ('Toba 60', 3),
#  (1614984541, 3),
#  ('ChildResQue Ita Channel', 3),
#  ('Daily Manga Art', 3),
#  ('Kla.TV Italiano', 3),
#  ('#SalviamoILNostroPresente🇮🇹👊', 3),
#  ('Libera Espressione', 3),
#  ('ZАПИСКИ VЕТЕРАНА', 3),
#  ('Altar of Speed 2.0', 3),
#  ('Моисей |Сводки с фронта', 3),
#  ('NO ZTL NO CITTÀ 15 MINUTI ®', 3),
#  ('Военкор Ярем', 3),
#  ('Arruinas Channel', 3),
#  ('La pillola bianca del giorno', 3),
#  ('Dr. BARBARA BALANZONI (qui doc, video, audio,foto)', 3),
#  ('Comitato per la Liberazione di Julian Assange - Italia', 3),
#  ('Военкор l Z l Лисицын ZOV-TV', 3),
#  ('SocialTv Network', 3),
#  ('RA - Russia Amica (Дружественная Россия)', 3),
#  ('Monster Girls & Trap Posting', 3),
#  ('Foids Facility 👨\u200d⚕️👩\u200d⚕️', 3),
#  ('🤡Congregation of Clussy🤡', 3),
#  ('PRO ITALIA - Canale Ufficiale', 3),
#  ('Smokes & Memes is FRONT!', 3),
#  ('Dentro la Notizia®', 3),
#  ('Renovatio 21', 3),
#  ('O.S.A. Italia (canale)', 3),
#  ('il Post', 3),
#  ('Операция Z: Военкоры Русской Весны', 3),
#  ('BLAST - ilblast.it', 3),
#  ('RA/Avv. DDr. Renate Holzeisen', 3),
#  ('Черные береты Каспия', 3),
#  (1712680300, 3),
#  ('PALESTINA HOY 🇵🇸', 3),
#  ('Hux’s Deluxe Channel', 3),
#  ('Хроника оператора БпЛА', 3),
#  ('Alessandro Di Battista', 3),
#  ('Go to @OdeToPower3', 3),
#  ('HiKARi 光 🌻', 3),
#  ('Abbas Djuma', 3),
#  ('Fard Lizard 4: Return of The Shid', 3),
#  ('СОЛДАТ УДАЧИ', 3),
#  ("L'Era dell'Oro - Antonella e Werner", 3),
#  (1633241826, 3),
#  ('Globe Eye 🌍', 3),
#  ('Forgotten Bible quotes', 3),
#  ('Росич | Rosich', 3),
#  ('🇷🇺БОБР🇷🇺', 3),
#  ('Paola Arminio Farmacista e Filosofa della Guarigione', 3),
#  ('animali di merda', 3),
#  ('Arminius News', 3),
#  ('Informazione Multipolare 🚩', 3),
#  ('Eurosiberia', 3),
#  ('Acaposting :3', 3),
#  ('Che cibo!', 3),
#  ('Pressenza - Italia', 3),
#  ('Climate Watch - Ultimora.net', 3),
#  ('Roast Beef Unleashed', 3),
#  ("Alt Skull's Charnel House", 3),
#  ('Il Canale Animato', 3),
#  ('Fate/Italy', 3),
#  ('LON - I Memes di Benjamin', 3),
#  ('Comitato Delicati PRIMA UDIENZA', 3),
#  ('WORLDIVERGENT™️', 3),
#  ('Zлой Пруф️', 3),
#  ('GROENORD-Robertson Arms Co.', 3),
#  ('Mecha pos(pia)taggio stregoso', 3),
#  ('Volchads - anti-humanist swiftie imperialism Edition', 3),
#  ('Collettivo Shaoshan - Notizie sulla Cina 🇨🇳', 3),
#  ('Metal Gear Solid V: Sigma (Balls) Pain', 3),
#  ('Info Nesh🇮🇹', 3),
#  ('Говорит ТопаZ☠️', 3),
#  ('The Lads Go Racemixing', 3),
#  ('Real Matrix World', 3),
#  ('Free Open Source Posthumanism', 3),
#  ('Markov News', 3),
#  ('4Chan - /POL/HIS/INT/', 3),
#  ('Nicholas J. Fuentes', 3),
#  ('Azz Incorporated', 3),
#  (1636580726, 3),
#  ('Denudamento', 3),
#  ('Raven Smiles Memes [M. Inc]', 3),
#  ('Amarnites and Wrens', 3),
#  ('RI_ESISTENZA', 3),
#  ('Д///ИХАД', 3),
#  ('Working Men Memes', 3),
#  ("[SILLY] romu's catpository", 3),
#  ('𝐑𝐞𝐭𝐚𝐫𝐝𝐬 𝐨𝐟 𝐓𝐢𝐤𝐓𝐨𝐤', 3),
#  ('> memes', 3),
#  ('Выпускайте Кракена!', 3),
#  ('Cute Happy Stuffs', 3),
#  ('Stonetoss', 3),
#  ('PoliTimeline News', 3),
#  ('BQQMERS IRL', 3),
#  ('L8COMP® Network Int.', 3),
#  ('РОГОЗИН', 3),
#  ("Futa-chan's Random Posting", 3),
#  ('MAGIC: THE GATHERING SHITPOSTING', 3),
#  ('Comunismo e antisocialismo', 3),
#  ('Megachip', 3),
#  ('Anime Legacy', 3),
#  ('WarGonzo', 3),
#  ('Степной ветер', 3),
#  ('Gazzetta filosofica', 3),
#  ('ℙ𝕣𝕠𝕥 ℍ𝕒𝕥𝕖', 3),
#  ('Persona memes', 3),
#  ('Flexposting 🇪🇺🇺🇦', 3),
#  ('Judge Frog’s S’more Cult', 3),
#  ('Pox Populi', 3),
#  ('Capra News', 3),
#  ('Chat GPT', 3),
#  ('Mahmood', 3),
#  ('Marwa Osman--MidEaStream', 3),
#  ('Orang cate behave your', 3),
#  ('Вѣстовой 🇷🇺', 3),
#  ('Er Talk Channel di Esse, Ross e Melone', 3),
#  ('Cult of the V8', 3),
#  ('BASED AI ART', 3),
#  ('Global Intel Watch', 3),
#  ('>implicando i videogiochi siano divertenti', 3),
#  ('Focus 24H 🗞️ – Notizie più Importanti 🔍', 3),
#  ('Маргарита Симоньян', 3),
#  ('GamingTalker', 3),
#  ('MILANOpiazzaFONTANA', 3),
#  ("Pibals' Großraum Europa #LynchObama", 3),
#  ('Tafelrundereloaded', 3),
#  ('NerV⚡️⚡️⚡️', 3),
#  ('/pol/ 4chan', 3),
#  ('USDA PRIME MEMES', 3),
#  ('Форпост', 3),
#  ('Induced Mass Psychosis', 3),
#  ('Davide Zedda (Giornalismo di inchiesta, informazione e controinformazione)',
#   3),
#  ('PvmpGvng', 3),
#  ('Vault of Secrets - Unpopular History', 3),
#  ('ZoomersIRL:Uncut', 3),
#  ('The Vi Improved', 3),
#  ('Russian Diplomat 🅉', 3),
#  ('Department Of Scaring The Hoes Away', 3),
#  ('DaZbastaDraw', 3),
#  ('☭ mandaroni ☭', 3),
#  ('The Daily Poor', 3),
#  ('Cartoon Creek', 3),
#  ('МИГ России', 3),
#  ('Two Majors - English Channel', 3),
#  ('Claudio Messora', 3),
#  ('Lord Of War', 3),
#  ('Terre Illustrate', 3),
#  ('Следком', 3),
#  ("L'impianto petrolifero sono molto stanco", 3),
#  ('Blair Cottrell', 3),
#  ('ANNA NEWS', 3),
#  ('Galactocosmic Ontological Disorder', 3),
#  ('Realdoc', 3),
#  ('СИГНАЛ', 3),
#  ('Malevisione', 3),
#  ('Chat con me stesso', 3),
#  ('COLE WOLFSSON', 3),
#  ('Pole Connection', 3),
#  ('#IONONMIARRENDO GROUP', 3),
#  ('Atlas: news on China', 3),
#  ('The Course of Empire (Uncensored)', 3),
#  ('人類絶滅攻撃 (mapo)', 3),
#  ('Mr Pool Italia 🇮🇹 - Analyses', 3),
#  ('Mediterranean Man', 3),
#  ('Casa della verità', 3),
#  ('Stefano Franchi, Bologna', 3),
#  ("Sviatoslav's Shitposts", 3),
#  ('Jackson Hinkle', 3),
#  ('Politically Incorrect', 3),
#  ('Autism Central', 3),
#  ('SouthFront: Analysis & Intelligence', 3),
#  ('Fighterbomber', 3),
#  ('Пушилин Д.В.', 3),
#  ('Tupi Report 🇧🇷', 3),
#  ('Only Street Fighting', 3),
#  ('Socialism Beer', 3),
#  ('mamode wan meem', 3),
#  ('Анастасия Кашеварова 🇷🇺', 3),
#  ('КАТРУСЯ', 3),
#  ('Wholesome & Virtuous', 3),
#  ('Fashposting', 3),
#  ('M&M posting', 3),
#  ('Enzo Pennetta - Critica Scientifica', 3),
#  ('Sam Hyde Bags l Million Dollar Extreme', 3),
#  ('Legion Napier: Quiet Riot', 3),
#  ('Reese Report', 3),
#  ('Antifasciocomunismo', 3),
#  ('Manosphere ITA 🇮🇹', 3),
#  (2049802705, 3),
#  ('Ste2510_YT Lounge 🇧🇬', 3),
#  ('NonVita', 3),
#  ('SEGRETI INCOGNITO 🔏', 3),
#  ("L'Ordine del Giorno", 2),
#  ('Roy - الحرب الثالثة', 2),
#  ('Libertà e Verità', 2),
#  ('Spotted Unipa', 2),
#  ('Reportage 2.0', 2),
#  ('МОО Вече', 2),
#  ('europadelsud', 2),
#  ('Turanic Schizoposting🐺', 2),
#  ('Military Summary', 2),
#  ('Alpha & Omega', 2),
#  ('Юрист на Югах', 2),
#  ('La Verità', 2),
#  ('Khamenei.it', 2),
#  ('Lanonaelica', 2),
#  ('ГРИГОРЬЕВ', 2),
#  ('🗿; Chevauchée', 2),
#  ('Война Глазами Журналиста', 2),
#  ('🇺🇸🇷🇺🇮🇹Trump and the PATRIOTS ITALIA 🐸🇺🇸', 2),
#  (1595839251, 2),
#  ('Liberalism and Whiteness', 2),
#  ('/DIY/ (/fit/?)', 2),
#  ('IL GRANDE RISVEGLIO_Q 1776', 2),
#  ('GNOME CONSERVATISM', 2),
#  ('Blood $atellite', 2),
#  (1212902599, 2),
#  (1649214617, 2),
#  ('The Islander', 2),
#  ('Banana Society', 2),
#  ('ТРОЙКА 🏴\u200d☠️', 2),
#  ('F.K.MAGNVS', 2),
#  ('ПриZрак Новороссии', 2),
#  ('Fortissax is Typing', 2),
#  ('Bosozoku Collection', 2),
#  ('Beregini', 2),
#  ('Il Canale di Loti', 2),
#  ('Svitlana NEWS', 2),
#  ('LOSTARMOUR | Carthago delenda est!', 2),
#  ("Alexzan's Telegram blog - Galaxy! ⚝", 2),
#  ('Fumetteria ch. ⚝⃠', 2),
#  ('apple.com', 2),
#  ('Monica Elisa', 2),
#  ('ZENIT', 2),
#  ("Woodpecker's Hove", 2),
#  ("Cronache dal virus che non c'è", 2),
#  ('Matteo Montevecchi', 2),
#  ('Strategic Culture Foundation', 2),
#  ('Paracetamolo BNKR44 FANCLUB', 2),
#  ('Covo di Lyfex', 2),
#  ('Griff Capital LLC', 2),
#  ('Europe Elects Official', 2),
#  ('Uriel Crua', 2),
#  ('/r/Mapporn', 2),
#  ('Джокер ДНР', 2),
#  ('Iranball 2: Electric Boogaloo | Post-suicide EDITION', 2),
#  ('Чешир таежный и дело о пропавшем 28-м штате', 2),
#  ('Il canale di Marco', 2),
#  ('Mobile Suit Merriuaa DAI CAZZO HOLD THE DOOR BECNABOR', 2),
#  ('Донбасский Партизан', 2),
#  ('Danilo Hardy', 2),
#  ('Sparkling water (la mia sbo)', 2),
#  ("Enby pirate's depressed and horny memes and unrelated mischievous stuff",
#   2),
#  ('gabriel oracolo di kirby 🏳️\u200d🌈 👽', 2),
#  ('Underground', 2),
#  ('White People Telegram', 2),
#  ('Militare Semplice', 2),
#  ('07th Expansion Italia', 2),
#  ('Агрегатор', 2),
#  ('FUORI DAL GREGGE 🐑🐑🐑', 2),
#  ('Африканская инициатива 🌍', 2),
#  ('Il Fritto Misto 2', 2),
#  ('ТЫ ТАМ БЫЛ? (Павел Кукушкин)', 2),
#  ('Вадим Лобов. Новости', 2),
#  ('Franco Fracassi Giornalista Indipendente', 2),
#  ("\U0001faf4🏻Devil's Downfall\U0001faf3🏻", 2),
#  ('Рубрика от Ледка', 2),
#  ('Beyond Liberalism', 2),
#  ('Slantie Mongoloid Hate', 2),
#  ('vx-underground', 2),
#  ('Jacopo Coghe', 2),
#  (1774881602, 2),
#  ('Gunpla Italia', 2),
#  ('Pensa&Scrivi', 2),
#  ('ТРИБУНАЛ', 2),
#  ('Jay le Trump Z - Truth Bombs and Intel', 2),
#  ('🄵🅁🄰🄶🄸🄻🄴 🄳🄴🄼🄾🄲🅁🄰🄲🅈', 2),
#  ('Opinioni personali', 2),
#  ('Настоящий Гладков', 2),
#  ('ARBITRIUM PSG', 2),
#  ('Shalnyak', 2),
#  ('DistopiaEva', 2),
#  ('Dystopian Discourse', 2),
#  ('maledetto bile', 2),
#  ('Ugo Fuoco 🔥 Stop Dittatura', 2),
#  ('MultiXAM', 2),
#  ('🦦 Otter gang 🦦', 2),
#  (1236702378, 2),
#  ('JOIN @geopolitics_live » official Sputnik International mirror', 2),
#  ('Лука Ебков', 2),
#  ('Tiberio & Flaminia (ed altri amici gattastri 🙄)', 2),
#  ('Cats of Internal Combustion', 2),
#  ('Daniel Haqiqatjou Official', 2),
#  ('Russian MFA 🇷🇺', 2),
#  ("EDOARDO DINI IL CLAN DELL'ANTIVIRUS", 2),
#  ('Герои спецоперации Z', 2),
#  ('EXTRA BREAD', 2),
#  ('Fortnite ITA | News & Leaks 🇮🇹', 2),
#  (2022709466, 2),
#  ('🇮🇹⚙️🕉🛠☯️🇮🇹LABORATORIO del LAVORO - Facciamo alchimie', 2),
#  ('Radio28Tv', 2),
#  ('Интербригады 2022', 2),
#  ('i disegni bellissimi di emma', 2),
#  ('Wojak', 2),
#  ('CatHunt', 2),
#  ('La Terra dei Padri', 2),
#  ('Разведотряд 106', 2),
#  ('musick to play in the dark', 2),
#  ('Am I an electric sheep?', 2),
#  ('Looting Channel', 2),
#  (1960648125, 2),
#  ('Christian Cookery', 2),
#  ('I,Hypocrite', 2),
#  ('Pissed Texan', 2),
#  ('Leggiamo le leggi (Laura Carosi)', 2),
#  ('MikaYoutubers', 2),
#  ('Правда за нами', 2),
#  ('Italiaeilmondo', 2),
#  ('Генерал-губернатор ДВ', 2),
#  ('WARPIG memes', 2),
#  ('Сыны Монархии', 2),
#  ('Verticale', 2),
#  ('Resistance Channel', 2),
#  ('G4M3 0V3R CH4NN3L 🐸', 2),
#  ('ФЕСТИВАЛЬ «RT.ДОК:ВРЕМЯ ГЕРОЕВ»', 2),
#  ('✂️ Monogatari Series Italia', 2),
#  ('Юрий Баранчик', 2),
#  ('ПТСР TEAM Community', 2),
#  ("Kefka's Shrine", 2),
#  ('⚔️ СВАРЩИКИ', 2),
#  ('LordLando-chan(nel)', 2),
#  ('krISSS knife', 2),
#  ("Ossomaki's Crafting Table (Drawing & TTRPG)", 2),
#  ('Redpilled Rabbit', 2),
#  ('severe shitposting society', 2),
#  ('Angryposting VII Rebirth', 2),
#  ('"Un commercialista di Bari" [cit.] @giuslit', 2),
#  ('Mr. Putin', 2),
#  ('Anime & Manga Copypasta', 2),
#  ('Военное обозрение', 2),
#  ('Covid-19 - Ultimora.net', 2),
#  (1216053281, 2),
#  ('Me_irl', 2),
#  ('Асфальт', 2),
#  ('Quds News Network', 2),
#  ('Congregation of Clussy 3', 2),
#  ('EroSoc - Erotic Socialism', 2),
#  ("King Koopa's Shellposting Kingdom", 2),
#  ('Racial Beauty', 2),
#  ("𝔾𝕠𝕣𝕠'𝕤 ℙ𝕒𝕝𝕒𝕔𝕖 - ℝ𝕖𝕒𝕝𝕚𝕥𝕪 𝕄𝕠𝕠𝕟𝕗𝕒𝕝𝕝", 2),
#  ('Avv. Mauro Sandri', 2),
#  ('"C\'s" tea', 2),
#  ('Akashic Record ✍️', 2),
#  ('Украина.ру', 2),
#  ('Computeristic World (Aesthetics, Lain and Stuff)', 2),
#  ('От Первого Лица | ОПЛ', 2),
#  ('ITALIASTAN🇮🇹🇮🇶🇮🇷🇰🇼🇲🇩🇸🇲🇶🇦🇸🇦🇹🇯🇬🇧🇺🇸🇺🇾🇬🇪', 2),
#  ('Awake432hz 🌬𓂀 Coscienza Cosmica', 2),
#  ('СВЕЖЕСТИ', 2),
#  ('Rete Voltaire in italiano', 2),
#  ('Notizie Oggi Lineasera | Canale Italia', 2),
#  ('Vincent James', 2),
#  ('Блокнот Пропагандиста', 2),
#  ('ДМИТРИЙ ЗИМЕНКИН', 2),
#  ('Militia Christi', 2),
#  ('PsyOps Memes', 2),
#  ('THE NEW INSIDER', 2),
#  ('The Impartial Truth', 2),
#  ('Franco Sampieri - NEWS', 2),
#  ('Trad Liberators of Europe 🇷🇺', 2),
#  ('Trad Lives Matter', 2),
#  ('Александр Хинштейн', 2),
#  ("NP's Deranged Rants", 2),
#  ('Осташко! Важное', 2),
#  ('MITTDOLCINO.COM Channel', 2),
#  ('Arktos', 2),
#  ('Владислав Угольный 🐕\u200d🦺', 2),
#  (1626184334, 2),
#  ('Irina 🇷🇺', 2),
#  ('Африканский Корпус', 2),
#  ("ade's dump", 2),
#  ('Local Team Alert', 2),
#  ('WYF 2024', 2),
#  (1639604235, 2),
#  ('Niggers', 2),
#  ('Il CORAGGIO del Dubbio - A!', 2),
#  ('Sede G Rank degli uppercut', 2),
#  ('Katehon', 2),
#  ('Exposing Pajeets', 2),
#  ('Поддубный |Z|О|V| edition', 2),
#  ('/gfk/', 2),
#  ('ЖИТЬ', 2),
#  ("Come Don Chisciotte PIU' SALUTE di Valentina Bennati", 2),
#  ('Позывной Брюс', 2),
#  (1782269431, 2),
#  ('Сливочный каприз', 2),
#  ('Рамзай', 2),
#  ('Marinella Mondaini', 2),
#  ('⚡GIULAMASCHERA- Il Risveglio ✨', 2),
#  ('𝗣𝗮𝗷𝗲𝗲𝘁 𝗚𝘂𝗹𝗮𝗴 𝗦𝗵𝗶𝘁𝗽𝗼𝘀𝘁𝗶𝗻𝗴 🍃', 2),
#  ('Democrazia Giustizia e Libertà', 2),
#  ('Canale Comitato Fortitudo', 2),
#  ('The Commissioner (Blue Check University)', 2),
#  ('INZAION di Luca Nali', 2),
#  ('Nexus Next', 2),
#  ('Pills for Thrills', 2),
#  ('Синяя Z Борода', 2),
#  ('Дюков. Историк-рационализатор', 2),
#  ('Survive the Jive: All-feed', 2),
#  ('Голос страны', 2),
#  ('ДШРГ Русич', 2),
#  ('La Pescheria Giovyncella', 2),
#  ('🔥МоскалькоV🔥', 2),
#  ('Clash Report', 2),
#  ('Meme Cannons 🧯', 2),
#  ('Гуманитарная помощь', 2),
#  (1568801280, 2),
#  ('Злой журналист', 2),
#  ('VELES тихонько пишет', 2),
#  ('Война. Без фейков', 2),
#  ('memes outta my ass', 2),
#  ('CI((\u2060✷\u2060‿\u2060✷\u2060))SEPIN 🦀', 2),
#  ('Comitato Liberi Pensatori', 2),
#  ('KEK-o-rama', 2),
#  ('🅶🆄🆁🆄🄷🄸🅃🄴🄲🄷.ᶜᵒᵐ', 2),
#  ('Avv. Roberto De Petro', 2),
#  (1881917116, 2),
#  ('Старше Эдды', 2),
#  ('Giolmiposting 🦦', 2),
#  ('lean mean tiger team machine: Sopping Fucking Wet Edition', 2),
#  ('Афанасьев Z', 2),
#  ('Олег Царёв', 2),
#  ('Polizia Tributaria - Matelica', 2),
#  ('Dèmos', 2),
#  ('Resolute Auditory Violence', 2),
#  ('Ministero dei Meme', 2),
#  (1395469662, 2),
#  (1399985034, 2),
#  ('Курилка мичмана Птичкина', 2),
#  ('Gearóid Murphy', 2),
#  (2022518348, 2),
#  ('Russell TEXAS Bentley', 2),
#  ('Difendersi Ora - Avv. Fusillo', 2),
#  (1148125857, 2),
#  ('Noi i no vax, i complottisti, i sopravvissuti 😂😂😂😂😂😂😂😂', 2),
#  ('ExistWell', 2),
#  ('AngoloLiberodiLu', 2),
#  ('Умар Кремлев', 2),
#  ('The Cradle', 2),
#  ('MemriTV', 2),
#  ('Mems per non cummare che effettivamente fanno cum', 2),
#  ('Border Nights (ufficiale)', 2),
#  ('Fat People Hate', 2),
#  ('Goth memes', 2),
#  ('Mambolosco Fanclub', 2),
#  ('Филолог в засаде', 2),
#  (1193423105, 2),
#  ('Die Schwarze Fahne', 2),
#  ('Первый Харьковский', 2),
#  ('Первый Севастопольский', 2),
#  ('🐾🏳️\u200d⚧️ Manic Pubbygirl posting 🏳️\u200d⚧️🐾', 2),
#  ('Gabriele Sannino Quello che i media non dicono', 2),
#  ...]

# %%
sorted(list(zip(G.vs['label'],G.vs.indegree())), key=lambda x: x[1], reverse=True)
# Out:
# [('Sa Defenza Channel', 472),
#  ('Slutty SSRI Bomb Party', 293),
#  ('Jimble & Sons LLC', 277),
#  ('So far, so good', 240),
#  ('Colonelcassad', 238),
#  ('Leonardo Guerra', 222),
#  ('Кирилл Фёдоров / Война История Оружие', 194),
#  ('Роман Сапоньков', 193),
#  ('Stanza del porco dio', 186),
#  ('Libertà e Verità', 166),
#  ('Giuseppe Masala Chili 🌶', 165),
#  ('️I HATE THE ANTICHRIST️', 153),
#  ('O.d.E.G. Guerra NATO-RUSSIA', 147),
#  ('InfoDefenseITALIA', 146),
#  ('Akechi fanclub (sbeku no meku pornopostaggio)', 144),
#  ('Romanov Лайт ]ࣩࣩࣩࣩ࣯ࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩࣩ', 132),
#  ('Pepe Escobar', 128),
#  ('📇📃Reality Of War🔎📖', 123),
#  ('🇧🇾 Fortezza di Brest🇧🇾', 109),
#  ('Giorgio Bianchi Photojournalist', 100),
#  ('NazBol Party Club² ☭ - Trans Pride!!! EDITION', 88),
#  ('The Fascifist Archive', 84),
#  ('F.D.B.', 81),
#  ('Оркестр Вагнера | Wagner', 80),
#  ('truthfree', 76),
#  ('Alessandro Orsini', 76),
#  ('Comitato Ucraina Antifascista Bologna', 72),
#  ('Военкор Котенок', 71),
#  ('Church of Internal Combustion', 70),
#  ('Donbass italia', 69),
#  ('Clara Statello - Canale Ufficiale', 68),
#  ('Idee&Azione', 68),
#  ('Jay le Trump Z - Truth Bombs and Intel', 64),
#  ('Giubbe Rosse', 61),
#  ('Vi racconto la Russia', 61),
#  ('Военный Осведомитель', 60),
#  ('Irene Mangiazizze', 59),
#  ('Operazione Verità News 📰🗞', 57),
#  ('Gianluca Marletta - News e riflessioni', 57),
#  ('LR, Geopolitica e News', 53),
#  ('𝑆𝑜𝑛𝑜 𝑛𝑢𝑑𝑜.', 53),
#  ('canalw dove uhhhhhhhhhhhhhhhhhhhh allora praticamentw qua si uhhhh e poi huhhhhhh aaaa e poi anche cose strane tipo smalto pink',
#   53),
#  ('Pentium che discute #Dopoacasa', 52),
#  ('Andrea Lucidi -Canale ufficiale- Андреа Лучиди -официальный телеграм канал-',
#   51),
#  ('Fumetteria ch. ⚝⃠', 51),
#  ('Governo del Cambianiente Channel', 50),
#  ('Spread It', 48),
#  ('[BASED REBOOT] - Blinded by the lights 🚀', 48),
#  ('Fronte della Resistenza al Mondialismo', 46),
#  ('Ex Azione Incel - 2° gruppo', 46),
#  ('Ukraine Watch', 45),
#  ('Subscribe to @FardLizard4', 45),
#  ('Zorro Steppe (Kang Zone)', 44),
#  ('Robocock 🐔', 43),
#  ('Calabria Saudita 🇸🇦🗣', 43),
#  ('Western Moment', 42),
#  ('La Miglior Corsa [SONO IO LA CROCE] 🏁 🧯', 42),
#  ('BlackPill Italia', 42),
#  ('In ogni caso nessun rimorso', 40),
#  ('Enjoy the Decline', 40),
#  ('ITALIA UNITA', 38),
#  ('Catholics IRL', 37),
#  ('Istantanee che procedono irrefrenabilmente.', 37),
#  ('Money Man Mike', 36),
#  ('Angryposting VII Rebirth', 36),
#  ('Total Drama', 35),
#  ('Khazars IRL', 33),
#  ('Femoids Unleashed', 32),
#  ('Zoomers IRL', 31),
#  ('BLAST - ilblast.it', 31),
#  ("Jammish's random memes", 30),
#  ('Thuletide', 29),
#  ('Multipolare News', 28),
#  ('⛽️', 28),
#  ('Best Timeline', 28),
#  ('Reportage 2.0', 27),
#  ('Anto channel', 26),
#  ('Ultra Royal MAGA Enjoyers Dark Edition', 26),
#  ('Comitato per il Donbass Antinazista - Notizie sulla guerra in Ucraina', 25),
#  ('Monster Girls & Trap Posting', 25),
#  ("L'AntiDiplomatico", 24),
#  ('Chudjak', 24),
#  ('White Pride', 23),
#  ('Day of the Flush', 23),
#  ('Una voce nel Silenzio ✝️', 22),
#  ('Bravi Ragazzi', 20),
#  ('krISSS knife', 20),
#  ('La terza ROMA', 19),
#  ('Altar of Speed 2.0', 19),
#  ('Daniel Haqiqatjou Official', 19),
#  ('il Fritto Misto ™️', 18),
#  ('Tutti i fatti', 18),
#  ('Anime Enjoyers', 18),
#  ('Christian Brotherhood', 18),
#  ("Il Corriere dell'Animazione", 17),
#  ('la fionda📕', 17),
#  ('Social Cringe & Based Posting', 17),
#  ('Lebanese News and Updates', 17),
#  ('guardia.di.fnaf.nza', 17),
#  ('Редакция ШМЕЛЬ', 17),
#  ('WarZone - News', 16),
#  ('Fard Lizard 4: Return of The Shid', 16),
#  ('Un ponte tra Italia e Russia', 15),
#  ('Turanic Schizoposting🐺', 14),
#  ('Arminius News', 14),
#  ('Istituto Analisi Crimini Youtuber e Altri Tizi sul Web', 14),
#  ("L'Ordine del Giorno", 13),
#  ('Suriyakmaps', 13),
#  ('Genshin Impact feet posting 🦶😳', 12),
#  ('Che cibo!', 12),
#  ('/gfk/', 12),
#  ('Luce e Tenebre', 11),
#  ('Galleria Pugyaa!!', 11),
#  ('Simps IRL', 11),
#  ('Radio MODIFICATI', 11),
#  ('Vento dell’Est 🇮🇹🕊🇷🇺', 10),
#  ('Comitato per la Liberazione di Julian Assange - Italia', 10),
#  ('⚡️War Digital News⚡️', 9),
#  ('𝐻𝒾𝒹𝒹𝑒𝓃 𝒟𝒶𝓉𝒶𝐵𝒶𝓈𝑒', 9),
#  ('Istituto Italia Brics', 9),
#  ('Italy is ANIME', 9),
#  ('Lion Udler', 8),
#  ('Pics that go hard', 8),
#  ('Ste2510_YT Lounge 🇧🇬', 8),
#  ('NonVita', 8),
#  ('🅱️IayLover Academy', 7),
#  ('Mattonews 🎙🧱🧊', 7),
#  ('Mai dire Kiev', 7),
#  ('Resistenza su tela Федерика Васселли', 7),
#  ("Futa-chan's Random Posting", 7),
#  ('Roy - الحرب الثالثة', 6),
#  ('LIVE - Ultimora.net', 6),
#  ('Archivio Hufeland [Cinema TV Lost Media]', 6),
#  ('Ultimora.net - POLITICS 24', 6),
#  ('Inimicizie', 6),
#  ('Foids Facility 👨\u200d⚕️👩\u200d⚕️', 6),
#  ('Wignats and Chud Central', 6),
#  ('Archivi Ayanami', 6),
#  ("ULTIM'ORA 24", 6),
#  ('MAGIC: THE GATHERING SHITPOSTING', 6),
#  ('We wuz Kangzz', 5),
#  ('Estero 24H 🌍 – Notizie dal Mondo 🗞', 5),
#  ('Militare Semplice', 5),
#  ('Political memes', 5),
#  ('Climate Watch - Ultimora.net', 5),
#  ('Roast Beef Unleashed', 5),
#  ("Breaking News - ULTIM'ORA", 5),
#  ('✝ Ragazzi Normali ✝', 5),
#  ('RetardTok', 5),
#  ('Whoreschwitz Concentration Camp', 5),
#  ('Eureka Riflessioni', 5),
#  ('TR: Judgement Day', 4),
#  ('TR 3: Rise Of The Machines', 4),
#  ('Cyaomamma', 4),
#  ('Ultimora.net - POLITICS', 4),
#  ('Bosozoku Collection', 4),
#  ('Cats of Internal Combustion', 4),
#  ('Globe Eye 🌍', 4),
#  ('AmiciApple.it', 4),
#  ('French Hate 🏳🏳', 4),
#  ('The Best Quotes', 4),
#  ('Zeb89', 4),
#  ("𝕴𝖗𝖊𝖓𝖊𝖔'𝖘 𝕻𝕯𝕱𝖘 𝕸𝖆𝖌𝖎𝖈𝖆𝖑 𝕿𝖔𝖜𝖊𝖗🗼", 4),
#  ('Memologia Memetica & STUFF', 4),
#  ('Transgender Horror Stories', 4),
#  ('IL Circo 🤡', 4),
#  ('Spotted Unipa', 3),
#  ('Lettera da Mosca', 3),
#  ('War Room - Russia, Ucraina, NATO', 3),
#  ('Zyklon IRL', 3),
#  ("Italia 24H Live 🔴 – Notizie dall'Italia", 3),
#  ('🎀 𝒲𝒶𝒾𝒻𝓊𝓈𝒰𝓃𝒸𝒽𝒶𝒾𝓃𝑒𝒹 🎀', 3),
#  ('Pro Vita & Famiglia', 3),
#  ('Napoli hard pictures', 3),
#  ('Covid-19 - Ultimora.net', 3),
#  ('📊 Sondaggi - Ultimora.net', 3),
#  ('Femministe Sputtanate', 3),
#  ('Pixelpostaggio', 3),
#  ('RangeloniNews', 2),
#  ('Angelo Gambella', 2),
#  ('Memini depressi ma per finta', 2),
#  ('Empyrean Codex', 2),
#  ('Tiberio & Flaminia (ed altri amici gattastri 🙄)', 2),
#  ('Copepasta', 2),
#  ('Breaking News - Ultimora.net', 2),
#  ('Sexual Subversion - LGBT Agenda', 2),
#  ('>implicando i videogiochi siano divertenti', 2),
#  ('Italia 24H 🇮🇹 Flash – Notizie Italia 🗞', 2),
#  ('Cessa Magra', 2),
#  ('bestioline', 2),
#  ('Internet Scholarship', 2),
#  ('Deliri Pungenti - Mlem', 2),
#  ('Most Brutally Pill💊', 2),
#  ('Trash Bin', 1),
#  ('Forgotten Bible quotes', 1),
#  ('🧠 Sapiens³', 1),
#  ('War Monitor', 1),
#  ('ZoomersIRL:Uncut', 1),
#  ('Women Cringe Department', 1),
#  ('LA LUMACW', 1),
#  ('Pdl Igra - canale ufficiale🏴 🇩🇰', 1),
#  ('Psl Gods', 1),
#  ("eroBAldo's lewd temple", 1),
#  ('Schizocraft', 1),
#  ('⚡️ARDITI DELLA STRADA⚡️', 1),
#  ('Mafkamote', 1),
#  ('Antifasciocomunismo', 1),
#  ('Manosphere ITA 🇮🇹', 1),
#  ('SEGRETI INCOGNITO 🔏', 1),
#  ('Schizoblogs', 1),
#  ('Aviazione russa - Analisi Difesa', 0),
#  ('La Mia Russia', 0),
#  ('Воевода Вещает', 0),
#  ('Повёрнутые на Z войне 🇷🇺', 0),
#  ('Centro Unico di Informazione e Coordinamento Nazionale', 0),
#  ('Fiorangela, canale pubblico.', 0),
#  ("Notizie dall'Iran islamico e rivoluzionario", 0),
#  ('Неофициальный Безсонов', 0),
#  ('Io leggo 𝔅loղdet & 𝔉riǝղdຮ', 0),
#  ('Francesca Quibla, sono il tuo sogno eretico.', 0),
#  ('МОО Вече', 0),
#  ("Ultim'ora notizie 🌍", 0),
#  ('Kill Dogma Tv Ufficiale', 0),
#  ('VQB Channel', 0),
#  ('Geopolitics Live', 0),
#  ('АРХАНГЕЛ СПЕЦНАЗА Z🇷🇺', 0),
#  ('Io Non Mi Vaccino 💉👎🏻', 0),
#  ('Земля Будущего', 0),
#  ('Giuseppe Salamone', 0),
#  ('Repubblica Araba di Siria 🇸🇾', 0),
#  ('Cesare Sacchetti', 0),
#  ('europadelsud', 0),
#  ('𝙴𝚞𝚛𝚊𝚜𝚒𝚊𝚗 𝚅𝚘𝚕𝚔', 0),
#  ('Rise of the Global South', 0),
#  ('Saker Italia', 0),
#  ('Military Summary', 0),
#  ('💀REVERSE SIDE OF THE MEDAL💀', 0),
#  ('Ольга Вязовская "Леля"', 0),
#  ('Alpha & Omega', 0),
#  ('Юрист на Югах', 0),
#  ('La Verità', 0),
#  ('🇬🇧 SITREP - Independent OSINT Channel 🇬🇧', 0),
#  ('Laura Ru', 0),
#  ('Cultured American', 0),
#  ('No remorse Iran/Palestina', 0),
#  ('Holy Modification Parish', 0),
#  ('RER | Russia Emilia-Romagna | 🇷🇺🇮🇹', 0),
#  ('Fotone - Il ragazzo dal futuro [Tv-Sigle-Cartoni-Video-Audio]', 0),
#  ('ALL YOUR BASE 2', 0),
#  ('Sovranità', 0),
#  ('PBellavite', 0),
#  ('ヒマワリ会 Sunflower Society', 0),
#  ('Два майора', 0),
#  ('Khamenei.it', 0),
#  ('Марьяна Батьковна', 0),
#  ('CRISPR/GNUGUN Coopernetties', 0),
#  ('🎮 VideogamesBirthdays', 0),
#  ('AASIB.ORG', 0),
#  ('Лыня🇷🇺', 0),
#  ('Slavyangrad', 0),
#  ('La Banda degli Idraulici', 0),
#  ('Voluntarist Memes', 0),
#  ('Sard TV Retrò 📼 📺🦩', 0),
#  ('Il Testimone', 0),
#  ('la Repubblica', 0),
#  ('Lanonaelica', 0),
#  ('DataBase Italia', 0),
#  (1401755002, 0),
#  ('/g/‘s Tech Memes', 0),
#  ('Объясняет Readovka', 0),
#  ('Piccolenote', 0),
#  ('PlayLover Academy', 0),
#  ('Ambasciata Russa in Italia/Посольство РФ в Италии', 0),
#  ('Race Realism Channel', 0),
#  ('liberaveritas 🌬🌊', 0),
#  ('Martina Pastorelli', 0),
#  ('Enigmatic Ghost-cluster', 0),
#  ('выдры и мемы 🦦', 0),
#  ('Federico Dezzani Blog', 0),
#  ('Кирилл Фёдоров', 0),
#  ('Q Tv official 3.0 - Qui radio londra Tv NEWS h24', 0),
#  ("L'Indipendente", 0),
#  ('Schizophrenics Online', 0),
#  ('Maurizio Martucci giornalista libero', 0),
#  ('Third Position Hub', 0),
#  ('La Nuova Bussola Quotidiana', 0),
#  ('ГРИГОРЬЕВ', 0),
#  ('Mondo multipolare', 0),
#  ('idk memes tho', 0),
#  ("🎀 𝔹𝕌ℕ'𝕊 𝔹𝕌ℕ𝕂𝔼ℝ 🎀", 0),
#  ('🗿; Chevauchée', 0),
#  ('Sconti (codici, buoni, offerte)', 0),
#  ('The Border 2.0', 0),
#  ('Война Глазами Журналиста', 0),
#  ('Deranged Posting - Good Things Happen Edition', 0),
#  ('Cris Cersei Channel', 0),
#  ('Readovka', 0),
#  ('Anglo Imperial Channel', 0),
#  ('Avv. Francesco Cinquemani', 0),
#  ('🇺🇸🇷🇺🇮🇹Trump and the PATRIOTS ITALIA 🐸🇺🇸', 0),
#  ('ROCCO CANTAUNTORE', 0),
#  (1595839251, 0),
#  ('Liberalism and Whiteness', 0),
#  ('placeholder', 0),
#  ('GeopoliticalCenter', 0),
#  ('𝕋𝖗𝖚𝖊 𝕮𝖍𝖗𝖎𝖘𝖙𝖎𝖆𝖓𝖘', 0),
#  ('/DIY/ (/fit/?)', 0),
#  ('name doesn’t exist', 0),
#  ('MARIO IMPROTA ARTIST', 0),
#  ('Intel Republic', 0),
#  ('Dambiev', 0),
#  ('RAM RANCH & BIG SNEED INC.', 0),
#  ('Il Veritiero', 0),
#  ('Marco Cosentino', 0),
#  ('In Telegram Veritas', 0),
#  ('News Academy Italia - Intelligence For Freedom', 0),
#  ('IL GRANDE RISVEGLIO_Q 1776', 0),
#  ('GNOME CONSERVATISM', 0),
#  ('Fronte Sovranista (di Kaspercarlo) - non si parla di scie chimiche -', 0),
#  ('Cybernetic Void', 0),
#  ('Comunidad Saker Latinoamérica', 0),
#  ('Apri la tua mente ... Iveta Semetkova Official', 0),
#  ('Marco Rizzo', 0),
#  ('Malori improvvisi', 0),
#  ('Blood $atellite', 0),
#  (1212902599, 0),
#  ('/v/ do Brasil', 0),
#  ("Libtard's Nightmare", 0),
#  ('Autism Memes', 0),
#  ('CONTRONARRAZIONE', 0),
#  ('NO furto eolico Sardegna!', 0),
#  ('Matteo Gracis', 0),
#  ('Aipom fa cose (strane)', 0),
#  ('/x/', 0),
#  ('🎂 AnimeBirthdays', 0),
#  ('Raffaella Regoli canale ufficiale', 0),
#  ('🇰🇵🌐 Pyongyang Internazionale 🌐🇰🇵', 0),
#  (1649214617, 0),
#  ('Secret Society Blanket', 0),
#  ('The Islander', 0),
#  ('Аналитическая служба Донбасса', 0),
#  ('Pino Cabras', 0),
#  ('Revolt Against the Non Fren World 2: 2 Drunk 2 Drive', 0),
#  ('Nogeoingegneria', 0),
#  ("L'Osservatorio - Esteri", 0),
#  ('NICOLAI LILIN', 0),
#  ('Irina Socolova', 0),
#  ('Il Giornale', 0),
#  ('𝗗𝗜𝗦𝗜𝗡𝗙𝗢𝗥𝗠𝗔𝗭𝗜𝗢𝗡𝗘.𝗜𝗧 - Marcello Pamio', 0),
#  ('Christian Tabletop', 0),
#  ('Breaking News - Ultimora.net', 0),
#  ('TERRA (Tanker Enemy Channel)', 0),
#  ('Francesca Totolo (Unico canale)', 0),
#  ('Роман Алехин', 0),
#  ('Gundamecha', 0),
#  ('Marrake(k)bab🥄', 0),
#  ('Banana Society', 0),
#  ('ТРОЙКА 🏴\u200d☠️', 0),
#  ('F.K.MAGNVS', 0),
#  ('susiety', 0),
#  ('ПриZрак Новороссии', 0),
#  ('S̸̈ͅC̵̺͒H̷̰̤͚̀I̵ ͔Z̵̬̼͗O̴̝̺̐͋͌P̴̹̹̙̾̒̑Ǒ̶͚͐̎S̵̭͕̔͗T̸͙̔͘͜Į̸̂N̴̰̈́͘G̴̫̩̜͑̍͝',
#   0),
#  ('Осведомитель', 0),
#  ('L’Altra Faccia dell’Impero', 0),
#  ('ꑭ Oppressed Lifters', 0),
#  ('Fortissax is Typing', 0),
#  ('Really cool memes actually', 0),
#  ('Target', 0),
#  ('ImolaOggi Channel', 0),
#  ('Beregini', 0),
#  ("Secolo d'Italia", 0),
#  ('ЖИВОВ Z 🇷🇺', 0),
#  ('bmpd', 0),
#  ('Ziegler Channel ＭＹ ＰＵＳＳＹ ＩＮ ＢＩＯ', 0),
#  ('Matteo Brandi - Canale Ufficiale', 0),
#  ('Proud ODDstanians', 0),
#  ('Josef stern💪 informazioni libere.', 0),
#  ('La Tana NSFW del Sorcio 🇺🇦🇵🇸', 0),
#  ('[CANALE] Miracolo a Milano', 0),
#  ('Qlobal-Change Italia 🇮🇹', 0),
#  ('Andrea Tosatto Official', 0),
#  ('Vare TROPICALSHINY Posting [ Sumika shrine ]', 0),
#  ('BRIGATE BENSON', 0),
#  ('Il Canale di Loti', 0),
#  ('Svitlana NEWS', 0),
#  ('🇷🇺Дневник Мракоборцев | Z🇷🇺 (Группа Аида СпН "Ахмат")', 0),
#  ('C E N S O R | M E | D A D D Y - Anime edition', 0),
#  ('Geg the gambler', 0),
#  ('GEOPOLI (Mappe&Storia)', 0),
#  ('Война с фейками', 0),
#  ('アニメ・ミーム・レポ・😭⃠・🇮🇱⃠', 0),
#  ('LOSTARMOUR | Carthago delenda est!', 0),
#  ('𝕀ℕ𝕊𝕀𝔻𝔼ℝ ℚ 𝕀𝕋𝔸𝕃𝕐 🇮🇹', 0),
#  ('Balkniggers & Slavtards', 0),
#  ("Alexzan's Telegram blog - Galaxy! ⚝", 0),
#  ('apple.com', 0),
#  ('Портфель Генштаба', 0),
#  ('Aletheia Intelligence (OSINT)', 0),
#  ('InfoDefenseENGLISH', 0),
#  ('Node of Time العربية\u200e', 0),
#  ('Wᴀʀ Rᴇᴀʟ Tɪᴍᴇ 🔞', 0),
#  ('Квантум справедливости', 0),
#  ('Monica Elisa', 0),
#  ("[\U0001faa8] romu's repository", 0),
#  ('ZENIT', 0),
#  ('HickTown', 0),
#  ('La civetta bianca', 0),
#  ("Woodpecker's Hove", 0),
#  ('Patria Socialista', 0),
#  (1267795651, 0),
#  ('Progetto Razzia', 0),
#  ('IL RISVEGLIO DELLA FENICE', 0),
#  ('Bran.co ets', 0),
#  ('ХИЛЕР l HEALER', 0),
#  ("Cronache dal virus che non c'è", 0),
#  ('Matteo Montevecchi', 0),
#  ('UKR LEAKS_Italia', 0),
#  (1592564357, 0),
#  ('Working Man Memes', 0),
#  ('🇦🇺AussieCossack🇷🇺', 0),
#  ('Strategic Culture Foundation', 0),
#  ('Paracetamolo BNKR44 FANCLUB', 0),
#  ('Covo di Lyfex', 0),
#  ('☕️рыр м🐳мент', 0),
#  ('Weltanschauung Italia', 0),
#  ('GREY ZONE', 0),
#  ('Astra Militarum [Z]', 0),
#  ('Russia e Dintorni', 0),
#  ('sicksadsorrymess', 0),
#  ('Israele News', 0),
#  ('ARSENALE K CHANNEL - Circolo Ricreativo delle Bestie di Satira', 0),
#  ('BEAST OF GOD / MT MEDIA', 0),
#  ('Enzo Di Frenna • BLOG', 0),
#  ('Due maestri di sala', 0),
#  ('Intel Slava Z', 0),
#  ('Laluce.news', 0),
#  ('Канал специального назначения', 0),
#  ('Griff Capital LLC', 0),
#  ('Europe Elects Official', 0),
#  ('Uriel Crua', 0),
#  ('/r/Mapporn', 0),
#  ('Джокер ДНР', 0),
#  ('Joeri no Jigoku 😳🥴🤙', 0),
#  ('18+ The Weasel Meme Stash 18+', 0),
#  ('Рыбарь', 0),
#  ('Южная башня', 0),
#  ('CasaDelSoleTV', 0),
#  ('CURANTE RAFFAELE VARVARA', 0),
#  ('Global Resistance News', 0),
#  ('ZERGULIO🇷🇺', 0),
#  ('Iranball 2: Electric Boogaloo | Post-suicide EDITION', 0),
#  ('Il Canarino nella Miniera di Carbone', 0),
#  ('Чешир таежный и дело о пропавшем 28-м штате', 0),
#  ('Il canale di Marco', 0),
#  ('Mobile Suit Merriuaa DAI CAZZO HOLD THE DOOR BECNABOR', 0),
#  ('Notizie 24 ore', 0),
#  ('Донбасский Партизан', 0),
#  ('Danilo Hardy', 0),
#  ("Manga's Corner 🐉", 0),
#  ('Ultimo Uomo ☧', 0),
#  ("L'eRemita", 0),
#  ('Visione Tv', 0),
#  ('Byoblu', 0),
#  ("Fyodor's Necro", 0),
#  ("Ol' Sweepys Southern-Style Broom Emporium and Meme Trading Post", 0),
#  ('Bello, Onesto, emigrato Australia', 0),
#  ('La Cattedrale di Kirby NG+', 0),
#  ('BASTA guerra nel Donbass', 0),
#  ('Sparkling water (la mia sbo)', 0),
#  ('Jomsvikings', 0),
#  ('Zаписки мичмана Птичкина', 0),
#  ("𝑲𝒖𝒘𝒂𝒅𝒐𝒓𝒊𝒂𝒏 ~Oyashiro-sama's cult~", 0),
#  ('Scenari Economici Channel', 0),
#  ('Sauce', 0),
#  ('Lyceum musicum Citaudium Novum, Catana - Circulus veneratorum Rosalindae',
#   0),
#  ('TERZO MILLENNIO', 0),
#  ('Dardix Hub', 0),
#  ('Comunità Militante Raido', 0),
#  ('Centro Studi Eurasia e Mediterraneo (CeSEM)', 0),
#  ('Sputnik Africa', 0),
#  ("Snark Shark's Shit", 0),
#  ('Dal Popolo italiano con amore', 0),
#  ("Enby pirate's depressed and horny memes and unrelated mischievous stuff",
#   0),
#  ('Dissociati Liberi', 0),
#  ("Smeed's Springery and Bloomery (not boioioing edition)", 0),
#  ('Neuroni Funzionanti', 0),
#  ('gabriel oracolo di kirby 🏳️\u200d🌈 👽', 0),
#  ('Кикури каждый день(Наверное)', 0),
#  ('ROKOT | FRASTUONO', 0),
#  ('𝗖𝗢𝗡𝗦𝗘𝗡𝗦𝗢 𝗗𝗜𝗦𝗜𝗡𝗙𝗢𝗥𝗠𝗔𝗧𝗢', 0),
#  ('Midget memes, broken dreams', 0),
#  ('Белорусский силовик 🇧🇾', 0),
#  ('Olga guida SPb', 0),
#  ('ZOG 2.0', 0),
#  ('АДЕКВАТ Z', 0),
#  ('SAS Mahjong Supplies ᗜˬᗜ ⚝⃠', 0),
#  ('Rossella Fidanza', 0),
#  ('Der Einzige - Il fronte intellettuale', 0),
#  ('Twongo', 0),
#  ('Underground', 0),
#  ('Natty Light Nationalism', 0),
#  ('Andrea Zhok', 0),
#  ('Internet §u§ Machine', 0),
#  ('Savino Balzano', 0),
#  ('White People Telegram', 0),
#  ('Месть доброй воли', 0),
#  ('White House Watch', 0),
#  ('Gospa News', 0),
#  ('History Memes', 0),
#  ('Greed Photography', 0),
#  ('Anti-Bug Eaters', 0),
#  ("🐙Lovecraft's Cat🐙", 0),
#  ('SilvioDallaTorre', 0),
#  ('TEAM 17', 0),
#  ('Уголок Ситха', 0),
#  (1622084077, 0),
#  ('Gods Strongest Dumpster Divers', 0),
#  ('Eurasia & Multipolarity', 0),
#  ('Canale epico di Rei 😎', 0),
#  ('07th Expansion Italia', 0),
#  ('Агрегатор', 0),
#  ('Eventi Avversi News', 0),
#  ('Lo Squillo di Gilberto Trombetta', 0),
#  ('Андрей Медведев', 0),
#  ('ALI - Avvocati Liberi', 0),
#  ("Daniele Dell'Orco Geopolitica", 0),
#  ('Срочно, Сейчас', 0),
#  ('Yuliana Titaeva / Юлиана Титаева', 0),
#  ('Veeb Bob Channel (Can-Am Weekend 2020)', 0),
#  ('IL PIANO - LA RINASCITA DELL UMANITÀ', 0),
#  (1355818098, 0),
#  ('FUORI DAL GREGGE 🐑🐑🐑', 0),
#  (2118575870, 0),
#  ('🌍 𝐕𝐎𝐂𝐈 𝐃𝐀𝐋𝐋𝐀 𝐒𝐓𝐑𝐀𝐃𝐀 🌎', 0),
#  ('Африканская инициатива 🌍', 0),
#  ('Il Fritto Misto 2', 0),
#  ('CORVELVA', 0),
#  (1680897239, 0),
#  ('I feed dogs chocolate', 0),
#  ('Press TV', 0),
#  ('Il Vaso di Pandora', 0),
#  ('Informazione Consapevole', 0),
#  ('𝕂𝕚𝕥𝕥𝕖𝕟 𝔾𝕒𝕟𝕘 🐈', 0),
#  ('ТЫ ТАМ БЫЛ? (Павел Кукушкин)', 0),
#  ('БелВПО', 0),
#  ('Вадим Лобов. Новости', 0),
#  ('Дмитрий Медведев', 0),
#  ('Marx21.it', 0),
#  ('Тринадцатый.', 0),
#  ('Franco Fracassi Giornalista Indipendente', 0),
#  ('Keith Woods', 0),
#  ('I Fucking Hate Science', 0),
#  ('Kotsnews', 0),
#  ('Toba 60', 0),
#  ('Воин DV', 0),
#  ('/slashbiz/ ~ Sneed, Crypto, Business and Finance, AI, memes and news, and being poor in general',
#   0),
#  ('ℂ𝕒𝕥𝕙𝕠𝕝𝕚𝕔 𝔸𝕡𝕠𝕝𝕠𝕘𝕖𝕥𝕚𝕔𝕤 𝕒𝕟𝕕 ℙ𝕠𝕝𝕖𝕞𝕚𝕔𝕤', 0),
#  (1636876924, 0),
#  ("\U0001faf4🏻Devil's Downfall\U0001faf3🏻", 0),
#  ('/𝘽𝙖𝙛/ 𝘽𝙖𝙨𝙚𝙙 𝙖𝙣𝙙 𝙁𝙞𝙩', 0),
#  ('Blofeld’s Undersea Lair (You Only Live Twice)', 0),
#  ('Ludovica Iacovacci', 0),
#  ('Рубрика от Ледка', 0),
#  ('papera fanclub 🍉', 0),
#  ('Neural OpenNet', 0),
#  ('Beyond Liberalism', 0),
#  ('Shit posting from the front lines', 0),
#  ('Ростех', 0),
#  ('Sa.R Coaching e Comunicazione - Verso la Versione Migliore di Te!', 0),
#  ('Aryan Traphouse', 0),
#  (1614984541, 0),
#  ('Slantie Mongoloid Hate', 0),
#  ('Silver Nervuti - Canale Ufficiale', 0),
#  ('Comitato Centrale', 0),
#  ('vx-underground', 0),
#  ('Vynlazer Militia International', 0),
#  ('Jacopo Coghe', 0),
#  ('Ukrainians Are Based Goy', 0),
#  ('Neinsider', 0),
#  ('ChildResQue Ita Channel', 0),
#  ('Pacster Dice Cose', 0),
#  ('Военкор Астрахань', 0),
#  ('🔥 Spicy Steamed Memeballs 🔥', 0),
#  ('UKR LEAKS_ara', 0),
#  (1774881602, 0),
#  ('Daily Manga Art', 0),
#  ('ЧЕСТНЫЙ ВЛАСОВ', 0),
#  ('The Depot', 0),
#  ('Kla.TV Italiano', 0),
#  ('Gunpla Italia', 0),
#  ('они пришли', 0),
#  ('Israel (is over) Maymay Base 🛢 BBC-News EDITION', 0),
#  ('Surf Dad', 0),
#  ('Художник Z патриот Елена Бегма', 0),
#  ('🇮🇹IL PAESE DEI BALOCCHI🇮🇹', 0),
#  ('Народная милиция ДНР', 0),
#  ('Pensa&Scrivi', 0),
#  ('The Land of Mu ⚛️', 0),
#  ('Dirlebanger', 0),
#  ('#SalviamoILNostroPresente🇮🇹👊', 0),
#  ('ТРИБУНАЛ', 0),
#  ('Libera Espressione', 0),
#  ('ZАПИСКИ VЕТЕРАНА', 0),
#  ('🇳🇱🇱🇷Q Belgianjokes 😂 Q 🇱🇷🇳🇱', 0),
#  ('ComeDonChisciotte.org - UFFICIALE', 0),
#  ('Good Shit™️😤😤', 0),
#  ('небезызвестный приколдес', 0),
#  ('Daylight Blue - Mahoyo Edition', 0),
#  ('Моисей |Сводки с фронта', 0),
#  ('Mild Mannered', 0),
#  ('🄵🅁🄰🄶🄸🄻🄴 🄳🄴🄼🄾🄲🅁🄰🄲🅈', 0),
#  ('NO ZTL NO CITTÀ 15 MINUTI ®', 0),
#  ('Opinioni personali', 0),
#  ('Anime Tea Times', 0),
#  ('MORTI DA VACCINO COVID-19', 0),
#  ('Aviahub⚪️🟠', 0),
#  ('Военкор Ярем', 0),
#  ('Movimento Indipendenza!', 0),
#  ('Arruinas Channel', 0),
#  ('La pillola bianca del giorno', 0),
#  ("L' arte di Satyrus", 0),
#  ('Dr. BARBARA BALANZONI (qui doc, video, audio,foto)', 0),
#  ('🤍💙♥️MADRE RUSSIA🤍💙♥️', 0),
#  ('Cringe-o-rama V2', 0),
#  ('Настоящий Гладков', 0),
#  ('КатяВаля', 0),
#  ('Notizie da Asia Centrale e Caucaso', 0),
#  (1333789968, 0),
#  ('St. Peter’s Firewood Emporium', 0),
#  ('Военкор l Z l Лисицын ZOV-TV', 0),
#  ('The Fascio Newsletter', 0),
#  ('Paolo Borgognone', 0),
#  ('esoteric vibrations 🌻✝️', 0),
#  ('Lara Arlotta Ufficiale', 0),
#  ('Korean Hate', 0),
#  ("Russian Federation's Pro-Putin Channel", 0),
#  ('EternalShit', 0),
#  ('SocialTv Network', 0),
#  ('Joel Davis', 0),
#  ('ARBITRIUM PSG', 0),
#  ('РИА Новости', 0),
#  ('Военные преступники', 0),
#  ('Pics with Nationalities', 0),
#  ('Shalnyak', 0),
#  ('La locanda di Lore Remastered ma è maledetta dalla cone di Bronya. Pre Comicon arc',
#   0),
#  ('Sosach Waffen', 0),
#  ('WMS 🇮🇹 - War Meme Squad Italia', 0),
#  ('Israele Senza Filtri', 0),
#  (1870867398, 0),
#  (1949113532, 0),
#  ('RA - Russia Amica (Дружественная Россия)', 0),
#  ('IL PUGNO DURO DEL CLAN', 0),
#  ('♠️Exposing Truth♣️', 0),
#  ('Federica Francesconi - canale ufficiale 🖤🔥💪', 0),
#  ('💚🤍❤️ ITA "INFORMAZIONE"', 0),
#  ('DistopiaEva', 0),
#  ('Dystopian Discourse', 0),
#  ('Un altro punto di vista', 0),
#  ('maledetto bile', 0),
#  ('Empyrean Art⚜️🖼️', 0),
#  ('Комментатор', 0),
#  ('UBERSOY’s Slovo', 0),
#  ('●T● Lion White Potus____🔔', 0),
#  ('Foto piedi Orrore Profondo', 0),
#  ('нежный мех 🦕', 0),
#  ('Ugo Fuoco 🔥 Stop Dittatura', 0),
#  ('MultiXAM', 0),
#  ('Sara Reginella - Canale ufficiale', 0),
#  ('Gaganauts of Geopolitics', 0),
#  (1483620643, 0),
#  ('JewishContributions.com', 0),
#  ('Репортёр Руденко V', 0),
#  ('🦦 Otter gang 🦦', 0),
#  ('📢 Progetto DREYFUS {LIVE news}', 0),
#  ('LA VERITÀ RENDE LIBERI', 0),
#  ('/BMW/ - The Bureau of Memetic Warfare', 0),
#  ('Middle East Spectator', 0),
#  ('ODDstan Videos', 0),
#  (1236702378, 0),
#  ('JOIN @geopolitics_live » official Sputnik International mirror', 0),
#  ('Лука Ебков', 0),
#  ('🤡Congregation of Clussy🤡', 0),
#  ('Люди Z', 0),
#  ('PRO ITALIA - Canale Ufficiale', 0),
#  ('Francesco Amodeo', 0),
#  ('Compagnia Dostoevskij', 0),
#  ('Frente Oriental', 0),
#  ('Денис [Z] Григорюк', 0),
#  ('X-HEAVY', 0),
#  ('Smokes & Memes is FRONT!', 0),
#  ('Trump History', 0),
#  ('ألسنا على الحق', 0),
#  ('🇮🇹🇷🇺🄸🅃🄰🄻🄸🄰 🆉︎🇷🇺🇮🇹', 0),
#  ('Dentro la Notizia®', 0),
#  ('Guerra nordica', 0),
#  ('Russian MFA 🇷🇺', 0),
#  ('ENTRE GUERRAS', 0),
#  ('FREE ASSANGE Italia', 0),
#  ('/v/‘s Video Memes', 0),
#  ('9MQ Web TV', 0),
#  ("EDOARDO DINI IL CLAN DELL'ANTIVIRUS", 0),
#  ('Matteo Demicheli', 0),
#  ('Empyrean Memes🍄', 0),
#  ('Maurizio Vezzosi', 0),
#  ('lol calm down', 0),
#  ('Герои спецоперации Z', 0),
#  ('Marvbol Gang: BALLS IN BIO', 0),
#  ('Renovatio 21', 0),
#  ('National Revolution', 0),
#  ('Бармалей 🦇 #снаряды/гос.награды_Вагнеру 🇷🇺', 0),
#  ('КАСПЕР 🇧🇾', 0),
#  ('X-21 Memes: Edge Dpt.', 0),
#  ('O.S.A. Italia (canale)', 0),
#  ('Страх и ненависть в Бамако (ARTEM BLINOV)', 0),
#  ('ГорИнформбюро', 0),
#  ('Word on the ϟtreet', 0),
#  ('EXTRA BREAD', 0),
#  ('il Post', 0),
#  ('Операция Z: Военкоры Русской Весны', 0),
#  (1933159099, 0),
#  ('Michael J. Nelson', 0),
#  ('Fortnite ITA | News & Leaks 🇮🇹', 0),
#  ('Военторг Marvin Tactical', 0),
#  ('Fearless John - @European_dissident', 0),
#  (1648425831, 0),
#  ('P(r)ettyposting 💖🍉', 0),
#  ('Inessa S ️️', 0),
#  ('⚔️ Чёрная Мамба ⚔️', 0),
#  ('Sou Wan', 0),
#  ('Seek Truth From Facts', 0),
#  (1402266347, 0),
#  ('𝘾𝙤𝙡𝙪𝙢𝙗𝙪𝙨 𝙄𝙣𝙛𝙤𝙧𝙢𝙖𝙯𝙞𝙤𝙣𝙚', 0),
#  ('Чешир и удивительное путешествие на контейнер', 0),
#  ('ZOROARYAN', 0),
#  ('Q Evidence', 0),
#  ('ARCAPACIS', 0),
#  (1851358412, 0),
#  (2022709466, 0),
#  ('🇵🇸🏳️\u200d🌈∆̷Ⓐ☭ASCELLE FANCLUB☭Ⓐ∆̷🏳️\u200d🌈🇵🇸', 0),
#  ('Il Baule dei Meme di Letteralmente lo Sherlock Holmes della Soia', 0),
#  ('🇮🇹⚙️🕉🛠☯️🇮🇹LABORATORIO del LAVORO - Facciamo alchimie', 0),
#  ('Radio28Tv', 0),
#  ('Kremlin. News', 0),
#  (1246662598, 0),
#  ('Davide Rossi scrittore', 0),
#  ('Pietro Minute (canale)', 0),
#  ('MARIage sorcière', 0),
#  ('RA/Avv. DDr. Renate Holzeisen', 0),
#  ('Черные береты Каспия', 0),
#  ('eternal classic', 0),
#  ('Интербригады 2022', 0),
#  ('Socialism with Chinese Characteristics', 0),
#  ('Damn.🦶🏻', 0),
#  ('i disegni bellissimi di emma', 0),
#  ('Wojak', 0),
#  ('Hic Sunt Leones 🦁 - (canale di Renato Russo)', 0),
#  ('Bellum Acta - Intel, Urgent News and Archives', 0),
#  ('КОРТАДОР', 0),
#  ("I Guerrieri dell'AMORE", 0),
#  ('Stalinist Revisionism', 0),
#  ('Tartararikus', 0),
#  ('Артур Виноградов', 0),
#  ('𝐏𝐮𝐩𝐩𝐞𝐫 𝐆𝐚𝐧𝐠 🐶', 0),
#  (1385594756, 0),
#  ('Respect Your Elders', 0),
#  ('LeakyVax', 0),
#  ('As-Subah', 0),
#  ('Eurasia | Rivista di studi geopolitici', 0),
#  ('Kekenavts Analytics', 0),
#  ('Z News ChannelZ📡', 0),
#  ('Bittereinders Nasionaal', 0),
#  ('География сердца', 0),
#  ('CatHunt', 0),
#  ('La Terra dei Padri', 0),
#  ('Holistic Earth', 0),
#  ('РаZVожаев', 0),
#  ('Giovanni Lindo Memetti', 0),
#  (1712680300, 0),
#  ('Devil Shitposting', 0),
#  ('Reddit Moments', 0),
#  ('Разведотряд 106', 0),
#  ("Gondola's mannerbvnd compovnd", 0),
#  ('musick to play in the dark', 0),
#  ('Оперативные сводки', 0),
#  ('Avia.pro', 0),
#  ('Am I an electric sheep?', 0),
#  ('PALESTINA HOY 🇵🇸', 0),
#  ('Hux’s Deluxe Channel', 0),
#  ('UmanitàinAzione', 0),
#  ('Di Sana e Robusta Costituzione', 0),
#  ('アジアの曙', 0),
#  ('Looting Channel', 0),
#  (1223065977, 0),
#  (1960648125, 0),
#  ('Хроника оператора БпЛА', 0),
#  ('Russia Beyond in italiano', 0),
#  ('GUNDAM ᐟ GUNPLA * ガンダム', 0),
#  ('A ｓｈｕｒａ ｐｏｓｔｉｎｇ[Queen Draco edition] ☯️', 0),
#  ('Christian Cookery', 0),
#  ('Tama’s Corner🔪🎉 [COMMS OPEN]', 0),
#  ('TARTARIA ITALIA INTERNATIONAL : La storia non può rimanere nascosta per sempre',
#   0),
#  ('I,Hypocrite', 0),
#  ('Ратник 2-го раZряда', 0),
#  ('Pissed Texan', 0),
#  ('Alessandro Di Battista', 0),
#  ('tumblr', 0),
#  ("V's journal of scientific shitposting - Now certified 100% psyop free", 0),
#  ('Leggiamo le leggi (Laura Carosi)', 0),
#  ("JC's Shitposting Fartzone", 0),
#  ('MikaYoutubers', 0),
#  ('Русская классическая живопись', 0),
#  ('Go to @OdeToPower3', 0),
#  (1784668808, 0),
#  ('irinapetrakova', 0),
#  ("Daboo's Stuff", 0),
#  ('HiKARi 光 🌻', 0),
#  ('Punished Clossington', 0),
#  ('Atom Front III: ADL ☢', 0),
#  ('miki is going delulu', 0),
#  ('Abbas Djuma', 0),
#  ('OttolinaTV', 0),
#  ('International Reporters', 0),
#  ('NOTICIAS BRAVAS', 0),
#  ('Casus Belli', 0),
#  ('Anna KuZnetsoVa', 0),
#  ('Правда за нами', 0),
#  ('СОЛДАТ УДАЧИ', 0),
#  ("PLAYMASTERMOVIE - canale d'informazione libera", 0),
#  ('Italiaeilmondo', 0),
#  ('Максим Шугалей', 0),
#  ("L'Era dell'Oro - Antonella e Werner", 0),
#  ('Генерал-губернатор ДВ', 0),
#  ('Effetto Risonanza', 0),
#  ('Alexander Dugin', 0),
#  ('INDIPENDENZA!🇮🇹 - EMILIA', 0),
#  (1633241826, 0),
#  ('DD Geopolitics', 0),
#  ('Silvana Sale_ Babajola Arrubia ☭', 0),
#  ('Игра в ЦивилиZацию', 0),
#  ('Пул N3', 0),
#  ('GIORGIO RICCARDINI QUANTISTICO', 0),
#  ('НПО Двина', 0),
#  ('ТАСС', 0),
#  ('🇮🇹 Italiani in Russia 🇷🇺', 0),
#  ('Pars Today Russian', 0),
#  ('Avv. Andrea Perillo', 0),
#  ('УКРОПСКИЙ ФРЕШ', 0),
#  ('Larkin', 0),
#  ('Anti European Fascism', 0),
#  ("Rei's Gallery", 0),
#  ("L'Osservatorio - Italia", 0),
#  ('Lapekoranera.it', 0),
#  ('WARPIG memes', 0),
#  ('Russians With Attitude', 0),
#  ('Сыны Монархии', 0),
#  ('Roberto Vannacci Ufficiale', 0),
#  ('𝐕𝐢𝐝𝐞𝐨𝐬 𝐄𝐱𝐭𝐫𝐞𝐦𝐞 🔞', 0),
#  ('NOVAX ZONE ITALIA 🚑', 0),
#  ('The Conspiracy Hole', 0),
#  ("Dyne's Everything Dump", 0),
#  ('СREW RUSSIA', 0),
#  ('Росич | Rosich', 0),
#  ('ЖелеZные каски', 0),
#  ('ALL YOUR BASE', 0),
#  ('Ukraine Scenes from Journalistic Crusade', 0),
#  ('Resistance News Network', 0),
#  ('Компартия ☭ Беларуси', 0),
#  ('Verticale', 0),
#  ('🇷🇺БОБР🇷🇺', 0),
#  ('EDGYLiFTER85', 0),
#  ('Third Reich Memes', 0),
#  ('Z комитет + карта СВО', 0),
#  ('Franco Battiato Telegram Channel', 0),
#  ('Sergio Berlato', 0),
#  ('Resistance Channel', 0),
#  ('Paola Arminio Farmacista e Filosofa della Guarigione', 0),
#  ('animali di merda', 0),
#  ('contropiano', 0),
#  ('Red Ice TV', 0),
#  ('Алексей Суконкин', 0),
#  ('G4M3 0V3R CH4NN3L 🐸', 0),
#  ('Kuzmenko Blog', 0),
#  ('ФЕСТИВАЛЬ «RT.ДОК:ВРЕМЯ ГЕРОЕВ»', 0),
#  (1302430368, 0),
#  ('💚🤍❤️ Madre in ITA', 0),
#  ('✂️ Monogatari Series Italia', 0),
#  ('Il blog di Sabino Paciolla', 0),
#  ('Юрий Баранчик', 0),
#  ("UU's Memes", 0),
#  ('Shitposting: a lexical abuse', 0),
#  ('Revista La Comuna.', 0),
#  ('Дзермант', 0),
#  ('Ma è fattuale', 0),
#  ('Informazione Multipolare 🚩', 0),
#  ('Eurosiberia', 0),
#  ('Помощь военнослужащим 31', 0),
#  ('InsideOver', 0),
#  ('ПТСР TEAM Community', 0),
#  ("Kefka's Shrine", 0),
#  ('💚🤍❤️ ITA ARIA "Istruzione & Cultura"', 0),
#  ('Multilevel della libertà', 0),
#  ('World Pravda', 0),
#  ('/CIG/ Telegram | Counter Intelligence Global', 0),
#  ('Kriss Raff info', 0),
#  ('💚🤍❤️ Il Mondo ITA', 0),
#  ('UrFO_INFO', 0),
#  ('Massoneria e Che te lo dico a fare 👁️👃🏻', 0),
#  ('⚔️ СВАРЩИКИ', 0),
#  ('Biblioteca per la consapevolezza', 0),
#  ('Sondaggi BiDiMedia', 0),
#  ('Acaposting :3', 0),
#  ('LordLando-chan(nel)', 0),
#  ('Data distribution center', 0),
#  ("Ossomaki's Crafting Table (Drawing & TTRPG)", 0),
#  ('Redpilled Rabbit', 0),
#  ('severe shitposting society', 0),
#  ('Davida CamQrani', 0),
#  ('IRNA НА РУССКОМ', 0),
#  ('La durezza del vivere', 0),
#  ('Консерватор', 0),
#  ("\U0001fa99 THE FERRYMAN'S TOLL \U0001fa99", 0),
#  ('Пушистые угнетатели', 0),
#  ('Гост Юнгер', 0),
#  ('Anticapitalist Surrealism 🇵🇸🔻', 0),
#  ('Mapo', 0),
#  ('Putin.Life', 0),
#  ("Muncher's collective", 0),
#  (1505747277, 0),
#  ('"Un commercialista di Bari" [cit.] @giuslit', 0),
#  ('Mr. Putin', 0),
#  ('Fabio Fazio si incula da solo con un sofisticato sistema di specchi e leve',
#   0),
#  ('ПОДКАСТ ДНР', 0),
#  ('Anime & Manga Copypasta', 0),
#  ('Men intel', 0),
#  ('Luca Ratti News emergenza censura', 0),
#  ('Военное обозрение', 0),
#  ('Я и друг мой вертолёт', 0),
#  ('Ambasciator non porta pena', 0),
#  (1213041076, 0),
#  ('Fronte dei Popoli', 0),
#  (1216053281, 0),
#  ('ПАНКИН', 0),
#  ('‼️ULTIMA OFFERTA💰- le migliori offerte del web', 0),
#  ('Концерн «Калашников»', 0),
#  ('U_G_M', 0),
#  ("Eta's stolen memes 'n' queer stuff (personal art not included)", 0),
#  (1089515781, 0),
#  ('Me_irl', 0),
#  ('Асфальт', 0),
#  ("Buttafuoco's Memes N' Takes", 0),
#  ('Greater East Asia Co-Prosperity Sphere (大東亜共栄圏)', 0),
#  ('Pressenza - Italia', 0),
#  ('Quds News Network', 0),
#  ('Кастраторная жоская', 0),
#  ('Congregation of Clussy 3', 0),
#  ('Apocalisse ✨( la rivelazione) ✨VERITÀ Nascoste', 0),
#  ('EroSoc - Erotic Socialism', 0),
#  ('The straggot', 0),
#  ('Nin.Gish.Zid.Da - ®wld', 0),
#  ('Come Don Chisciotte - Informazione indipendente dal 2003', 0),
#  ('Awesome MP4', 0),
#  ('Kulturjam.it', 0),
#  ('Zaraf | Z', 0),
#  ('COMICON', 0),
#  ('Il bandito da firenze', 0),
#  ("King Koopa's Shellposting Kingdom", 0),
#  (1230715784, 0),
#  ('Правда Шурави.', 0),
#  ("Alt Skull's Charnel House", 0),
#  ('Geopolitika en español', 0),
#  ('Racial Beauty', 0),
#  ("𝔾𝕠𝕣𝕠'𝕤 ℙ𝕒𝕝𝕒𝕔𝕖 - ℝ𝕖𝕒𝕝𝕚𝕥𝕪 𝕄𝕠𝕠𝕟𝕗𝕒𝕝𝕝", 0),
#  ('Avv. Mauro Sandri', 0),
#  ('Il campo elettromagnetico di Sheikah e Yakeri', 0),
#  ('Il Canale Animato', 0),
#  ('Benedetta Piola Caselli', 0),
#  ('"C\'s" tea', 0),
#  ('Pino Daniele 2', 0),
#  ('Книга Носовича', 0),
#  ('Луганские заметки | Lugansk remembers', 0),
#  ('White Lads Aesthetics', 0),
#  (1536714302, 0),
#  ('Fate/Italy', 0),
#  ('Geopolitical news24/24🇺🇦 News', 0),
#  ('LON - I Memes di Benjamin', 0),
#  ("Bellerophon's Autism Plantation", 0),
#  ('Daily Duck', 0),
#  ('Middle Earth Times', 0),
#  ('Суверенная экономика', 0),
#  ('Emporium ReRedux', 0),
#  ('SìAMO - canale ufficiale', 0),
#  ('Buffonate di Stato', 0),
#  ('Post-Shitposting (ZHIN-ZHIAN-AZADI: Show Must Go On! edition)', 0),
#  ('No Remorse (China)', 0),
#  ('Akashic Record ✍️', 0),
#  (1519094009, 0),
#  ('Украина.ру', 0),
#  ('Amerikaner', 0),
#  ('Comitato Delicati PRIMA UDIENZA', 0),
#  ('sharted in my pants (Mumu Ogun thunderstrike your mom)', 0),
#  ...]

# %% [markdown]
# # Let's filter for only links over 1

# %%
edgelist_filtered = edgelist[edgelist['count']>1]

# %%
## load it into igraph
G = ig.Graph.TupleList(edgelist_filtered.itertuples(index=False), directed=True, weights=True)

# %%
## community detection
communities = G.as_undirected().community_leiden(objective_function="modularity")

## add community as node label
G.vs['community'] = communities.membership

# %%
G.vs['label'] = list(map(lambda x: id_to_names_int.get(x,x),G.vs['name']))
G.vs['desc'] = list(map(lambda x: id_to_desc_int.get(x,x),G.vs['name']))

# %%
Sigma(G, node_size=G.degree(mode='out'),
      node_color=G.vs['community'], 
      hide_edges_on_move=True,
      node_color_gradient='Viridis', node_label=G.vs['label'],
     layout_settings = {"barnesHutOptimize":False,
                       'gravity': 0.1})
# Out:
# Sigma(ig.Graph with 2,047 nodes and 4,122 edges)

# %%
max(communities.membership)
#23 communities
# Out:
# 23

# %%
dict_degree = Counter(G.degree())
dict_degree_in = Counter(G.indegree())
dict_degree_out = Counter(G.outdegree())

# %%
plt.scatter(dict_degree.keys(), dict_degree.values())
plt.xscale('log')
plt.yscale('log')
plt.title('Degree distribution (total degree)')
plt.show()

# %%
plt.scatter(dict_degree_in.keys(), dict_degree_in.values())
plt.xscale('log')
plt.yscale('log')
plt.title('Indegree distribution')
plt.show()

# %%
plt.scatter(dict_degree_out.keys(), dict_degree_out.values())
plt.xscale('log')
plt.yscale('log')
plt.title('Outdegree distribution')
plt.show()
